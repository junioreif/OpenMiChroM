# %% [markdown]
# # Tutorial: Single chromosome optimization using OpenMiChroM
#
#
# ## This tutorial enables performing optimization in MiChroM Parameters

# %% [markdown]
# The first step is import the OpenMiChroM modules.
#
# (To install OpenMM and OpenMiChroM, follow the instalation guide)

# %%
from OpenMiChroM.ChromDynamics import MiChroM #OpenMiChroM simulation module
from OpenMiChroM.Optimization import CustomMiChroMTraining #optimization MiChroM parameters module
from OpenMiChroM.CndbTools import cndbTools #analysis tools module

#modules to load and plot .dense file 
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.preprocessing import normalize
import numpy as np
import pandas as pd
import h5py

# %% [markdown]
# *The second step is to have a look on the experimental Hi-C*
#
# A Hi-C file is required for the analysis and training of the MiChroM Potentials (Types and Ideal Chromosome). The file format chosen here is a matrix .txt file (we call it the dense file).

# %% [markdown]
# For this tutorial, we will use chromosome 10 from GM12878 in 100 kb resolution.
#
# To extract it from the .hic file we can use juicer_tools with this command:
#
# *java -jar juicer_tools_1.22.01.jar dump observed NONE -d https://hicfiles.s3.amazonaws.com/hiseq/gm12878/in-situ/combined.hic 10 10 BP 100000 input/chr10_100k.dense*

# %%
# %%bash
# java -jar apps/juicer_tools_1.22.01.jar dump observed Balanced -d https://hicfiles.s3.amazonaws.com/hiseq/gm12878/in-situ/combined.hic 10 10 BP 100000 input/chr10_100k.dense
# Out:
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# WARN [2022-08-30T15:28:22,497]  [Globals.java:138] [main]  Development mode is enabled
# INFO [2022-08-30T15:28:23,120]  [DirectoryManager.java:179] [main]  IGV Directory: /home/antonio/igv
# INFO [2022-08-30T15:28:23,331]  [HttpUtils.java:937] [main]  Range-byte request succeeded

# %% [markdown]
# This command downloads the .hic from the web and extracts the chromosome 10 in .dense format to the folder "input".
#
# You can get more information about it at the JuicerTools documentation.

# %% [markdown]
# Visualize the .dense file for inspection

# %%
filename = 'input/chr10_100k.dense'
hic_file = np.loadtxt(filename)

r=np.triu(hic_file, k=1) 
r[np.isnan(r)]= 0.0
r = normalize(r, axis=1, norm='max') 
rd = np.transpose(r) 
r=r+rd + np.diag(np.ones(len(r)))
print("number of beads: ", len(r))
plt.matshow(r,norm=mpl.colors.LogNorm(vmin=0.0001, vmax=r.max()),cmap="Reds")  
plt.colorbar()
# Out:
# number of beads:  1356

# %% [markdown]
# The Hi-C map has resolution of $100 kb$ per bead, so the chromosome 10 model has a polymer chain with a total of 1356 beads

# %% [markdown]
# The next step is to extract the sequence file (A/B sequence) by using the eigenvector decomposition. <br>
#
# Using the juicertools you can extract the eigenvector file. The eigenvector has values both negatives and positives and here we will arbitrary set positives as A1 and negatives as B1. <br>
#
# For more details about how it works, take a look on this paper: https://pubs.acs.org/doi/full/10.1021/acs.jpcb.1c04174

# %%
# %%bash
# java -jar apps/juicer_tools_1.22.01.jar eigenvector -p Balanced https://hicfiles.s3.amazonaws.com/hiseq/gm12878/in-situ/combined.hic 10 BP 100000 input/chr10_100k.eigen
# Out:
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# WARN [2022-08-30T15:33:08,279]  [Globals.java:138] [main]  Development mode is enabled
# INFO [2022-08-30T15:33:08,783]  [DirectoryManager.java:179] [main]  IGV Directory: /home/antonio/igv
# INFO [2022-08-30T15:33:08,975]  [HttpUtils.java:937] [main]  Range-byte request succeeded

# %%
eigen = np.loadtxt("input/chr10_100k.eigen")
plt.plot(eigen)

# %% [markdown]
# From the .eigen file we can create the A/B sequence file.

# %%
# %%bash
# awk '{if ($1 < 0) print "B1"; else print "A1"}' input/chr10_100k.eigen | cat -n > input/seq_chr10_100k.txt
# head input/seq_chr10_100k.txt
# Out:
#      1	A1
#      2	B1
#      3	B1
#      4	B1
#      5	B1
#      6	B1
#      7	B1
#      8	B1
#      9	B1
#     10	B1

# %% [markdown]
# The pipeline to perform the Types Potential Optimization is:<br>
#
# 1 - Run a long simulation using the homopolymer potential + customTypes potential.
#     The first iteration will start with all parameters equal to zero or a initial guess.<br>
#
# 2 - Get frames from this simualtion to perform the inversion for Types.<br>
#
# 3 - In the end of inversion, new values to types interactions will be produced.<br>
#
# 4 - Calcule the error between the simulated and experimental parameters. If the error is above the treshold, re-do steps 1-3 until reaching the treshold (usually 10% or 15%).

# %% [markdown]
# The Types file is a .txt file with a matrix labeled with values for each interaction. In this tutorial, we will be training A1 and B1 type. <br>
#
# Lets create the initial file at this format: <br>
# A1,B1<br>
# 0,0<br>
# 0,0<br>
#
# For this matrix, we have AA AB BA BB interactions.
#
# Save it as lambda_0.txt

# %%
# %%bash
# echo "A1,B1
# 0,0
# 0,0" > input/lambda_0
#
# cat input/lambda_0
# Out:
# A1,B1
# 0,0
# 0,0

# %% [markdown]
# With all the required inputs, lets perform a simulation for iteration 0

# %% [markdown]
# In MiChroM initiation there are some variables to setup:
#
# **time_step=0.01** (the time step using for integration, default is 0.01)<br>
# **temperature=1** (Set the temperature of your simulation)<br>
# **name='opt_chr10_100K'** (the simulation name)<br>

# %%
sim = MiChroM(name='opt_chr10_100K',temperature=1.0, time_step=0.01)
# Out:
#     ***************************************************************************************
#      **** **** *** *** *** *** *** *** OpenMiChroM-1.0.3 *** *** *** *** *** *** **** ****
#
#          OpenMiChroM is a Python library for performing chromatin dynamics simulations.
#                             OpenMiChroM uses the OpenMM Python API,
#                 employing the MiChroM (Minimal Chromatin Model) energy function.
#       The chromatin dynamics simulations generate an ensemble of 3D chromosomal structures
#       that are consistent with experimental Hi-C maps, also allows simulations of a single
#                  or multiple chromosome chain using High-Performance Computing
#                             in different platforms (GPUs and CPUs).
#          OpenMiChroM documentation is available at https://open-michrom.readthedocs.io
#
#          OpenMiChroM is described in: Oliveira Junior, A. B & Contessoto, V, G et. al.
#       A Scalable Computational Approach for Simulating Complexes of Multiple Chromosomes.
#                   Journal of Molecular Biology. doi:10.1016/j.jmb.2020.10.034.
#                                               and
#                                  Oliveira Junior, A. B. et al.
#      Chromosome Modeling on Downsampled Hi-C Maps Enhances the Compartmentalization Signal.
#                         J. Phys. Chem. B, doi:10.1021/acs.jpcb.1c04174.
#
#                     Copyright (c) 2022, The OpenMiChroM development team at
#                                         Rice University
#     ***************************************************************************************

# %% [markdown]
# Now you need to setup the platform that you will use, the options are:
#
# **platform="cuda"** (remember that you need to install CUDA in your system)<br>
# **GPU="0" (optional)** (if you have more than one GPU device, you can set which gpu you want ["0", "1",...,"n"])<br>
# **platform="cpu"**<br>
# **platform="opencl"**<br>

# %%
sim.setup(platform="CUDA")

# %% [markdown]
# Set the folder name where the output will be saved

# %%
sim.saveFolder('iteration_0')

# %% [markdown]
# The next step is to setup your chromosome sequence and initial configuration

# %%
mychro = sim.create_springSpiral(ChromSeq="input/seq_chr10_100k.txt")

# %% [markdown]
# Load the initial structure into "sim" object

# %%
sim.loadStructure(mychro, center=True)

# %% [markdown]
# Now it is time to include the force field in the simulation object "sim"
#
# Lets separate forces in two sets:
#
# **Homopolymer Potentials**

# %%
sim.addFENEBonds(kfb=30.0)
sim.addAngles(ka=2.0)
sim.addRepulsiveSoftCore(Ecut=4.0)

# %% [markdown]
# **Chromosome Potentials**
#
# In this tutorial, it is used the CustomTypes potential. <br>
# Here we need to pass a file that contains a matrix of interactions for each other different type of chromosome.
# To check that, you can look on the documentation https://open-michrom.readthedocs.io/en/latest/OpenMiChroM.html#OpenMiChroM.ChromDynamics.MiChroM.addCustomTypes <br>

# %%
sim.addCustomTypes(mu=3.22, rc = 1.78, TypesTable='input/lambda_0')

# %% [markdown]
# Note: these valeus for mu and rc were calculated for human GM12878 cells and can be changed for other species.

# %% [markdown]
# The last potential to be added is the spherical restraint in order to collapse the initial structure

# %%
sim.addFlatBottomHarmonic(kr=5*10**-3, n_rad=8.0)

# %% [markdown]
# Now we will run a short simulation in order to get a collapsed structure.

# %% [markdown]
# There are two variables that control the chromosomes simulation steps:
#
# **block:** The number of steps performed in each cycle (n_Blocks)<br>
# **n_blocks:** The number of blocks that will be perfomed. <br>
#
# In this example, to perfom the collapsing we will run $5\times10^2 \times  10^3 = 5\times10^5$ steps

# %%
block = 5*10**2 
n_blocks = 10**3

# %% [markdown]
# We can save the radius of gyration of each block to observe the convergence into the collapsed state (the time required here depends on the size of your chromosome)

# %%
rg = []

# %%
for _ in range(n_blocks):
    sim.runSimBlock(block, increment=False)
    rg.append(sim.chromRG())

#save a collapsed structure in pdb format for inspection
sim.saveStructure(mode = 'pdb')
# Out:
# Number of exceptions: 1355
# adding force  FENEBond 0
# adding force  AngleForce 1
# Add exclusions for RepulsiveSoftCore force
# adding force  RepulsiveSoftCore 2
# Add exclusions for CustomTypes force
# adding force  CustomTypes 3
# adding force  FlatBottomHarmonic 4
# Positions...
#  loaded!
# potential energy is 31.227320
# bl=0 pos[1]=[103.9 -4.9 0.5] dr=1.21 t=0.0ps kin=1.54 pot=31.50 Rg=72.950 SPS=2267
# bl=0 pos[1]=[102.1 -4.6 2.3] dr=1.98 t=0.0ps kin=1.75 pot=31.15 Rg=71.660 SPS=15314
# bl=0 pos[1]=[98.4 -2.7 3.1] dr=2.06 t=0.0ps kin=1.82 pot=30.83 Rg=70.152 SPS=15337
# bl=0 pos[1]=[95.3 -1.7 3.3] dr=2.02 t=0.0ps kin=1.80 pot=30.44 Rg=68.589 SPS=15319
# bl=0 pos[1]=[93.4 -2.4 5.5] dr=1.97 t=0.0ps kin=1.82 pot=30.04 Rg=67.051 SPS=15652
# bl=0 pos[1]=[91.4 -1.7 6.1] dr=1.95 t=0.0ps kin=1.85 pot=29.65 Rg=65.530 SPS=15538
# bl=0 pos[1]=[90.3 -0.9 5.4] dr=1.93 t=0.0ps kin=1.86 pot=29.28 Rg=64.040 SPS=16477
# bl=0 pos[1]=[89.4 -1.0 7.0] dr=1.93 t=0.0ps kin=1.92 pot=28.89 Rg=62.538 SPS=18441
# bl=0 pos[1]=[88.0 0.1 8.4] dr=1.91 t=0.0ps kin=1.89 pot=28.52 Rg=61.061 SPS=20534
# bl=0 pos[1]=[85.1 2.6 9.7] dr=1.89 t=0.0ps kin=1.93 pot=28.16 Rg=59.638 SPS=18455
# bl=0 pos[1]=[81.4 2.8 10.2] dr=1.85 t=0.0ps kin=1.83 pot=27.82 Rg=58.261 SPS=18745
# bl=0 pos[1]=[80.7 0.8 10.7] dr=1.81 t=0.0ps kin=1.83 pot=27.48 Rg=56.948 SPS=20802
# bl=0 pos[1]=[78.2 1.2 9.3] dr=1.78 t=0.0ps kin=1.77 pot=27.20 Rg=55.709 SPS=17335
# bl=0 pos[1]=[76.8 2.2 9.3] dr=1.73 t=0.0ps kin=1.71 pot=26.93 Rg=54.513 SPS=18477
# bl=0 pos[1]=[76.5 0.6 9.2] dr=1.72 t=0.0ps kin=1.74 pot=26.63 Rg=53.332 SPS=20323
# bl=0 pos[1]=[74.3 -0.9 9.5] dr=1.73 t=0.0ps kin=1.76 pot=26.37 Rg=52.133 SPS=18562
# bl=0 pos[1]=[71.7 -1.7 9.6] dr=1.72 t=0.0ps kin=1.79 pot=26.15 Rg=50.952 SPS=17982
# bl=0 pos[1]=[69.5 -0.5 9.5] dr=1.73 t=0.0ps kin=1.77 pot=25.88 Rg=49.796 SPS=19959
# bl=0 pos[1]=[67.7 -1.5 9.6] dr=1.67 t=0.0ps kin=1.73 pot=25.66 Rg=48.701 SPS=17869
# bl=0 pos[1]=[66.9 -0.9 10.4] dr=1.67 t=0.0ps kin=1.73 pot=25.44 Rg=47.618 SPS=17603
# bl=0 pos[1]=[64.7 -0.9 9.4] dr=1.66 t=0.0ps kin=1.71 pot=25.24 Rg=46.542 SPS=19074
# bl=0 pos[1]=[63.2 -0.8 7.7] dr=1.64 t=0.0ps kin=1.70 pot=25.03 Rg=45.490 SPS=20192
# bl=0 pos[1]=[61.8 -0.5 6.9] dr=1.61 t=0.0ps kin=1.64 pot=24.84 Rg=44.494 SPS=18912
# bl=0 pos[1]=[60.5 0.7 5.3] dr=1.60 t=0.0ps kin=1.69 pot=24.67 Rg=43.518 SPS=20562
# bl=0 pos[1]=[58.3 1.3 6.2] dr=1.60 t=0.0ps kin=1.68 pot=24.51 Rg=42.567 SPS=18838
# bl=0 pos[1]=[55.6 0.2 5.5] dr=1.56 t=0.0ps kin=1.60 pot=24.34 Rg=41.659 SPS=18804
# bl=0 pos[1]=[54.2 1.0 4.4] dr=1.58 t=0.0ps kin=1.64 pot=24.22 Rg=40.746 SPS=20677
# bl=0 pos[1]=[52.6 2.9 5.5] dr=1.55 t=0.0ps kin=1.62 pot=24.07 Rg=39.883 SPS=18787
# bl=0 pos[1]=[51.1 2.6 4.8] dr=1.53 t=0.0ps kin=1.64 pot=23.95 Rg=39.089 SPS=20565
# bl=0 pos[1]=[47.4 2.3 4.1] dr=1.48 t=0.0ps kin=1.65 pot=23.85 Rg=38.326 SPS=19244
# bl=0 pos[1]=[45.3 3.7 4.6] dr=1.52 t=0.0ps kin=1.61 pot=23.69 Rg=37.585 SPS=18783
# bl=0 pos[1]=[44.4 5.2 5.1] dr=1.49 t=0.0ps kin=1.59 pot=23.56 Rg=36.820 SPS=18927
# bl=0 pos[1]=[43.6 4.4 2.6] dr=1.47 t=0.0ps kin=1.59 pot=23.44 Rg=36.073 SPS=19171
# bl=0 pos[1]=[42.5 5.6 2.3] dr=1.46 t=0.0ps kin=1.56 pot=23.36 Rg=35.370 SPS=18843
# bl=0 pos[1]=[41.0 5.5 0.7] dr=1.44 t=0.0ps kin=1.53 pot=23.37 Rg=34.668 SPS=20317
# bl=0 pos[1]=[39.1 5.6 0.8] dr=1.44 t=0.0ps kin=1.59 pot=23.22 Rg=33.951 SPS=18905
# bl=0 pos[1]=[39.0 6.3 0.6] dr=1.42 t=0.0ps kin=1.59 pot=23.13 Rg=33.242 SPS=18669
# bl=0 pos[1]=[38.9 6.8 0.0] dr=1.41 t=0.0ps kin=1.63 pot=23.02 Rg=32.561 SPS=20701
# bl=0 pos[1]=[37.4 6.8 -0.5] dr=1.42 t=0.0ps kin=1.57 pot=22.99 Rg=31.896 SPS=18675
# bl=0 pos[1]=[35.5 6.2 -0.5] dr=1.43 t=0.0ps kin=1.55 pot=22.85 Rg=31.276 SPS=19311
# bl=0 pos[1]=[35.3 5.8 0.1] dr=1.41 t=0.0ps kin=1.63 pot=22.82 Rg=30.733 SPS=20022
# bl=0 pos[1]=[33.3 5.6 1.2] dr=1.39 t=0.0ps kin=1.57 pot=22.83 Rg=30.181 SPS=17535
# bl=0 pos[1]=[31.6 3.5 2.1] dr=1.40 t=0.0ps kin=1.59 pot=22.75 Rg=29.622 SPS=18023
# bl=0 pos[1]=[30.7 3.2 4.7] dr=1.38 t=0.0ps kin=1.53 pot=22.71 Rg=29.071 SPS=19159
# bl=0 pos[1]=[31.2 2.1 6.2] dr=1.38 t=0.0ps kin=1.54 pot=22.64 Rg=28.503 SPS=17855
# bl=0 pos[1]=[32.1 2.1 6.2] dr=1.37 t=0.0ps kin=1.54 pot=22.57 Rg=27.961 SPS=16317
# bl=0 pos[1]=[33.0 3.0 4.8] dr=1.37 t=0.0ps kin=1.58 pot=22.55 Rg=27.447 SPS=16984
# bl=0 pos[1]=[31.8 3.7 2.9] dr=1.36 t=0.0ps kin=1.61 pot=22.45 Rg=26.988 SPS=17442
# bl=0 pos[1]=[30.3 6.5 2.9] dr=1.37 t=0.0ps kin=1.61 pot=22.48 Rg=26.554 SPS=18385
# bl=0 pos[1]=[29.7 6.2 3.6] dr=1.37 t=0.0ps kin=1.54 pot=22.38 Rg=26.141 SPS=18705
# bl=0 pos[1]=[29.9 4.9 5.1] dr=1.34 t=0.0ps kin=1.55 pot=22.36 Rg=25.731 SPS=17511
# bl=0 pos[1]=[29.1 2.9 4.9] dr=1.33 t=0.0ps kin=1.50 pot=22.26 Rg=25.307 SPS=18391
# bl=0 pos[1]=[27.4 0.9 4.7] dr=1.33 t=0.0ps kin=1.48 pot=22.23 Rg=24.875 SPS=19232
# bl=0 pos[1]=[27.9 -0.9 4.2] dr=1.33 t=0.0ps kin=1.50 pot=22.19 Rg=24.429 SPS=17631
# bl=0 pos[1]=[27.5 -3.2 4.4] dr=1.33 t=0.0ps kin=1.52 pot=22.21 Rg=24.010 SPS=17098
# bl=0 pos[1]=[26.8 -4.7 3.8] dr=1.35 t=0.0ps kin=1.56 pot=22.16 Rg=23.629 SPS=16283
# bl=0 pos[1]=[26.7 -4.7 3.2] dr=1.33 t=0.0ps kin=1.56 pot=22.14 Rg=23.256 SPS=16827
# bl=0 pos[1]=[26.8 -4.4 2.6] dr=1.34 t=0.0ps kin=1.63 pot=22.13 Rg=22.844 SPS=16918
# bl=0 pos[1]=[27.7 -2.7 2.0] dr=1.38 t=0.0ps kin=1.55 pot=22.08 Rg=22.458 SPS=19292
# bl=0 pos[1]=[25.9 -2.2 3.3] dr=1.33 t=0.0ps kin=1.48 pot=22.10 Rg=22.088 SPS=14574
# bl=0 pos[1]=[23.9 -1.4 3.2] dr=1.37 t=0.0ps kin=1.57 pot=22.03 Rg=21.742 SPS=17884
# bl=0 pos[1]=[21.7 -2.2 2.2] dr=1.35 t=0.0ps kin=1.54 pot=22.02 Rg=21.421 SPS=17353
# bl=0 pos[1]=[21.9 -2.9 2.7] dr=1.33 t=0.0ps kin=1.57 pot=22.01 Rg=21.130 SPS=17368
# bl=0 pos[1]=[20.6 -2.5 3.0] dr=1.34 t=0.0ps kin=1.53 pot=21.98 Rg=20.842 SPS=17250
# bl=0 pos[1]=[20.4 -2.1 2.9] dr=1.32 t=0.0ps kin=1.53 pot=21.97 Rg=20.547 SPS=19075
# bl=0 pos[1]=[20.4 -2.2 1.4] dr=1.28 t=0.0ps kin=1.51 pot=21.95 Rg=20.245 SPS=18238
# bl=0 pos[1]=[21.5 -2.3 0.8] dr=1.28 t=0.0ps kin=1.52 pot=21.89 Rg=19.947 SPS=16549
# bl=0 pos[1]=[20.7 -1.4 0.9] dr=1.28 t=0.0ps kin=1.48 pot=21.92 Rg=19.677 SPS=16441
# bl=0 pos[1]=[20.6 -1.9 0.3] dr=1.30 t=0.0ps kin=1.52 pot=21.91 Rg=19.474 SPS=16932
# bl=0 pos[1]=[21.1 -3.0 -0.6] dr=1.29 t=0.0ps kin=1.57 pot=21.86 Rg=19.258 SPS=16532
# bl=0 pos[1]=[23.5 -3.7 -0.9] dr=1.27 t=0.0ps kin=1.48 pot=21.87 Rg=19.032 SPS=17485
# bl=0 pos[1]=[25.4 -2.4 1.8] dr=1.29 t=0.0ps kin=1.55 pot=21.83 Rg=18.814 SPS=17673
# bl=0 pos[1]=[24.6 -0.1 3.0] dr=1.28 t=0.0ps kin=1.53 pot=21.85 Rg=18.641 SPS=15405
# bl=0 pos[1]=[21.8 -0.2 5.3] dr=1.27 t=0.0ps kin=1.59 pot=21.87 Rg=18.455 SPS=16270
# bl=0 pos[1]=[20.5 -3.5 5.6] dr=1.32 t=0.0ps kin=1.57 pot=21.86 Rg=18.229 SPS=16041
# bl=0 pos[1]=[21.1 -5.5 4.4] dr=1.27 t=0.0ps kin=1.54 pot=21.84 Rg=18.004 SPS=16192
# bl=0 pos[1]=[19.2 -6.3 3.1] dr=1.28 t=0.0ps kin=1.53 pot=21.85 Rg=17.757 SPS=16189
# bl=0 pos[1]=[19.8 -5.8 4.6] dr=1.25 t=0.0ps kin=1.52 pot=21.84 Rg=17.569 SPS=16545
# bl=0 pos[1]=[18.9 -6.3 5.8] dr=1.26 t=0.0ps kin=1.52 pot=21.81 Rg=17.410 SPS=16248
# bl=0 pos[1]=[20.5 -6.0 8.1] dr=1.27 t=0.0ps kin=1.57 pot=21.80 Rg=17.226 SPS=16711
# bl=0 pos[1]=[20.0 -4.7 8.7] dr=1.27 t=0.0ps kin=1.52 pot=21.82 Rg=17.064 SPS=16760
# bl=0 pos[1]=[19.3 -5.2 7.9] dr=1.29 t=0.0ps kin=1.56 pot=21.80 Rg=16.925 SPS=17865
# bl=0 pos[1]=[18.6 -5.7 8.4] dr=1.31 t=0.0ps kin=1.54 pot=21.80 Rg=16.789 SPS=17055
# bl=0 pos[1]=[17.7 -5.3 7.4] dr=1.32 t=0.0ps kin=1.59 pot=21.74 Rg=16.655 SPS=15830
# bl=0 pos[1]=[18.8 -3.7 7.8] dr=1.30 t=0.0ps kin=1.55 pot=21.68 Rg=16.497 SPS=16472
# bl=0 pos[1]=[18.5 -3.3 8.6] dr=1.28 t=0.0ps kin=1.56 pot=21.74 Rg=16.306 SPS=16209
# bl=0 pos[1]=[21.0 -1.3 9.8] dr=1.28 t=0.0ps kin=1.48 pot=21.80 Rg=16.062 SPS=16257
# bl=0 pos[1]=[22.9 -2.4 9.0] dr=1.25 t=0.0ps kin=1.49 pot=21.76 Rg=15.849 SPS=16302
# bl=0 pos[1]=[22.0 -3.3 8.9] dr=1.27 t=0.0ps kin=1.50 pot=21.71 Rg=15.634 SPS=16115
# bl=0 pos[1]=[21.5 -3.7 9.7] dr=1.27 t=0.0ps kin=1.47 pot=21.69 Rg=15.472 SPS=16689
# bl=0 pos[1]=[21.3 -4.3 9.5] dr=1.28 t=0.0ps kin=1.52 pot=21.66 Rg=15.321 SPS=16658
# bl=0 pos[1]=[21.1 -4.6 8.6] dr=1.27 t=0.0ps kin=1.48 pot=21.71 Rg=15.145 SPS=17151
# bl=0 pos[1]=[20.1 -5.9 9.8] dr=1.28 t=0.0ps kin=1.41 pot=21.69 Rg=15.024 SPS=17925
# bl=0 pos[1]=[19.4 -6.3 9.9] dr=1.24 t=0.0ps kin=1.45 pot=21.65 Rg=14.860 SPS=16636
# bl=0 pos[1]=[17.7 -6.7 9.0] dr=1.26 t=0.0ps kin=1.47 pot=21.64 Rg=14.700 SPS=16578
# bl=0 pos[1]=[16.2 -7.5 5.8] dr=1.27 t=0.0ps kin=1.49 pot=21.61 Rg=14.516 SPS=16436
# bl=0 pos[1]=[16.3 -7.4 4.1] dr=1.24 t=0.0ps kin=1.46 pot=21.64 Rg=14.371 SPS=16587
# bl=0 pos[1]=[15.1 -5.8 2.4] dr=1.24 t=0.0ps kin=1.49 pot=21.67 Rg=14.288 SPS=16585
# bl=0 pos[1]=[15.8 -4.6 1.4] dr=1.25 t=0.0ps kin=1.46 pot=21.68 Rg=14.224 SPS=16594
# bl=0 pos[1]=[16.6 -4.2 1.3] dr=1.23 t=0.0ps kin=1.53 pot=21.63 Rg=14.184 SPS=15348
# bl=0 pos[1]=[18.4 -4.6 1.8] dr=1.28 t=0.0ps kin=1.46 pot=21.69 Rg=14.125 SPS=16664
# bl=0 pos[1]=[19.6 -4.6 1.2] dr=1.27 t=0.0ps kin=1.52 pot=21.62 Rg=14.011 SPS=18536
# bl=0 pos[1]=[19.8 -3.7 0.2] dr=1.28 t=0.0ps kin=1.50 pot=21.65 Rg=13.868 SPS=16704
# bl=0 pos[1]=[18.4 -2.7 -1.6] dr=1.25 t=0.0ps kin=1.48 pot=21.66 Rg=13.707 SPS=16400
# bl=0 pos[1]=[17.9 -1.6 -1.9] dr=1.26 t=0.0ps kin=1.52 pot=21.66 Rg=13.534 SPS=17046
# bl=0 pos[1]=[17.4 -1.7 -1.4] dr=1.25 t=0.0ps kin=1.46 pot=21.65 Rg=13.437 SPS=16781
# bl=0 pos[1]=[16.4 -1.3 -2.2] dr=1.25 t=0.0ps kin=1.49 pot=21.61 Rg=13.315 SPS=16702
# bl=0 pos[1]=[14.4 -0.3 -1.9] dr=1.26 t=0.0ps kin=1.50 pot=21.60 Rg=13.167 SPS=17017
# bl=0 pos[1]=[14.8 -1.6 -1.8] dr=1.24 t=0.0ps kin=1.51 pot=21.62 Rg=12.986 SPS=17859
# bl=0 pos[1]=[14.6 -2.8 -1.7] dr=1.26 t=0.0ps kin=1.53 pot=21.60 Rg=12.847 SPS=16795
# bl=0 pos[1]=[14.1 -3.2 -1.2] dr=1.28 t=0.0ps kin=1.50 pot=21.59 Rg=12.755 SPS=17539
# bl=0 pos[1]=[12.6 -3.4 -0.2] dr=1.24 t=0.0ps kin=1.49 pot=21.61 Rg=12.649 SPS=16664
# bl=0 pos[1]=[13.7 -4.1 -1.5] dr=1.26 t=0.0ps kin=1.49 pot=21.60 Rg=12.539 SPS=16209
# bl=0 pos[1]=[14.6 -4.0 -1.5] dr=1.24 t=0.0ps kin=1.55 pot=21.61 Rg=12.473 SPS=16644
# bl=0 pos[1]=[14.3 -2.7 0.5] dr=1.29 t=0.0ps kin=1.55 pot=21.63 Rg=12.354 SPS=16801
# bl=0 pos[1]=[14.1 -4.3 1.3] dr=1.30 t=0.0ps kin=1.51 pot=21.60 Rg=12.228 SPS=17734
# bl=0 pos[1]=[15.3 -4.9 0.8] dr=1.28 t=0.0ps kin=1.51 pot=21.62 Rg=12.055 SPS=16541
# bl=0 pos[1]=[15.1 -6.0 0.2] dr=1.25 t=0.0ps kin=1.49 pot=21.64 Rg=11.916 SPS=16712
# bl=0 pos[1]=[14.2 -6.8 1.6] dr=1.24 t=0.0ps kin=1.46 pot=21.62 Rg=11.841 SPS=16592
# bl=0 pos[1]=[12.6 -7.3 2.6] dr=1.26 t=0.0ps kin=1.48 pot=21.62 Rg=11.794 SPS=15591
# bl=0 pos[1]=[11.1 -6.7 2.5] dr=1.26 t=0.0ps kin=1.50 pot=21.60 Rg=11.729 SPS=16452
# bl=0 pos[1]=[9.6 -7.3 4.7] dr=1.28 t=0.0ps kin=1.50 pot=21.62 Rg=11.693 SPS=16756
# bl=0 pos[1]=[10.4 -7.1 5.6] dr=1.27 t=0.0ps kin=1.49 pot=21.58 Rg=11.723 SPS=16978
# bl=0 pos[1]=[12.4 -7.6 4.8] dr=1.26 t=0.0ps kin=1.46 pot=21.57 Rg=11.737 SPS=16935
# bl=0 pos[1]=[13.8 -6.1 4.9] dr=1.24 t=0.0ps kin=1.52 pot=21.56 Rg=11.729 SPS=17286
# bl=0 pos[1]=[13.9 -6.4 4.4] dr=1.27 t=0.0ps kin=1.49 pot=21.59 Rg=11.718 SPS=16719
# bl=0 pos[1]=[13.9 -7.7 3.6] dr=1.26 t=0.0ps kin=1.44 pot=21.63 Rg=11.718 SPS=16449
# bl=0 pos[1]=[14.4 -8.9 4.0] dr=1.27 t=0.0ps kin=1.48 pot=21.57 Rg=11.786 SPS=16482
# bl=0 pos[1]=[14.8 -9.5 4.9] dr=1.26 t=0.0ps kin=1.46 pot=21.61 Rg=11.765 SPS=16923
# bl=0 pos[1]=[14.9 -10.1 4.0] dr=1.28 t=0.0ps kin=1.48 pot=21.59 Rg=11.761 SPS=16737
# bl=0 pos[1]=[14.3 -9.0 3.8] dr=1.30 t=0.0ps kin=1.45 pot=21.59 Rg=11.749 SPS=16644
# bl=0 pos[1]=[12.7 -6.6 2.6] dr=1.28 t=0.0ps kin=1.49 pot=21.59 Rg=11.705 SPS=17587
# bl=0 pos[1]=[13.7 -4.5 3.1] dr=1.25 t=0.0ps kin=1.51 pot=21.57 Rg=11.706 SPS=17379
# bl=0 pos[1]=[13.5 -5.1 2.1] dr=1.28 t=0.0ps kin=1.52 pot=21.63 Rg=11.736 SPS=16628
# bl=0 pos[1]=[13.1 -4.4 2.0] dr=1.31 t=0.0ps kin=1.54 pot=21.58 Rg=11.783 SPS=17106
# bl=0 pos[1]=[12.4 -2.8 2.5] dr=1.26 t=0.0ps kin=1.51 pot=21.61 Rg=11.775 SPS=16305
# bl=0 pos[1]=[13.5 -2.8 2.0] dr=1.28 t=0.0ps kin=1.54 pot=21.61 Rg=11.743 SPS=16207
# bl=0 pos[1]=[13.3 -1.2 0.4] dr=1.29 t=0.0ps kin=1.50 pot=21.55 Rg=11.683 SPS=16272
# bl=0 pos[1]=[12.5 -2.3 -0.3] dr=1.25 t=0.0ps kin=1.58 pot=21.63 Rg=11.625 SPS=16470
# bl=0 pos[1]=[11.4 -3.4 -0.7] dr=1.26 t=0.0ps kin=1.52 pot=21.62 Rg=11.595 SPS=16937
# bl=0 pos[1]=[11.3 -2.6 -1.2] dr=1.24 t=0.0ps kin=1.51 pot=21.64 Rg=11.575 SPS=17781
# bl=0 pos[1]=[10.4 -2.0 -1.0] dr=1.26 t=0.0ps kin=1.55 pot=21.64 Rg=11.624 SPS=16461
# bl=0 pos[1]=[12.1 -1.4 -2.0] dr=1.27 t=0.0ps kin=1.49 pot=21.63 Rg=11.661 SPS=16366
# bl=0 pos[1]=[11.6 0.1 -1.3] dr=1.25 t=0.0ps kin=1.51 pot=21.63 Rg=11.661 SPS=16266
# bl=0 pos[1]=[10.5 -0.1 -0.8] dr=1.29 t=0.0ps kin=1.49 pot=21.61 Rg=11.679 SPS=16567
# bl=0 pos[1]=[12.1 -1.1 -0.4] dr=1.26 t=0.0ps kin=1.51 pot=21.61 Rg=11.721 SPS=16290
# bl=0 pos[1]=[12.4 -1.5 -0.1] dr=1.28 t=0.0ps kin=1.54 pot=21.60 Rg=11.739 SPS=16262
# bl=0 pos[1]=[12.3 -1.0 0.3] dr=1.28 t=0.0ps kin=1.56 pot=21.52 Rg=11.756 SPS=16674
# bl=0 pos[1]=[14.5 0.3 1.2] dr=1.27 t=0.0ps kin=1.47 pot=21.60 Rg=11.716 SPS=17306
# bl=0 pos[1]=[15.4 0.4 2.9] dr=1.30 t=0.0ps kin=1.56 pot=21.55 Rg=11.715 SPS=17947
# bl=0 pos[1]=[15.6 0.2 3.5] dr=1.34 t=0.0ps kin=1.50 pot=21.59 Rg=11.719 SPS=16668
# bl=0 pos[1]=[15.3 -1.2 4.6] dr=1.30 t=0.0ps kin=1.55 pot=21.54 Rg=11.706 SPS=16071
# bl=0 pos[1]=[13.7 -1.1 4.3] dr=1.26 t=0.0ps kin=1.48 pot=21.61 Rg=11.599 SPS=16753
# bl=0 pos[1]=[13.2 -0.2 3.3] dr=1.28 t=0.0ps kin=1.52 pot=21.59 Rg=11.507 SPS=16634
# bl=0 pos[1]=[12.8 0.6 6.1] dr=1.28 t=0.0ps kin=1.51 pot=21.61 Rg=11.479 SPS=16680
# bl=0 pos[1]=[12.2 1.5 6.8] dr=1.27 t=0.0ps kin=1.51 pot=21.62 Rg=11.469 SPS=17030
# bl=0 pos[1]=[12.1 1.2 6.7] dr=1.26 t=0.0ps kin=1.47 pot=21.66 Rg=11.452 SPS=18076
# bl=0 pos[1]=[11.5 1.5 6.9] dr=1.24 t=0.0ps kin=1.52 pot=21.62 Rg=11.455 SPS=16718
# bl=0 pos[1]=[11.6 1.1 6.1] dr=1.24 t=0.0ps kin=1.51 pot=21.63 Rg=11.433 SPS=16310
# bl=0 pos[1]=[11.7 -0.2 5.4] dr=1.23 t=0.0ps kin=1.53 pot=21.60 Rg=11.457 SPS=16944
# bl=0 pos[1]=[11.5 -3.1 6.1] dr=1.27 t=0.0ps kin=1.54 pot=21.63 Rg=11.499 SPS=16643
# bl=0 pos[1]=[11.6 -4.3 7.5] dr=1.28 t=0.0ps kin=1.50 pot=21.63 Rg=11.532 SPS=16310
# bl=0 pos[1]=[11.0 -3.8 8.0] dr=1.20 t=0.0ps kin=1.50 pot=21.66 Rg=11.563 SPS=16290
# bl=0 pos[1]=[11.7 -2.9 8.1] dr=1.28 t=0.0ps kin=1.55 pot=21.62 Rg=11.568 SPS=16727
# bl=0 pos[1]=[13.2 -2.3 7.1] dr=1.29 t=0.0ps kin=1.50 pot=21.66 Rg=11.605 SPS=17732
# bl=0 pos[1]=[13.8 -2.8 6.4] dr=1.32 t=0.0ps kin=1.55 pot=21.55 Rg=11.674 SPS=17061
# bl=0 pos[1]=[14.3 -4.0 4.4] dr=1.29 t=0.0ps kin=1.45 pot=21.60 Rg=11.716 SPS=16634
# bl=0 pos[1]=[14.7 -4.0 3.9] dr=1.29 t=0.0ps kin=1.49 pot=21.59 Rg=11.743 SPS=16310
# bl=0 pos[1]=[12.7 -6.4 4.3] dr=1.26 t=0.0ps kin=1.46 pot=21.56 Rg=11.802 SPS=16799
# bl=0 pos[1]=[13.0 -7.4 4.4] dr=1.25 t=0.0ps kin=1.50 pot=21.55 Rg=11.880 SPS=16632
# bl=0 pos[1]=[12.0 -7.7 4.4] dr=1.24 t=0.0ps kin=1.47 pot=21.60 Rg=11.926 SPS=16493
# bl=0 pos[1]=[12.0 -6.5 6.1] dr=1.22 t=0.0ps kin=1.49 pot=21.57 Rg=11.906 SPS=17605
# bl=0 pos[1]=[11.4 -6.4 6.2] dr=1.24 t=0.0ps kin=1.51 pot=21.58 Rg=11.861 SPS=17815
# bl=0 pos[1]=[12.2 -6.6 6.0] dr=1.27 t=0.0ps kin=1.49 pot=21.57 Rg=11.792 SPS=16815
# bl=0 pos[1]=[12.2 -7.2 7.1] dr=1.28 t=0.0ps kin=1.48 pot=21.61 Rg=11.764 SPS=16636
# bl=0 pos[1]=[13.5 -7.2 6.3] dr=1.23 t=0.0ps kin=1.55 pot=21.57 Rg=11.713 SPS=16218
# bl=0 pos[1]=[12.9 -6.4 4.7] dr=1.26 t=0.0ps kin=1.55 pot=21.59 Rg=11.683 SPS=16233
# bl=0 pos[1]=[12.2 -5.0 4.6] dr=1.28 t=0.0ps kin=1.52 pot=21.57 Rg=11.645 SPS=16854
# bl=0 pos[1]=[10.5 -5.9 5.4] dr=1.27 t=0.0ps kin=1.45 pot=21.61 Rg=11.589 SPS=16718
# bl=0 pos[1]=[11.7 -6.9 5.1] dr=1.25 t=0.0ps kin=1.53 pot=21.56 Rg=11.530 SPS=18208
# bl=0 pos[1]=[11.4 -6.4 3.9] dr=1.25 t=0.0ps kin=1.51 pot=21.60 Rg=11.568 SPS=17130
# bl=0 pos[1]=[11.0 -7.7 5.7] dr=1.25 t=0.0ps kin=1.56 pot=21.62 Rg=11.604 SPS=16195
# bl=0 pos[1]=[9.9 -6.8 7.1] dr=1.27 t=0.0ps kin=1.56 pot=21.62 Rg=11.700 SPS=15787
# bl=0 pos[1]=[10.1 -5.0 6.2] dr=1.27 t=0.0ps kin=1.51 pot=21.57 Rg=11.758 SPS=16057
# bl=0 pos[1]=[10.0 -4.9 6.6] dr=1.27 t=0.0ps kin=1.47 pot=21.63 Rg=11.765 SPS=16383
# bl=0 pos[1]=[9.5 -5.2 5.3] dr=1.25 t=0.0ps kin=1.45 pot=21.59 Rg=11.819 SPS=15937
# bl=0 pos[1]=[9.3 -4.9 6.4] dr=1.24 t=0.0ps kin=1.49 pot=21.59 Rg=11.836 SPS=15607
# bl=0 pos[1]=[8.1 -3.4 7.0] dr=1.22 t=0.0ps kin=1.47 pot=21.63 Rg=11.800 SPS=16601
# bl=0 pos[1]=[6.9 -2.0 5.7] dr=1.26 t=0.0ps kin=1.51 pot=21.67 Rg=11.736 SPS=16360
# bl=0 pos[1]=[6.5 -2.1 4.7] dr=1.29 t=0.0ps kin=1.57 pot=21.62 Rg=11.657 SPS=17023
# bl=0 pos[1]=[5.9 -2.1 5.0] dr=1.28 t=0.0ps kin=1.55 pot=21.57 Rg=11.604 SPS=16517
# bl=0 pos[1]=[5.3 -1.6 4.6] dr=1.24 t=0.0ps kin=1.47 pot=21.61 Rg=11.584 SPS=18408
# bl=0 pos[1]=[5.8 -1.6 4.3] dr=1.25 t=0.0ps kin=1.50 pot=21.61 Rg=11.533 SPS=16857
# bl=0 pos[1]=[5.8 -3.1 4.7] dr=1.23 t=0.0ps kin=1.49 pot=21.58 Rg=11.466 SPS=16338
# bl=0 pos[1]=[4.7 -4.5 5.1] dr=1.26 t=0.0ps kin=1.51 pot=21.59 Rg=11.453 SPS=16244
# bl=0 pos[1]=[5.9 -4.5 4.2] dr=1.26 t=0.0ps kin=1.50 pot=21.65 Rg=11.472 SPS=16485
# bl=0 pos[1]=[7.1 -3.8 4.2] dr=1.27 t=0.0ps kin=1.54 pot=21.57 Rg=11.509 SPS=16676
# bl=0 pos[1]=[6.7 -4.5 3.7] dr=1.27 t=0.0ps kin=1.54 pot=21.60 Rg=11.541 SPS=16826
# bl=0 pos[1]=[8.2 -4.7 3.4] dr=1.26 t=0.0ps kin=1.53 pot=21.60 Rg=11.552 SPS=17268
# bl=0 pos[1]=[8.9 -3.6 5.4] dr=1.27 t=0.0ps kin=1.51 pot=21.67 Rg=11.544 SPS=17787
# bl=0 pos[1]=[9.9 -3.5 5.8] dr=1.22 t=0.0ps kin=1.51 pot=21.61 Rg=11.574 SPS=16520
# bl=0 pos[1]=[11.4 -3.9 5.1] dr=1.24 t=0.0ps kin=1.51 pot=21.61 Rg=11.581 SPS=16782
# bl=0 pos[1]=[12.1 -6.2 3.7] dr=1.23 t=0.0ps kin=1.51 pot=21.60 Rg=11.595 SPS=16739
# bl=0 pos[1]=[10.7 -7.9 2.7] dr=1.23 t=0.0ps kin=1.51 pot=21.61 Rg=11.640 SPS=16580
# bl=0 pos[1]=[10.5 -7.9 0.6] dr=1.23 t=0.0ps kin=1.45 pot=21.63 Rg=11.646 SPS=16785
# bl=0 pos[1]=[11.7 -8.2 1.1] dr=1.22 t=0.0ps kin=1.41 pot=21.57 Rg=11.652 SPS=17639
# bl=0 pos[1]=[11.0 -7.2 0.9] dr=1.25 t=0.0ps kin=1.46 pot=21.60 Rg=11.617 SPS=18905
# bl=0 pos[1]=[10.0 -8.3 0.2] dr=1.27 t=0.0ps kin=1.49 pot=21.58 Rg=11.583 SPS=16673
# bl=0 pos[1]=[10.1 -8.0 0.3] dr=1.30 t=0.0ps kin=1.54 pot=21.59 Rg=11.595 SPS=17079
# bl=0 pos[1]=[12.3 -7.9 0.4] dr=1.27 t=0.0ps kin=1.61 pot=21.56 Rg=11.592 SPS=16317
# bl=0 pos[1]=[12.9 -7.9 1.7] dr=1.28 t=0.0ps kin=1.52 pot=21.65 Rg=11.593 SPS=16587
# bl=0 pos[1]=[12.5 -7.2 1.8] dr=1.28 t=0.0ps kin=1.51 pot=21.61 Rg=11.606 SPS=16769
# bl=0 pos[1]=[10.9 -5.4 1.7] dr=1.28 t=0.0ps kin=1.54 pot=21.59 Rg=11.642 SPS=17943
# bl=0 pos[1]=[11.1 -5.5 2.5] dr=1.28 t=0.0ps kin=1.52 pot=21.57 Rg=11.723 SPS=16833
# bl=0 pos[1]=[12.2 -4.2 3.5] dr=1.29 t=0.0ps kin=1.54 pot=21.63 Rg=11.745 SPS=12329
# bl=0 pos[1]=[14.5 -3.6 4.8] dr=1.28 t=0.0ps kin=1.53 pot=21.60 Rg=11.763 SPS=16180
# bl=0 pos[1]=[16.6 -3.2 5.9] dr=1.25 t=0.0ps kin=1.51 pot=21.63 Rg=11.822 SPS=18263
# bl=0 pos[1]=[16.2 -1.8 5.0] dr=1.24 t=0.0ps kin=1.47 pot=21.63 Rg=11.867 SPS=17584
# bl=0 pos[1]=[16.9 -2.0 3.7] dr=1.26 t=0.0ps kin=1.49 pot=21.62 Rg=11.842 SPS=16306
# bl=0 pos[1]=[15.2 -2.9 4.3] dr=1.27 t=0.0ps kin=1.46 pot=21.61 Rg=11.826 SPS=16842
# bl=0 pos[1]=[14.5 -2.8 5.9] dr=1.26 t=0.0ps kin=1.53 pot=21.61 Rg=11.835 SPS=16797
# bl=0 pos[1]=[15.9 -2.4 4.7] dr=1.26 t=0.0ps kin=1.49 pot=21.61 Rg=11.812 SPS=17062
# bl=0 pos[1]=[16.7 -1.9 4.3] dr=1.24 t=0.0ps kin=1.47 pot=21.57 Rg=11.788 SPS=16663
# bl=0 pos[1]=[17.3 -3.2 4.9] dr=1.26 t=0.0ps kin=1.47 pot=21.61 Rg=11.742 SPS=17722
# bl=0 pos[1]=[15.5 -4.0 5.2] dr=1.28 t=0.0ps kin=1.47 pot=21.64 Rg=11.690 SPS=17244
# bl=0 pos[1]=[15.4 -3.6 5.6] dr=1.27 t=0.0ps kin=1.50 pot=21.55 Rg=11.661 SPS=16544
# bl=0 pos[1]=[15.8 -4.9 5.8] dr=1.24 t=0.0ps kin=1.47 pot=21.59 Rg=11.633 SPS=16575
# bl=0 pos[1]=[15.7 -5.6 7.1] dr=1.24 t=0.0ps kin=1.48 pot=21.56 Rg=11.638 SPS=16739
# bl=0 pos[1]=[16.7 -5.4 6.5] dr=1.25 t=0.0ps kin=1.48 pot=21.52 Rg=11.652 SPS=16375
# bl=0 pos[1]=[14.3 -4.5 4.6] dr=1.25 t=0.0ps kin=1.49 pot=21.50 Rg=11.631 SPS=16730
# bl=0 pos[1]=[14.1 -3.6 5.2] dr=1.26 t=0.0ps kin=1.43 pot=21.61 Rg=11.552 SPS=16644
# bl=0 pos[1]=[13.8 -5.0 4.5] dr=1.26 t=0.0ps kin=1.50 pot=21.59 Rg=11.474 SPS=17802
# bl=0 pos[1]=[13.3 -5.8 4.7] dr=1.24 t=0.0ps kin=1.50 pot=21.59 Rg=11.451 SPS=16347
# bl=0 pos[1]=[13.4 -6.5 5.3] dr=1.25 t=0.0ps kin=1.52 pot=21.62 Rg=11.387 SPS=16250
# bl=0 pos[1]=[12.4 -6.3 5.3] dr=1.25 t=0.0ps kin=1.51 pot=21.63 Rg=11.336 SPS=16356
# bl=0 pos[1]=[11.5 -4.7 6.0] dr=1.27 t=0.0ps kin=1.53 pot=21.62 Rg=11.282 SPS=16797
# bl=0 pos[1]=[11.0 -3.9 5.4] dr=1.29 t=0.0ps kin=1.49 pot=21.61 Rg=11.258 SPS=16714
# bl=0 pos[1]=[11.8 -2.5 6.5] dr=1.24 t=0.0ps kin=1.49 pot=21.59 Rg=11.283 SPS=16262
# bl=0 pos[1]=[11.2 -3.3 7.0] dr=1.20 t=0.0ps kin=1.47 pot=21.57 Rg=11.387 SPS=16457
# bl=0 pos[1]=[11.5 -4.3 7.3] dr=1.25 t=0.0ps kin=1.50 pot=21.56 Rg=11.453 SPS=17944
# bl=0 pos[1]=[11.8 -4.5 7.0] dr=1.25 t=0.0ps kin=1.46 pot=21.59 Rg=11.483 SPS=17565
# bl=0 pos[1]=[11.9 -4.9 7.1] dr=1.26 t=0.0ps kin=1.48 pot=21.58 Rg=11.482 SPS=16711
# bl=0 pos[1]=[11.1 -4.2 6.9] dr=1.22 t=0.0ps kin=1.45 pot=21.57 Rg=11.441 SPS=16738
# bl=0 pos[1]=[11.8 -4.8 7.2] dr=1.22 t=0.0ps kin=1.51 pot=21.58 Rg=11.414 SPS=16899
# bl=0 pos[1]=[10.0 -3.5 7.5] dr=1.25 t=0.0ps kin=1.53 pot=21.63 Rg=11.355 SPS=16744
# bl=0 pos[1]=[10.3 -3.3 7.0] dr=1.28 t=0.0ps kin=1.54 pot=21.58 Rg=11.328 SPS=18474
# bl=0 pos[1]=[11.4 -3.8 7.1] dr=1.24 t=0.0ps kin=1.51 pot=21.62 Rg=11.333 SPS=17282
# bl=0 pos[1]=[14.0 -3.5 7.5] dr=1.29 t=0.0ps kin=1.57 pot=21.57 Rg=11.329 SPS=16110
# bl=0 pos[1]=[14.2 -1.4 7.7] dr=1.28 t=0.0ps kin=1.45 pot=21.58 Rg=11.344 SPS=16187
# bl=0 pos[1]=[15.3 -1.7 7.0] dr=1.27 t=0.0ps kin=1.51 pot=21.58 Rg=11.381 SPS=16558
# bl=0 pos[1]=[16.1 -1.5 5.6] dr=1.27 t=0.0ps kin=1.54 pot=21.58 Rg=11.380 SPS=16524
# bl=0 pos[1]=[17.1 -1.9 5.5] dr=1.28 t=0.0ps kin=1.49 pot=21.63 Rg=11.394 SPS=16596
# bl=0 pos[1]=[16.2 -0.8 3.9] dr=1.31 t=0.0ps kin=1.48 pot=21.56 Rg=11.372 SPS=15444
# bl=0 pos[1]=[16.3 -1.9 2.8] dr=1.26 t=0.0ps kin=1.48 pot=21.54 Rg=11.333 SPS=16533
# bl=0 pos[1]=[16.5 -2.0 4.4] dr=1.27 t=0.0ps kin=1.53 pot=21.53 Rg=11.332 SPS=16945
# bl=0 pos[1]=[15.2 -1.7 4.3] dr=1.25 t=0.0ps kin=1.50 pot=21.59 Rg=11.338 SPS=17446
# bl=0 pos[1]=[13.8 -0.7 5.9] dr=1.26 t=0.0ps kin=1.52 pot=21.54 Rg=11.342 SPS=16378
# bl=0 pos[1]=[12.3 0.2 5.0] dr=1.26 t=0.0ps kin=1.55 pot=21.56 Rg=11.315 SPS=16519
# bl=0 pos[1]=[12.9 0.4 4.6] dr=1.26 t=0.0ps kin=1.54 pot=21.59 Rg=11.261 SPS=16127
# bl=0 pos[1]=[12.5 -0.8 4.7] dr=1.28 t=0.0ps kin=1.56 pot=21.56 Rg=11.173 SPS=15992
# bl=0 pos[1]=[13.3 -1.4 4.1] dr=1.29 t=0.0ps kin=1.48 pot=21.61 Rg=11.130 SPS=16048
# bl=0 pos[1]=[14.1 -2.5 2.6] dr=1.26 t=0.0ps kin=1.50 pot=21.60 Rg=11.146 SPS=16184
# bl=0 pos[1]=[13.8 -2.0 3.4] dr=1.27 t=0.0ps kin=1.50 pot=21.55 Rg=11.158 SPS=16255
# bl=0 pos[1]=[13.0 -2.1 2.4] dr=1.26 t=0.0ps kin=1.50 pot=21.60 Rg=11.193 SPS=16304
# bl=0 pos[1]=[13.4 -2.2 2.9] dr=1.29 t=0.0ps kin=1.51 pot=21.58 Rg=11.233 SPS=16250
# bl=0 pos[1]=[15.0 -3.2 1.7] dr=1.27 t=0.0ps kin=1.54 pot=21.55 Rg=11.267 SPS=18054
# bl=0 pos[1]=[13.4 -3.4 2.0] dr=1.25 t=0.0ps kin=1.56 pot=21.63 Rg=11.262 SPS=16725
# bl=0 pos[1]=[13.3 -2.6 2.3] dr=1.27 t=0.0ps kin=1.55 pot=21.62 Rg=11.212 SPS=16049
# bl=0 pos[1]=[13.1 -2.8 1.8] dr=1.24 t=0.0ps kin=1.55 pot=21.61 Rg=11.158 SPS=16231
# bl=0 pos[1]=[12.7 -4.0 1.3] dr=1.26 t=0.0ps kin=1.49 pot=21.64 Rg=11.099 SPS=16049
# bl=0 pos[1]=[13.3 -4.8 1.2] dr=1.25 t=0.0ps kin=1.52 pot=21.58 Rg=11.022 SPS=16326
# bl=0 pos[1]=[13.1 -6.2 1.7] dr=1.26 t=0.0ps kin=1.55 pot=21.55 Rg=10.987 SPS=16458
# bl=0 pos[1]=[12.8 -5.9 2.2] dr=1.24 t=0.0ps kin=1.48 pot=21.57 Rg=10.986 SPS=16192
# bl=0 pos[1]=[9.8 -3.8 2.6] dr=1.25 t=0.0ps kin=1.48 pot=21.55 Rg=10.997 SPS=16084
# bl=0 pos[1]=[9.8 -3.6 3.3] dr=1.23 t=0.0ps kin=1.42 pot=21.57 Rg=11.020 SPS=16146
# bl=0 pos[1]=[10.2 -3.5 1.6] dr=1.24 t=0.0ps kin=1.52 pot=21.55 Rg=10.999 SPS=15982
# bl=0 pos[1]=[10.5 -4.0 2.3] dr=1.24 t=0.0ps kin=1.50 pot=21.58 Rg=11.030 SPS=16074
# bl=0 pos[1]=[11.6 -4.0 2.2] dr=1.26 t=0.0ps kin=1.54 pot=21.59 Rg=11.061 SPS=15848
# bl=0 pos[1]=[12.8 -2.9 3.0] dr=1.25 t=0.0ps kin=1.54 pot=21.58 Rg=11.032 SPS=16664
# bl=0 pos[1]=[14.1 -0.9 3.3] dr=1.25 t=0.0ps kin=1.49 pot=21.60 Rg=10.994 SPS=16629
# bl=0 pos[1]=[15.1 -0.5 3.2] dr=1.23 t=0.0ps kin=1.51 pot=21.58 Rg=10.949 SPS=16758
# bl=0 pos[1]=[14.9 2.3 3.0] dr=1.23 t=0.0ps kin=1.47 pot=21.61 Rg=10.939 SPS=15936
# bl=0 pos[1]=[13.3 4.3 0.7] dr=1.27 t=0.0ps kin=1.47 pot=21.60 Rg=10.923 SPS=16333
# bl=0 pos[1]=[12.9 3.9 -0.8] dr=1.30 t=0.0ps kin=1.49 pot=21.54 Rg=10.924 SPS=16001
# bl=0 pos[1]=[14.0 3.8 -1.0] dr=1.27 t=0.0ps kin=1.47 pot=21.56 Rg=10.942 SPS=16394
# bl=0 pos[1]=[13.8 1.9 -0.8] dr=1.27 t=0.0ps kin=1.48 pot=21.55 Rg=10.912 SPS=16349
# bl=0 pos[1]=[13.3 0.7 -0.3] dr=1.26 t=0.0ps kin=1.47 pot=21.60 Rg=10.871 SPS=15731
# bl=0 pos[1]=[11.9 0.4 0.6] dr=1.26 t=0.0ps kin=1.49 pot=21.63 Rg=10.851 SPS=16615
# bl=0 pos[1]=[12.5 0.5 1.8] dr=1.25 t=0.0ps kin=1.57 pot=21.60 Rg=10.870 SPS=16193
# bl=0 pos[1]=[12.0 -0.2 2.8] dr=1.28 t=0.0ps kin=1.57 pot=21.61 Rg=10.835 SPS=16306
# bl=0 pos[1]=[11.5 0.2 3.4] dr=1.25 t=0.0ps kin=1.52 pot=21.62 Rg=10.801 SPS=16007
# bl=0 pos[1]=[12.5 -0.3 2.8] dr=1.28 t=0.0ps kin=1.53 pot=21.59 Rg=10.784 SPS=15913
# bl=0 pos[1]=[12.4 -0.1 3.0] dr=1.28 t=0.0ps kin=1.56 pot=21.56 Rg=10.787 SPS=15658
# bl=0 pos[1]=[12.1 -0.3 1.6] dr=1.25 t=0.0ps kin=1.47 pot=21.59 Rg=10.788 SPS=15941
# bl=0 pos[1]=[10.9 0.0 0.8] dr=1.24 t=0.0ps kin=1.48 pot=21.59 Rg=10.764 SPS=16110
# bl=0 pos[1]=[11.8 0.1 1.0] dr=1.23 t=0.0ps kin=1.50 pot=21.58 Rg=10.759 SPS=16496
# bl=0 pos[1]=[11.9 0.3 2.5] dr=1.22 t=0.0ps kin=1.48 pot=21.57 Rg=10.785 SPS=16856
# bl=0 pos[1]=[13.0 1.9 1.3] dr=1.22 t=0.0ps kin=1.51 pot=21.59 Rg=10.846 SPS=16824
# bl=0 pos[1]=[14.0 2.7 0.0] dr=1.27 t=0.0ps kin=1.53 pot=21.59 Rg=10.913 SPS=16259
# bl=0 pos[1]=[14.7 3.9 0.6] dr=1.25 t=0.0ps kin=1.47 pot=21.55 Rg=10.989 SPS=16325
# bl=0 pos[1]=[13.0 4.6 -0.9] dr=1.27 t=0.0ps kin=1.48 pot=21.57 Rg=11.109 SPS=16202
# bl=0 pos[1]=[11.8 4.1 0.5] dr=1.23 t=0.0ps kin=1.49 pot=21.56 Rg=11.165 SPS=16656
# bl=0 pos[1]=[10.5 5.9 0.9] dr=1.24 t=0.0ps kin=1.46 pot=21.59 Rg=11.164 SPS=16864
# bl=0 pos[1]=[9.9 7.2 2.1] dr=1.28 t=0.0ps kin=1.49 pot=21.57 Rg=11.165 SPS=16498
# bl=0 pos[1]=[11.7 9.5 5.5] dr=1.25 t=0.0ps kin=1.45 pot=21.59 Rg=11.149 SPS=17254
# bl=0 pos[1]=[13.7 10.2 5.5] dr=1.23 t=0.0ps kin=1.44 pot=21.55 Rg=11.159 SPS=17322
# bl=0 pos[1]=[12.9 9.3 6.9] dr=1.26 t=0.0ps kin=1.47 pot=21.55 Rg=11.197 SPS=16832
# bl=0 pos[1]=[13.3 11.0 9.5] dr=1.29 t=0.0ps kin=1.52 pot=21.54 Rg=11.253 SPS=16496
# bl=0 pos[1]=[12.4 11.8 10.7] dr=1.27 t=0.0ps kin=1.47 pot=21.57 Rg=11.308 SPS=16432
# bl=0 pos[1]=[12.3 13.0 11.5] dr=1.26 t=0.0ps kin=1.45 pot=21.56 Rg=11.321 SPS=16980
# bl=0 pos[1]=[11.6 11.0 10.6] dr=1.24 t=0.0ps kin=1.46 pot=21.54 Rg=11.299 SPS=15791
# bl=0 pos[1]=[11.1 11.0 7.2] dr=1.25 t=0.0ps kin=1.52 pot=21.55 Rg=11.251 SPS=16168
# bl=0 pos[1]=[10.8 11.0 5.2] dr=1.28 t=0.0ps kin=1.51 pot=21.59 Rg=11.233 SPS=16321
# bl=0 pos[1]=[12.0 10.6 4.6] dr=1.28 t=0.0ps kin=1.49 pot=21.58 Rg=11.226 SPS=16878
# bl=0 pos[1]=[13.2 10.1 4.7] dr=1.30 t=0.0ps kin=1.45 pot=21.62 Rg=11.220 SPS=17477
# bl=0 pos[1]=[13.8 9.7 6.1] dr=1.26 t=0.0ps kin=1.45 pot=21.62 Rg=11.252 SPS=16176
# bl=0 pos[1]=[14.1 10.2 6.0] dr=1.20 t=0.0ps kin=1.44 pot=21.62 Rg=11.276 SPS=15670
# bl=0 pos[1]=[16.0 11.3 6.6] dr=1.23 t=0.0ps kin=1.49 pot=21.60 Rg=11.262 SPS=16378
# bl=0 pos[1]=[16.9 12.4 7.9] dr=1.24 t=0.0ps kin=1.54 pot=21.59 Rg=11.244 SPS=16564
# bl=0 pos[1]=[17.0 11.7 8.2] dr=1.25 t=0.0ps kin=1.57 pot=21.60 Rg=11.252 SPS=16449
# bl=0 pos[1]=[15.3 12.4 7.8] dr=1.31 t=0.0ps kin=1.55 pot=21.60 Rg=11.266 SPS=15641
# bl=0 pos[1]=[16.3 11.2 7.7] dr=1.26 t=0.0ps kin=1.51 pot=21.62 Rg=11.264 SPS=16257
# bl=0 pos[1]=[16.8 9.5 6.7] dr=1.22 t=0.0ps kin=1.44 pot=21.62 Rg=11.281 SPS=16345
# bl=0 pos[1]=[16.3 10.5 7.1] dr=1.24 t=0.0ps kin=1.49 pot=21.54 Rg=11.281 SPS=16570
# bl=0 pos[1]=[14.7 10.4 8.8] dr=1.26 t=0.0ps kin=1.53 pot=21.54 Rg=11.273 SPS=16268
# bl=0 pos[1]=[14.1 8.8 9.6] dr=1.27 t=0.0ps kin=1.47 pot=21.54 Rg=11.282 SPS=17151
# bl=0 pos[1]=[14.8 9.2 8.5] dr=1.29 t=0.0ps kin=1.51 pot=21.55 Rg=11.283 SPS=17305
# bl=0 pos[1]=[15.7 8.5 7.4] dr=1.27 t=0.0ps kin=1.48 pot=21.55 Rg=11.302 SPS=16737
# bl=0 pos[1]=[15.1 7.6 7.9] dr=1.27 t=0.0ps kin=1.48 pot=21.60 Rg=11.288 SPS=16367
# bl=0 pos[1]=[14.9 5.2 8.7] dr=1.28 t=0.0ps kin=1.50 pot=21.60 Rg=11.281 SPS=16496
# bl=0 pos[1]=[15.1 4.2 7.8] dr=1.26 t=0.0ps kin=1.54 pot=21.60 Rg=11.301 SPS=16556
# bl=0 pos[1]=[14.3 4.1 6.4] dr=1.25 t=0.0ps kin=1.52 pot=21.57 Rg=11.291 SPS=16427
# bl=0 pos[1]=[13.0 4.1 5.3] dr=1.26 t=0.0ps kin=1.48 pot=21.57 Rg=11.292 SPS=16524
# bl=0 pos[1]=[13.6 5.3 6.6] dr=1.24 t=0.0ps kin=1.49 pot=21.59 Rg=11.301 SPS=16918
# bl=0 pos[1]=[13.5 5.3 8.0] dr=1.24 t=0.0ps kin=1.50 pot=21.58 Rg=11.291 SPS=17532
# bl=0 pos[1]=[13.8 5.0 6.4] dr=1.27 t=0.0ps kin=1.54 pot=21.60 Rg=11.315 SPS=16955
# bl=0 pos[1]=[14.7 5.1 6.2] dr=1.26 t=0.0ps kin=1.51 pot=21.58 Rg=11.358 SPS=16167
# bl=0 pos[1]=[13.4 5.7 4.3] dr=1.25 t=0.0ps kin=1.48 pot=21.61 Rg=11.394 SPS=16322
# bl=0 pos[1]=[11.4 7.7 3.9] dr=1.26 t=0.0ps kin=1.48 pot=21.58 Rg=11.416 SPS=16125
# bl=0 pos[1]=[11.2 10.5 4.0] dr=1.29 t=0.0ps kin=1.48 pot=21.57 Rg=11.443 SPS=16674
# bl=0 pos[1]=[11.5 11.1 5.6] dr=1.23 t=0.0ps kin=1.47 pot=21.59 Rg=11.507 SPS=16942
# bl=0 pos[1]=[13.6 11.8 5.4] dr=1.28 t=0.0ps kin=1.51 pot=21.54 Rg=11.551 SPS=16488
# bl=0 pos[1]=[13.9 11.6 6.9] dr=1.24 t=0.0ps kin=1.45 pot=21.62 Rg=11.576 SPS=16194
# bl=0 pos[1]=[13.0 12.3 8.1] dr=1.26 t=0.0ps kin=1.46 pot=21.64 Rg=11.584 SPS=17045
# bl=0 pos[1]=[14.1 13.0 8.7] dr=1.26 t=0.0ps kin=1.50 pot=21.56 Rg=11.624 SPS=17653
# bl=0 pos[1]=[14.1 13.4 8.4] dr=1.27 t=0.0ps kin=1.48 pot=21.55 Rg=11.661 SPS=16450
# bl=0 pos[1]=[12.5 13.7 8.6] dr=1.27 t=0.0ps kin=1.55 pot=21.60 Rg=11.712 SPS=16392
# bl=0 pos[1]=[11.3 13.8 8.1] dr=1.28 t=0.0ps kin=1.54 pot=21.63 Rg=11.746 SPS=16275
# bl=0 pos[1]=[11.8 12.0 9.0] dr=1.27 t=0.0ps kin=1.53 pot=21.61 Rg=11.791 SPS=16138
# bl=0 pos[1]=[11.1 13.5 10.9] dr=1.26 t=0.0ps kin=1.52 pot=21.56 Rg=11.831 SPS=16262
# bl=0 pos[1]=[10.9 16.0 11.6] dr=1.27 t=0.0ps kin=1.49 pot=21.58 Rg=11.823 SPS=16131
# bl=0 pos[1]=[11.8 16.7 10.8] dr=1.29 t=0.0ps kin=1.56 pot=21.57 Rg=11.797 SPS=15868
# bl=0 pos[1]=[12.1 15.0 10.3] dr=1.30 t=0.0ps kin=1.46 pot=21.59 Rg=11.767 SPS=16220
# bl=0 pos[1]=[12.7 15.1 10.7] dr=1.29 t=0.0ps kin=1.48 pot=21.60 Rg=11.752 SPS=17082
# bl=0 pos[1]=[10.8 15.5 10.5] dr=1.27 t=0.0ps kin=1.50 pot=21.58 Rg=11.774 SPS=16641
# bl=0 pos[1]=[9.4 14.4 10.6] dr=1.27 t=0.0ps kin=1.48 pot=21.60 Rg=11.755 SPS=17460
# bl=0 pos[1]=[8.4 12.9 11.4] dr=1.24 t=0.0ps kin=1.49 pot=21.59 Rg=11.725 SPS=17060
# bl=0 pos[1]=[10.3 12.8 12.0] dr=1.26 t=0.0ps kin=1.48 pot=21.59 Rg=11.724 SPS=16163
# bl=0 pos[1]=[11.6 13.2 11.4] dr=1.24 t=0.0ps kin=1.48 pot=21.55 Rg=11.700 SPS=16551
# bl=0 pos[1]=[11.9 11.4 10.6] dr=1.27 t=0.0ps kin=1.47 pot=21.59 Rg=11.625 SPS=16669
# bl=0 pos[1]=[10.9 10.9 11.0] dr=1.26 t=0.0ps kin=1.48 pot=21.61 Rg=11.575 SPS=16131
# bl=0 pos[1]=[10.6 9.2 12.1] dr=1.24 t=0.0ps kin=1.47 pot=21.58 Rg=11.550 SPS=16818
# bl=0 pos[1]=[9.9 8.2 10.0] dr=1.29 t=0.0ps kin=1.50 pot=21.58 Rg=11.559 SPS=16289
# bl=0 pos[1]=[8.4 8.9 10.0] dr=1.31 t=0.0ps kin=1.49 pot=21.59 Rg=11.554 SPS=18223
# bl=0 pos[1]=[8.6 9.8 10.6] dr=1.31 t=0.0ps kin=1.53 pot=21.57 Rg=11.541 SPS=16659
# bl=0 pos[1]=[8.0 8.7 10.1] dr=1.29 t=0.0ps kin=1.50 pot=21.58 Rg=11.548 SPS=16201
# bl=0 pos[1]=[8.1 6.3 8.8] dr=1.29 t=0.0ps kin=1.51 pot=21.57 Rg=11.551 SPS=16482
# bl=0 pos[1]=[7.4 7.5 8.7] dr=1.26 t=0.0ps kin=1.48 pot=21.61 Rg=11.510 SPS=16316
# bl=0 pos[1]=[6.5 8.5 8.9] dr=1.27 t=0.0ps kin=1.52 pot=21.60 Rg=11.469 SPS=16398
# bl=0 pos[1]=[5.9 10.0 8.2] dr=1.24 t=0.0ps kin=1.53 pot=21.57 Rg=11.437 SPS=16368
# bl=0 pos[1]=[4.1 10.0 8.3] dr=1.30 t=0.0ps kin=1.47 pot=21.57 Rg=11.410 SPS=15802
# bl=0 pos[1]=[4.0 9.5 9.2] dr=1.25 t=0.0ps kin=1.44 pot=21.53 Rg=11.397 SPS=14993
# bl=0 pos[1]=[3.3 10.6 9.6] dr=1.23 t=0.0ps kin=1.45 pot=21.53 Rg=11.464 SPS=16247
# bl=0 pos[1]=[3.1 10.8 9.4] dr=1.27 t=0.0ps kin=1.46 pot=21.58 Rg=11.525 SPS=14516
# bl=0 pos[1]=[4.8 10.0 11.0] dr=1.27 t=0.0ps kin=1.52 pot=21.55 Rg=11.555 SPS=14960
# bl=0 pos[1]=[7.6 10.0 11.5] dr=1.28 t=0.0ps kin=1.52 pot=21.57 Rg=11.590 SPS=10228
# bl=0 pos[1]=[8.2 8.4 10.9] dr=1.26 t=0.0ps kin=1.47 pot=21.59 Rg=11.598 SPS=15114
# bl=0 pos[1]=[9.0 9.3 9.7] dr=1.27 t=0.0ps kin=1.46 pot=21.59 Rg=11.608 SPS=14979
# bl=0 pos[1]=[8.3 10.3 9.3] dr=1.26 t=0.0ps kin=1.43 pot=21.60 Rg=11.614 SPS=14299
# bl=0 pos[1]=[8.5 11.7 8.6] dr=1.25 t=0.0ps kin=1.45 pot=21.60 Rg=11.590 SPS=15685
# bl=0 pos[1]=[6.4 13.1 8.5] dr=1.27 t=0.0ps kin=1.57 pot=21.54 Rg=11.539 SPS=16859
# bl=0 pos[1]=[7.4 12.9 7.4] dr=1.23 t=0.0ps kin=1.51 pot=21.56 Rg=11.455 SPS=16353
# bl=0 pos[1]=[8.1 12.8 7.7] dr=1.21 t=0.0ps kin=1.43 pot=21.64 Rg=11.441 SPS=14292
# bl=0 pos[1]=[9.2 12.3 8.3] dr=1.23 t=0.0ps kin=1.55 pot=21.58 Rg=11.438 SPS=14465
# bl=0 pos[1]=[9.2 12.7 9.6] dr=1.26 t=0.0ps kin=1.56 pot=21.60 Rg=11.412 SPS=15143
# bl=0 pos[1]=[7.0 12.4 11.2] dr=1.27 t=0.0ps kin=1.56 pot=21.61 Rg=11.366 SPS=14816
# bl=0 pos[1]=[4.4 13.0 10.1] dr=1.25 t=0.0ps kin=1.49 pot=21.64 Rg=11.374 SPS=14805
# bl=0 pos[1]=[4.0 11.1 9.0] dr=1.23 t=0.0ps kin=1.48 pot=21.60 Rg=11.420 SPS=14475
# bl=0 pos[1]=[3.1 11.8 6.8] dr=1.25 t=0.0ps kin=1.48 pot=21.53 Rg=11.430 SPS=16150
# bl=0 pos[1]=[4.7 12.7 5.6] dr=1.24 t=0.0ps kin=1.50 pot=21.60 Rg=11.404 SPS=16209
# bl=0 pos[1]=[4.4 12.1 5.9] dr=1.27 t=0.0ps kin=1.50 pot=21.61 Rg=11.373 SPS=15178
# bl=0 pos[1]=[5.7 11.8 5.9] dr=1.23 t=0.0ps kin=1.52 pot=21.61 Rg=11.333 SPS=14092
# bl=0 pos[1]=[6.6 10.7 5.1] dr=1.21 t=0.0ps kin=1.50 pot=21.62 Rg=11.312 SPS=13835
# bl=0 pos[1]=[6.3 9.6 4.9] dr=1.25 t=0.0ps kin=1.54 pot=21.59 Rg=11.275 SPS=14253
# bl=0 pos[1]=[5.4 7.8 4.7] dr=1.26 t=0.0ps kin=1.52 pot=21.59 Rg=11.302 SPS=15126
# bl=0 pos[1]=[4.3 8.0 3.6] dr=1.26 t=0.0ps kin=1.52 pot=21.59 Rg=11.332 SPS=15077
# bl=0 pos[1]=[5.1 9.2 3.3] dr=1.27 t=0.0ps kin=1.51 pot=21.59 Rg=11.344 SPS=15039
# bl=0 pos[1]=[4.4 10.4 1.6] dr=1.25 t=0.0ps kin=1.49 pot=21.61 Rg=11.356 SPS=15054
# bl=0 pos[1]=[5.1 10.2 -0.0] dr=1.27 t=0.0ps kin=1.50 pot=21.58 Rg=11.346 SPS=15355
# bl=0 pos[1]=[6.9 8.6 -0.6] dr=1.24 t=0.0ps kin=1.46 pot=21.61 Rg=11.311 SPS=15781
# bl=0 pos[1]=[7.8 8.6 0.7] dr=1.25 t=0.0ps kin=1.48 pot=21.57 Rg=11.260 SPS=16517
# bl=0 pos[1]=[8.9 10.4 1.7] dr=1.24 t=0.0ps kin=1.48 pot=21.58 Rg=11.209 SPS=16147
# bl=0 pos[1]=[6.9 10.2 3.9] dr=1.24 t=0.0ps kin=1.47 pot=21.59 Rg=11.195 SPS=16159
# bl=0 pos[1]=[5.2 7.9 4.3] dr=1.20 t=0.0ps kin=1.51 pot=21.62 Rg=11.161 SPS=15964
# bl=0 pos[1]=[5.4 6.1 3.7] dr=1.25 t=0.0ps kin=1.54 pot=21.57 Rg=11.180 SPS=14559
# bl=0 pos[1]=[6.3 6.0 1.9] dr=1.24 t=0.0ps kin=1.50 pot=21.58 Rg=11.194 SPS=14506
# bl=0 pos[1]=[4.9 5.6 1.5] dr=1.28 t=0.0ps kin=1.52 pot=21.58 Rg=11.198 SPS=14714
# bl=0 pos[1]=[4.8 5.5 -0.5] dr=1.25 t=0.0ps kin=1.51 pot=21.59 Rg=11.176 SPS=12728
# bl=0 pos[1]=[3.8 5.8 0.2] dr=1.25 t=0.0ps kin=1.50 pot=21.59 Rg=11.178 SPS=13490
# bl=0 pos[1]=[4.0 5.9 -0.7] dr=1.26 t=0.0ps kin=1.47 pot=21.53 Rg=11.194 SPS=14073
# bl=0 pos[1]=[4.5 5.6 -0.5] dr=1.27 t=0.0ps kin=1.49 pot=21.57 Rg=11.182 SPS=13291
# bl=0 pos[1]=[5.1 4.0 -0.1] dr=1.27 t=0.0ps kin=1.55 pot=21.55 Rg=11.192 SPS=15026
# bl=0 pos[1]=[7.0 2.0 0.3] dr=1.23 t=0.0ps kin=1.46 pot=21.56 Rg=11.186 SPS=15051
# bl=0 pos[1]=[7.0 3.1 1.4] dr=1.22 t=0.0ps kin=1.44 pot=21.57 Rg=11.173 SPS=14971
# bl=0 pos[1]=[8.0 5.6 1.7] dr=1.23 t=0.0ps kin=1.48 pot=21.56 Rg=11.188 SPS=14666
# bl=0 pos[1]=[8.3 6.0 2.5] dr=1.25 t=0.0ps kin=1.41 pot=21.57 Rg=11.225 SPS=14518
# bl=0 pos[1]=[11.1 6.9 3.1] dr=1.24 t=0.0ps kin=1.46 pot=21.54 Rg=11.263 SPS=15538
# bl=0 pos[1]=[11.6 6.1 2.8] dr=1.25 t=0.0ps kin=1.47 pot=21.51 Rg=11.341 SPS=15859
# bl=0 pos[1]=[11.8 5.9 3.0] dr=1.25 t=0.0ps kin=1.42 pot=21.56 Rg=11.384 SPS=16418
# bl=0 pos[1]=[11.5 5.1 2.5] dr=1.22 t=0.0ps kin=1.45 pot=21.53 Rg=11.409 SPS=16702
# bl=0 pos[1]=[9.9 5.1 0.9] dr=1.27 t=0.0ps kin=1.47 pot=21.58 Rg=11.466 SPS=16072
# bl=0 pos[1]=[10.0 6.6 2.7] dr=1.27 t=0.0ps kin=1.46 pot=21.55 Rg=11.486 SPS=15287
# bl=0 pos[1]=[8.8 5.9 4.1] dr=1.22 t=0.0ps kin=1.47 pot=21.57 Rg=11.537 SPS=15319
# bl=0 pos[1]=[7.1 6.5 5.6] dr=1.27 t=0.0ps kin=1.56 pot=21.59 Rg=11.579 SPS=15286
# bl=0 pos[1]=[7.5 5.7 6.8] dr=1.29 t=0.0ps kin=1.54 pot=21.57 Rg=11.638 SPS=14949
# bl=0 pos[1]=[7.8 4.1 5.6] dr=1.25 t=0.0ps kin=1.50 pot=21.62 Rg=11.716 SPS=15375
# bl=0 pos[1]=[9.4 4.4 3.9] dr=1.24 t=0.0ps kin=1.51 pot=21.57 Rg=11.770 SPS=15227
# bl=0 pos[1]=[9.7 5.9 4.1] dr=1.25 t=0.0ps kin=1.52 pot=21.60 Rg=11.815 SPS=14986
# bl=0 pos[1]=[10.6 8.1 3.1] dr=1.30 t=0.0ps kin=1.58 pot=21.60 Rg=11.825 SPS=15490
# bl=0 pos[1]=[11.5 9.6 3.8] dr=1.28 t=0.0ps kin=1.52 pot=21.58 Rg=11.821 SPS=15717
# bl=0 pos[1]=[12.1 10.8 4.7] dr=1.29 t=0.0ps kin=1.49 pot=21.58 Rg=11.802 SPS=14601
# bl=0 pos[1]=[12.4 10.2 5.6] dr=1.26 t=0.0ps kin=1.49 pot=21.59 Rg=11.826 SPS=15674
# bl=0 pos[1]=[11.0 9.9 8.7] dr=1.28 t=0.0ps kin=1.48 pot=21.54 Rg=11.819 SPS=14775
# bl=0 pos[1]=[9.8 9.4 8.0] dr=1.26 t=0.0ps kin=1.48 pot=21.55 Rg=11.791 SPS=16302
# bl=0 pos[1]=[11.5 7.8 8.2] dr=1.25 t=0.0ps kin=1.44 pot=21.56 Rg=11.715 SPS=17843
# bl=0 pos[1]=[12.3 7.6 8.9] dr=1.22 t=0.0ps kin=1.45 pot=21.56 Rg=11.634 SPS=16554
# bl=0 pos[1]=[12.7 9.0 9.5] dr=1.23 t=0.0ps kin=1.47 pot=21.60 Rg=11.587 SPS=16282
# bl=0 pos[1]=[14.2 9.1 8.5] dr=1.26 t=0.0ps kin=1.55 pot=21.58 Rg=11.589 SPS=15760
# bl=0 pos[1]=[15.8 6.8 7.5] dr=1.28 t=0.0ps kin=1.54 pot=21.65 Rg=11.586 SPS=16480
# bl=0 pos[1]=[15.6 7.3 6.4] dr=1.27 t=0.0ps kin=1.53 pot=21.59 Rg=11.584 SPS=16643
# bl=0 pos[1]=[16.0 9.1 6.3] dr=1.24 t=0.0ps kin=1.49 pot=21.62 Rg=11.602 SPS=16618
# bl=0 pos[1]=[15.8 10.2 7.0] dr=1.23 t=0.0ps kin=1.47 pot=21.67 Rg=11.551 SPS=15702
# bl=0 pos[1]=[15.0 8.8 7.9] dr=1.21 t=0.0ps kin=1.48 pot=21.63 Rg=11.475 SPS=16503
# bl=0 pos[1]=[14.8 7.2 6.0] dr=1.27 t=0.0ps kin=1.55 pot=21.59 Rg=11.450 SPS=16700
# bl=0 pos[1]=[14.6 6.3 6.0] dr=1.29 t=0.0ps kin=1.55 pot=21.53 Rg=11.413 SPS=17996
# bl=0 pos[1]=[14.8 5.6 8.1] dr=1.25 t=0.0ps kin=1.46 pot=21.61 Rg=11.402 SPS=17511
# bl=0 pos[1]=[14.0 4.5 10.1] dr=1.27 t=0.0ps kin=1.51 pot=21.58 Rg=11.389 SPS=16810
# bl=0 pos[1]=[14.0 4.7 11.8] dr=1.27 t=0.0ps kin=1.48 pot=21.61 Rg=11.379 SPS=16418
# bl=0 pos[1]=[15.0 4.8 12.7] dr=1.26 t=0.0ps kin=1.47 pot=21.60 Rg=11.397 SPS=16421
# bl=0 pos[1]=[15.5 4.6 11.2] dr=1.25 t=0.0ps kin=1.45 pot=21.60 Rg=11.422 SPS=16726
# bl=0 pos[1]=[16.1 3.1 11.6] dr=1.25 t=0.0ps kin=1.48 pot=21.58 Rg=11.437 SPS=16784
# bl=0 pos[1]=[15.5 2.9 10.5] dr=1.25 t=0.0ps kin=1.52 pot=21.58 Rg=11.408 SPS=16960
# bl=0 pos[1]=[16.8 2.4 10.5] dr=1.26 t=0.0ps kin=1.50 pot=21.56 Rg=11.383 SPS=17579
# bl=0 pos[1]=[18.2 3.5 11.7] dr=1.26 t=0.0ps kin=1.48 pot=21.56 Rg=11.434 SPS=16286
# bl=0 pos[1]=[19.2 4.1 13.6] dr=1.24 t=0.0ps kin=1.46 pot=21.60 Rg=11.485 SPS=16646
# bl=0 pos[1]=[17.1 5.0 14.1] dr=1.24 t=0.0ps kin=1.55 pot=21.56 Rg=11.489 SPS=16795
# bl=0 pos[1]=[16.9 4.2 14.1] dr=1.26 t=0.0ps kin=1.53 pot=21.53 Rg=11.506 SPS=16809
# bl=0 pos[1]=[17.4 5.6 14.1] dr=1.25 t=0.0ps kin=1.45 pot=21.57 Rg=11.510 SPS=16401
# bl=0 pos[1]=[16.6 5.1 13.4] dr=1.25 t=0.0ps kin=1.49 pot=21.55 Rg=11.443 SPS=16297
# bl=0 pos[1]=[16.4 2.7 14.0] dr=1.27 t=0.0ps kin=1.42 pot=21.55 Rg=11.404 SPS=16257
# bl=0 pos[1]=[15.1 2.0 14.2] dr=1.25 t=0.0ps kin=1.45 pot=21.57 Rg=11.385 SPS=16796
# bl=0 pos[1]=[13.6 2.5 15.6] dr=1.27 t=0.0ps kin=1.52 pot=21.57 Rg=11.410 SPS=17872
# bl=0 pos[1]=[11.0 3.1 13.9] dr=1.28 t=0.0ps kin=1.53 pot=21.56 Rg=11.471 SPS=16252
# bl=0 pos[1]=[9.2 3.5 14.1] dr=1.23 t=0.0ps kin=1.49 pot=21.54 Rg=11.448 SPS=16327
# bl=0 pos[1]=[7.7 4.0 12.5] dr=1.24 t=0.0ps kin=1.50 pot=21.57 Rg=11.370 SPS=16749
# bl=0 pos[1]=[8.7 3.7 12.2] dr=1.28 t=0.0ps kin=1.48 pot=21.60 Rg=11.256 SPS=16409
# bl=0 pos[1]=[9.5 3.6 13.6] dr=1.28 t=0.0ps kin=1.53 pot=21.59 Rg=11.168 SPS=16534
# bl=0 pos[1]=[9.7 4.2 15.7] dr=1.24 t=0.0ps kin=1.42 pot=21.59 Rg=11.133 SPS=16253
# bl=0 pos[1]=[8.0 4.3 16.4] dr=1.24 t=0.0ps kin=1.46 pot=21.61 Rg=11.159 SPS=16435
# bl=0 pos[1]=[7.2 3.6 14.7] dr=1.28 t=0.0ps kin=1.49 pot=21.57 Rg=11.131 SPS=16637
# bl=0 pos[1]=[6.4 3.3 14.0] dr=1.26 t=0.0ps kin=1.51 pot=21.56 Rg=11.100 SPS=17653
# bl=0 pos[1]=[4.9 2.3 12.9] dr=1.25 t=0.0ps kin=1.49 pot=21.54 Rg=11.129 SPS=17116
# bl=0 pos[1]=[5.5 2.7 12.5] dr=1.23 t=0.0ps kin=1.48 pot=21.60 Rg=11.167 SPS=16121
# bl=0 pos[1]=[5.2 2.1 11.2] dr=1.26 t=0.0ps kin=1.53 pot=21.55 Rg=11.191 SPS=16092
# bl=0 pos[1]=[4.8 2.5 10.9] dr=1.27 t=0.0ps kin=1.53 pot=21.54 Rg=11.221 SPS=15978
# bl=0 pos[1]=[4.3 3.1 11.3] dr=1.27 t=0.0ps kin=1.52 pot=21.58 Rg=11.212 SPS=16466
# bl=0 pos[1]=[3.2 5.6 10.8] dr=1.27 t=0.0ps kin=1.50 pot=21.58 Rg=11.214 SPS=16319
# bl=0 pos[1]=[3.2 7.1 10.0] dr=1.26 t=0.0ps kin=1.49 pot=21.59 Rg=11.243 SPS=16252
# bl=0 pos[1]=[3.5 7.7 10.0] dr=1.24 t=0.0ps kin=1.46 pot=21.57 Rg=11.311 SPS=16442
# bl=0 pos[1]=[4.1 7.5 10.1] dr=1.22 t=0.0ps kin=1.49 pot=21.58 Rg=11.349 SPS=16912
# bl=0 pos[1]=[4.8 7.1 10.3] dr=1.23 t=0.0ps kin=1.50 pot=21.56 Rg=11.359 SPS=17737
# bl=0 pos[1]=[4.9 7.1 9.3] dr=1.27 t=0.0ps kin=1.56 pot=21.56 Rg=11.412 SPS=17012
# bl=0 pos[1]=[5.9 5.6 9.3] dr=1.26 t=0.0ps kin=1.53 pot=21.56 Rg=11.453 SPS=16359
# bl=0 pos[1]=[5.5 5.6 10.6] dr=1.29 t=0.0ps kin=1.50 pot=21.63 Rg=11.511 SPS=16746
# bl=0 pos[1]=[5.2 5.7 11.1] dr=1.24 t=0.0ps kin=1.52 pot=21.59 Rg=11.581 SPS=16735
# bl=0 pos[1]=[4.2 6.0 12.0] dr=1.28 t=0.0ps kin=1.49 pot=21.58 Rg=11.645 SPS=16161
# bl=0 pos[1]=[3.5 4.6 12.8] dr=1.26 t=0.0ps kin=1.48 pot=21.61 Rg=11.670 SPS=16337
# bl=0 pos[1]=[2.3 6.7 14.1] dr=1.22 t=0.0ps kin=1.48 pot=21.58 Rg=11.726 SPS=16765
# bl=0 pos[1]=[2.3 7.0 14.0] dr=1.26 t=0.0ps kin=1.50 pot=21.61 Rg=11.736 SPS=16179
# bl=0 pos[1]=[1.8 5.5 14.5] dr=1.25 t=0.0ps kin=1.51 pot=21.61 Rg=11.705 SPS=17704
# bl=0 pos[1]=[2.6 4.2 13.2] dr=1.26 t=0.0ps kin=1.49 pot=21.65 Rg=11.650 SPS=17247
# bl=0 pos[1]=[2.4 2.9 14.6] dr=1.21 t=0.0ps kin=1.49 pot=21.63 Rg=11.614 SPS=15454
# bl=0 pos[1]=[3.5 4.0 14.7] dr=1.23 t=0.0ps kin=1.48 pot=21.65 Rg=11.570 SPS=16037
# bl=0 pos[1]=[3.4 4.1 15.5] dr=1.25 t=0.0ps kin=1.52 pot=21.63 Rg=11.489 SPS=15929
# bl=0 pos[1]=[4.9 2.4 15.9] dr=1.23 t=0.0ps kin=1.48 pot=21.57 Rg=11.397 SPS=16634
# bl=0 pos[1]=[4.6 0.5 15.0] dr=1.25 t=0.0ps kin=1.45 pot=21.63 Rg=11.351 SPS=16432
# bl=0 pos[1]=[3.5 1.3 12.3] dr=1.25 t=0.0ps kin=1.53 pot=21.54 Rg=11.348 SPS=16558
# bl=0 pos[1]=[1.8 2.1 11.3] dr=1.26 t=0.0ps kin=1.48 pot=21.61 Rg=11.382 SPS=16400
# bl=0 pos[1]=[0.8 1.6 11.9] dr=1.26 t=0.0ps kin=1.53 pot=21.55 Rg=11.387 SPS=16556
# bl=0 pos[1]=[-0.9 2.0 13.3] dr=1.26 t=0.0ps kin=1.51 pot=21.56 Rg=11.357 SPS=16879
# bl=0 pos[1]=[-1.6 2.5 14.9] dr=1.23 t=0.0ps kin=1.48 pot=21.56 Rg=11.324 SPS=17526
# bl=0 pos[1]=[-1.3 3.2 17.5] dr=1.24 t=0.0ps kin=1.49 pot=21.57 Rg=11.299 SPS=16049
# bl=0 pos[1]=[-2.1 4.2 17.3] dr=1.27 t=0.0ps kin=1.49 pot=21.57 Rg=11.272 SPS=16648
# bl=0 pos[1]=[-3.3 3.7 16.1] dr=1.25 t=0.0ps kin=1.50 pot=21.59 Rg=11.230 SPS=16884
# bl=0 pos[1]=[-3.1 4.0 16.0] dr=1.27 t=0.0ps kin=1.50 pot=21.61 Rg=11.229 SPS=16429
# bl=0 pos[1]=[-2.7 2.1 15.2] dr=1.21 t=0.0ps kin=1.50 pot=21.57 Rg=11.219 SPS=16690
# bl=0 pos[1]=[-2.9 0.2 13.7] dr=1.26 t=0.0ps kin=1.50 pot=21.58 Rg=11.224 SPS=16573
# bl=0 pos[1]=[-4.7 0.6 14.6] dr=1.28 t=0.0ps kin=1.50 pot=21.56 Rg=11.249 SPS=16941
# bl=0 pos[1]=[-5.6 0.8 13.5] dr=1.26 t=0.0ps kin=1.46 pot=21.59 Rg=11.302 SPS=17891
# bl=0 pos[1]=[-6.5 0.9 12.3] dr=1.24 t=0.0ps kin=1.49 pot=21.56 Rg=11.346 SPS=16829
# bl=0 pos[1]=[-7.2 0.9 11.6] dr=1.25 t=0.0ps kin=1.51 pot=21.54 Rg=11.340 SPS=16617
# bl=0 pos[1]=[-5.7 -1.0 11.0] dr=1.23 t=0.0ps kin=1.49 pot=21.52 Rg=11.290 SPS=16811
# bl=0 pos[1]=[-4.7 -1.0 9.9] dr=1.22 t=0.0ps kin=1.42 pot=21.53 Rg=11.261 SPS=16233
# bl=0 pos[1]=[-3.8 0.0 9.2] dr=1.25 t=0.0ps kin=1.51 pot=21.53 Rg=11.299 SPS=16332
# bl=0 pos[1]=[-3.1 -0.1 8.9] dr=1.24 t=0.0ps kin=1.49 pot=21.59 Rg=11.354 SPS=16506
# bl=0 pos[1]=[-1.9 0.7 10.6] dr=1.23 t=0.0ps kin=1.46 pot=21.57 Rg=11.391 SPS=16025
# bl=0 pos[1]=[-1.1 0.1 10.4] dr=1.23 t=0.0ps kin=1.49 pot=21.62 Rg=11.425 SPS=15899
# bl=0 pos[1]=[-0.5 0.7 8.9] dr=1.24 t=0.0ps kin=1.48 pot=21.64 Rg=11.418 SPS=16469
# bl=0 pos[1]=[0.6 0.8 6.7] dr=1.25 t=0.0ps kin=1.53 pot=21.59 Rg=11.379 SPS=17319
# bl=0 pos[1]=[0.3 -0.5 6.9] dr=1.31 t=0.0ps kin=1.49 pot=21.64 Rg=11.372 SPS=16626
# bl=0 pos[1]=[-1.3 -0.4 6.9] dr=1.27 t=0.0ps kin=1.52 pot=21.60 Rg=11.388 SPS=16146
# bl=0 pos[1]=[-2.3 -1.3 7.7] dr=1.27 t=0.0ps kin=1.54 pot=21.59 Rg=11.377 SPS=16346
# bl=0 pos[1]=[-3.8 0.5 8.4] dr=1.27 t=0.0ps kin=1.49 pot=21.60 Rg=11.328 SPS=16280
# bl=0 pos[1]=[-4.6 -0.1 7.9] dr=1.28 t=0.0ps kin=1.53 pot=21.55 Rg=11.367 SPS=16132
# bl=0 pos[1]=[-4.3 -1.0 8.9] dr=1.30 t=0.0ps kin=1.58 pot=21.51 Rg=11.387 SPS=16404
# bl=0 pos[1]=[-4.6 -0.6 10.5] dr=1.30 t=0.0ps kin=1.49 pot=21.56 Rg=11.375 SPS=15822
# bl=0 pos[1]=[-4.6 1.6 11.5] dr=1.24 t=0.0ps kin=1.46 pot=21.56 Rg=11.365 SPS=16810
# bl=0 pos[1]=[-3.4 1.9 11.4] dr=1.26 t=0.0ps kin=1.44 pot=21.59 Rg=11.323 SPS=16654
# bl=0 pos[1]=[-2.8 1.5 11.2] dr=1.25 t=0.0ps kin=1.51 pot=21.55 Rg=11.303 SPS=16842
# bl=0 pos[1]=[-3.4 0.0 10.7] dr=1.27 t=0.0ps kin=1.50 pot=21.55 Rg=11.292 SPS=17321
# bl=0 pos[1]=[-1.7 1.3 11.0] dr=1.24 t=0.0ps kin=1.47 pot=21.55 Rg=11.310 SPS=16373
# bl=0 pos[1]=[-1.8 1.3 12.5] dr=1.24 t=0.0ps kin=1.46 pot=21.56 Rg=11.354 SPS=16157
# bl=0 pos[1]=[-1.8 2.3 12.5] dr=1.24 t=0.0ps kin=1.46 pot=21.58 Rg=11.343 SPS=16365
# bl=0 pos[1]=[-2.3 4.0 12.5] dr=1.22 t=0.0ps kin=1.50 pot=21.61 Rg=11.339 SPS=16361
# bl=0 pos[1]=[-3.0 5.5 12.8] dr=1.24 t=0.0ps kin=1.51 pot=21.61 Rg=11.355 SPS=16096
# bl=0 pos[1]=[-3.1 7.1 11.4] dr=1.26 t=0.0ps kin=1.55 pot=21.59 Rg=11.355 SPS=16300
# bl=0 pos[1]=[-2.9 7.7 12.2] dr=1.29 t=0.0ps kin=1.54 pot=21.61 Rg=11.334 SPS=16269
# bl=0 pos[1]=[-2.2 7.4 11.9] dr=1.25 t=0.0ps kin=1.51 pot=21.58 Rg=11.319 SPS=16405
# bl=0 pos[1]=[-0.3 7.7 11.0] dr=1.25 t=0.0ps kin=1.54 pot=21.57 Rg=11.322 SPS=16244
# bl=0 pos[1]=[-0.2 7.6 10.0] dr=1.26 t=0.0ps kin=1.52 pot=21.60 Rg=11.320 SPS=16328
# bl=0 pos[1]=[-0.1 7.4 9.1] dr=1.26 t=0.0ps kin=1.53 pot=21.57 Rg=11.321 SPS=16844
# bl=0 pos[1]=[-0.7 9.7 8.7] dr=1.24 t=0.0ps kin=1.50 pot=21.57 Rg=11.335 SPS=17317
# bl=0 pos[1]=[0.2 10.5 8.8] dr=1.25 t=0.0ps kin=1.51 pot=21.55 Rg=11.340 SPS=16925
# bl=0 pos[1]=[-0.4 11.7 11.1] dr=1.24 t=0.0ps kin=1.44 pot=21.56 Rg=11.365 SPS=16112
# bl=0 pos[1]=[-0.0 11.5 12.4] dr=1.23 t=0.0ps kin=1.46 pot=21.55 Rg=11.443 SPS=16123
# bl=0 pos[1]=[0.8 11.5 13.7] dr=1.23 t=0.0ps kin=1.48 pot=21.61 Rg=11.498 SPS=16133
# bl=0 pos[1]=[0.4 11.4 14.6] dr=1.25 t=0.0ps kin=1.53 pot=21.57 Rg=11.524 SPS=16741
# bl=0 pos[1]=[-1.2 12.1 15.1] dr=1.24 t=0.0ps kin=1.47 pot=21.57 Rg=11.502 SPS=16567
# bl=0 pos[1]=[-3.0 12.1 14.9] dr=1.24 t=0.0ps kin=1.44 pot=21.56 Rg=11.486 SPS=16564
# bl=0 pos[1]=[-3.3 10.7 15.5] dr=1.26 t=0.0ps kin=1.53 pot=21.54 Rg=11.473 SPS=16391
# bl=0 pos[1]=[-0.9 10.3 13.9] dr=1.26 t=0.0ps kin=1.49 pot=21.56 Rg=11.464 SPS=17625
# bl=0 pos[1]=[-0.1 9.1 11.5] dr=1.26 t=0.0ps kin=1.45 pot=21.59 Rg=11.468 SPS=16831
# bl=0 pos[1]=[-0.5 7.9 9.9] dr=1.24 t=0.0ps kin=1.49 pot=21.57 Rg=11.452 SPS=16028
# bl=0 pos[1]=[-0.8 8.4 9.9] dr=1.24 t=0.0ps kin=1.50 pot=21.53 Rg=11.414 SPS=16154
# bl=0 pos[1]=[0.5 8.9 8.8] dr=1.22 t=0.0ps kin=1.48 pot=21.53 Rg=11.369 SPS=16207
# bl=0 pos[1]=[0.3 9.7 9.1] dr=1.21 t=0.0ps kin=1.47 pot=21.58 Rg=11.317 SPS=16248
# bl=0 pos[1]=[-0.4 9.8 10.6] dr=1.27 t=0.0ps kin=1.49 pot=21.56 Rg=11.297 SPS=15664
# bl=0 pos[1]=[-1.3 10.9 9.9] dr=1.26 t=0.0ps kin=1.54 pot=21.60 Rg=11.279 SPS=15990
# bl=0 pos[1]=[-1.3 10.3 9.1] dr=1.25 t=0.0ps kin=1.53 pot=21.58 Rg=11.227 SPS=15865
# bl=0 pos[1]=[0.6 11.0 9.3] dr=1.24 t=0.0ps kin=1.52 pot=21.59 Rg=11.203 SPS=16127
# bl=0 pos[1]=[-0.1 10.7 10.5] dr=1.26 t=0.0ps kin=1.45 pot=21.62 Rg=11.164 SPS=16099
# bl=0 pos[1]=[0.1 8.8 9.3] dr=1.27 t=0.0ps kin=1.54 pot=21.57 Rg=11.146 SPS=16082
# bl=0 pos[1]=[-0.3 7.7 9.3] dr=1.25 t=0.0ps kin=1.50 pot=21.55 Rg=11.115 SPS=16034
# bl=0 pos[1]=[-0.6 6.9 9.0] dr=1.25 t=0.0ps kin=1.44 pot=21.59 Rg=11.080 SPS=15721
# bl=0 pos[1]=[0.1 7.4 9.1] dr=1.27 t=0.0ps kin=1.55 pot=21.52 Rg=11.106 SPS=14586
# bl=0 pos[1]=[2.2 8.5 8.2] dr=1.27 t=0.0ps kin=1.50 pot=21.56 Rg=11.162 SPS=16473
# bl=0 pos[1]=[1.7 9.8 7.9] dr=1.30 t=0.0ps kin=1.52 pot=21.58 Rg=11.184 SPS=16398
# bl=0 pos[1]=[0.1 10.3 8.0] dr=1.25 t=0.0ps kin=1.50 pot=21.59 Rg=11.213 SPS=16232
# bl=0 pos[1]=[-0.7 11.3 8.8] dr=1.27 t=0.0ps kin=1.48 pot=21.57 Rg=11.243 SPS=17384
# bl=0 pos[1]=[-1.8 9.9 10.5] dr=1.24 t=0.0ps kin=1.49 pot=21.58 Rg=11.265 SPS=16689
# ...
# bl=0 pos[1]=[-1.3 6.7 7.0] dr=1.26 t=0.0ps kin=1.55 pot=21.53 Rg=11.315 SPS=16370
# bl=0 pos[1]=[-3.0 5.8 8.8] dr=1.25 t=0.0ps kin=1.45 pot=21.57 Rg=11.296 SPS=16493
# bl=0 pos[1]=[-1.9 7.1 7.2] dr=1.27 t=0.0ps kin=1.49 pot=21.60 Rg=11.306 SPS=16792
# bl=0 pos[1]=[-3.4 9.3 6.4] dr=1.30 t=0.0ps kin=1.53 pot=21.52 Rg=11.298 SPS=17449
# bl=0 pos[1]=[-5.0 9.5 5.6] dr=1.27 t=0.0ps kin=1.45 pot=21.59 Rg=11.351 SPS=16411
# bl=0 pos[1]=[-3.7 9.2 5.3] dr=1.23 t=0.0ps kin=1.50 pot=21.55 Rg=11.425 SPS=16103
# bl=0 pos[1]=[-2.8 8.2 4.8] dr=1.23 t=0.0ps kin=1.50 pot=21.58 Rg=11.449 SPS=16180
# bl=0 pos[1]=[-1.6 7.5 4.7] dr=1.29 t=0.0ps kin=1.51 pot=21.54 Rg=11.440 SPS=16567
# bl=0 pos[1]=[0.3 7.7 5.1] dr=1.23 t=0.0ps kin=1.50 pot=21.58 Rg=11.432 SPS=16000
# bl=0 pos[1]=[1.8 6.7 6.1] dr=1.25 t=0.0ps kin=1.52 pot=21.56 Rg=11.418 SPS=16288
# bl=0 pos[1]=[1.3 6.2 5.8] dr=1.25 t=0.0ps kin=1.46 pot=21.57 Rg=11.443 SPS=15943
# bl=0 pos[1]=[0.9 6.3 5.9] dr=1.22 t=0.0ps kin=1.48 pot=21.56 Rg=11.444 SPS=16143
# bl=0 pos[1]=[-1.6 4.4 6.4] dr=1.20 t=0.0ps kin=1.50 pot=21.58 Rg=11.443 SPS=16091
# bl=0 pos[1]=[-2.2 4.2 6.8] dr=1.28 t=0.0ps kin=1.48 pot=21.54 Rg=11.397 SPS=16322
# bl=0 pos[1]=[-2.6 6.3 5.8] dr=1.26 t=0.0ps kin=1.46 pot=21.55 Rg=11.409 SPS=17330
# bl=0 pos[1]=[-3.7 4.9 6.4] dr=1.27 t=0.0ps kin=1.51 pot=21.54 Rg=11.398 SPS=16840
# bl=0 pos[1]=[-4.6 6.3 5.3] dr=1.29 t=0.0ps kin=1.50 pot=21.59 Rg=11.334 SPS=16500
# bl=0 pos[1]=[-3.2 3.9 5.0] dr=1.25 t=0.0ps kin=1.49 pot=21.57 Rg=11.306 SPS=16225
# bl=0 pos[1]=[-1.4 4.3 6.9] dr=1.30 t=0.0ps kin=1.58 pot=21.56 Rg=11.294 SPS=15891
# bl=0 pos[1]=[-2.2 5.8 7.5] dr=1.28 t=0.0ps kin=1.56 pot=21.57 Rg=11.296 SPS=16264
# bl=0 pos[1]=[-2.0 7.5 7.5] dr=1.29 t=0.0ps kin=1.52 pot=21.62 Rg=11.324 SPS=16492
# bl=0 pos[1]=[-3.1 6.6 7.6] dr=1.28 t=0.0ps kin=1.52 pot=21.57 Rg=11.367 SPS=16431
# bl=0 pos[1]=[-1.9 4.8 5.7] dr=1.25 t=0.0ps kin=1.49 pot=21.59 Rg=11.444 SPS=16584
# bl=0 pos[1]=[-0.8 4.8 4.3] dr=1.29 t=0.0ps kin=1.53 pot=21.58 Rg=11.518 SPS=16718
# bl=0 pos[1]=[-0.9 5.2 3.8] dr=1.27 t=0.0ps kin=1.52 pot=21.57 Rg=11.559 SPS=17297
# bl=0 pos[1]=[-1.1 5.4 4.8] dr=1.31 t=0.0ps kin=1.54 pot=21.62 Rg=11.556 SPS=17450
# bl=0 pos[1]=[-1.8 5.7 5.8] dr=1.27 t=0.0ps kin=1.47 pot=21.63 Rg=11.595 SPS=16838
# bl=0 pos[1]=[-2.2 6.7 7.0] dr=1.26 t=0.0ps kin=1.55 pot=21.57 Rg=11.602 SPS=16607
# bl=0 pos[1]=[-2.5 7.8 7.4] dr=1.27 t=0.0ps kin=1.54 pot=21.51 Rg=11.577 SPS=16751
# bl=0 pos[1]=[-2.3 6.7 7.6] dr=1.25 t=0.0ps kin=1.49 pot=21.58 Rg=11.588 SPS=16737
# bl=0 pos[1]=[-1.7 7.6 7.3] dr=1.26 t=0.0ps kin=1.45 pot=21.61 Rg=11.559 SPS=16630
# bl=0 pos[1]=[-3.1 6.1 9.6] dr=1.24 t=0.0ps kin=1.53 pot=21.59 Rg=11.487 SPS=17129
# bl=0 pos[1]=[-0.6 6.5 12.2] dr=1.28 t=0.0ps kin=1.55 pot=21.62 Rg=11.421 SPS=17300
# bl=0 pos[1]=[-2.3 7.0 14.1] dr=1.26 t=0.0ps kin=1.54 pot=21.58 Rg=11.397 SPS=17206
# bl=0 pos[1]=[-3.2 5.8 15.3] dr=1.28 t=0.0ps kin=1.50 pot=21.55 Rg=11.408 SPS=16097
# bl=0 pos[1]=[-4.2 5.1 15.1] dr=1.23 t=0.0ps kin=1.47 pot=21.60 Rg=11.423 SPS=16012
# bl=0 pos[1]=[-6.4 4.8 12.7] dr=1.24 t=0.0ps kin=1.52 pot=21.58 Rg=11.453 SPS=16386
# bl=0 pos[1]=[-5.3 5.7 11.7] dr=1.26 t=0.0ps kin=1.51 pot=21.58 Rg=11.415 SPS=16520
# bl=0 pos[1]=[-6.6 7.1 14.0] dr=1.27 t=0.0ps kin=1.51 pot=21.58 Rg=11.405 SPS=16122
# bl=0 pos[1]=[-6.0 7.9 15.0] dr=1.26 t=0.0ps kin=1.48 pot=21.56 Rg=11.438 SPS=16235
# bl=0 pos[1]=[-5.5 6.9 14.3] dr=1.24 t=0.0ps kin=1.49 pot=21.54 Rg=11.430 SPS=16572
# bl=0 pos[1]=[-4.9 5.5 14.5] dr=1.28 t=0.0ps kin=1.51 pot=21.57 Rg=11.378 SPS=16949
# bl=0 pos[1]=[-2.3 5.9 12.7] dr=1.30 t=0.0ps kin=1.51 pot=21.56 Rg=11.361 SPS=17611
# bl=0 pos[1]=[-2.8 5.4 11.9] dr=1.27 t=0.0ps kin=1.50 pot=21.61 Rg=11.362 SPS=16192
# bl=0 pos[1]=[-3.5 4.7 12.2] dr=1.24 t=0.0ps kin=1.50 pot=21.55 Rg=11.358 SPS=16249
# bl=0 pos[1]=[-2.7 4.0 13.8] dr=1.27 t=0.0ps kin=1.52 pot=21.53 Rg=11.358 SPS=16576
# bl=0 pos[1]=[-2.6 2.4 14.0] dr=1.26 t=0.0ps kin=1.53 pot=21.56 Rg=11.347 SPS=16374
# bl=0 pos[1]=[-2.0 2.4 14.0] dr=1.29 t=0.0ps kin=1.52 pot=21.58 Rg=11.314 SPS=16650
# bl=0 pos[1]=[-0.8 0.3 13.3] dr=1.25 t=0.0ps kin=1.46 pot=21.62 Rg=11.277 SPS=16114
# bl=0 pos[1]=[-0.2 -0.3 14.0] dr=1.24 t=0.0ps kin=1.44 pot=21.61 Rg=11.301 SPS=16338
# bl=0 pos[1]=[2.1 -0.5 14.9] dr=1.26 t=0.0ps kin=1.48 pot=21.55 Rg=11.340 SPS=16396
# bl=0 pos[1]=[3.5 -0.0 15.0] dr=1.29 t=0.0ps kin=1.53 pot=21.54 Rg=11.372 SPS=17033
# bl=0 pos[1]=[3.1 -0.2 14.6] dr=1.28 t=0.0ps kin=1.57 pot=21.53 Rg=11.399 SPS=17997
# bl=0 pos[1]=[1.3 0.9 13.7] dr=1.27 t=0.0ps kin=1.54 pot=21.56 Rg=11.400 SPS=16529
# bl=0 pos[1]=[0.2 1.5 15.1] dr=1.28 t=0.0ps kin=1.43 pot=21.60 Rg=11.395 SPS=16458
# bl=0 pos[1]=[2.3 1.3 15.6] dr=1.24 t=0.0ps kin=1.51 pot=21.57 Rg=11.427 SPS=16911
# bl=0 pos[1]=[3.4 2.9 16.2] dr=1.30 t=0.0ps kin=1.50 pot=21.60 Rg=11.479 SPS=16296
# bl=0 pos[1]=[3.4 3.7 16.0] dr=1.25 t=0.0ps kin=1.51 pot=21.60 Rg=11.510 SPS=16494
# bl=0 pos[1]=[3.3 3.7 16.6] dr=1.26 t=0.0ps kin=1.48 pot=21.60 Rg=11.539 SPS=16685
# bl=0 pos[1]=[3.0 3.1 16.1] dr=1.25 t=0.0ps kin=1.54 pot=21.55 Rg=11.558 SPS=17330
# bl=0 pos[1]=[3.4 3.6 17.3] dr=1.27 t=0.0ps kin=1.48 pot=21.60 Rg=11.523 SPS=17645
# bl=0 pos[1]=[4.5 3.4 15.4] dr=1.28 t=0.0ps kin=1.51 pot=21.59 Rg=11.478 SPS=16388
# bl=0 pos[1]=[3.8 2.4 14.1] dr=1.27 t=0.0ps kin=1.46 pot=21.61 Rg=11.449 SPS=16405
# bl=0 pos[1]=[2.6 1.9 13.4] dr=1.23 t=0.0ps kin=1.52 pot=21.60 Rg=11.386 SPS=16266
# bl=0 pos[1]=[3.6 0.3 12.4] dr=1.25 t=0.0ps kin=1.55 pot=21.63 Rg=11.408 SPS=15786
# bl=0 pos[1]=[4.9 -0.6 13.0] dr=1.27 t=0.0ps kin=1.55 pot=21.63 Rg=11.420 SPS=16410
# bl=0 pos[1]=[6.3 0.6 14.2] dr=1.26 t=0.0ps kin=1.55 pot=21.62 Rg=11.426 SPS=16069
# bl=0 pos[1]=[6.5 2.4 13.0] dr=1.27 t=0.0ps kin=1.55 pot=21.61 Rg=11.400 SPS=16509
# bl=0 pos[1]=[5.8 2.2 12.6] dr=1.30 t=0.0ps kin=1.54 pot=21.61 Rg=11.361 SPS=16085
# bl=0 pos[1]=[6.3 0.3 11.1] dr=1.28 t=0.0ps kin=1.55 pot=21.61 Rg=11.360 SPS=16024
# bl=0 pos[1]=[4.5 -0.0 12.4] dr=1.27 t=0.0ps kin=1.54 pot=21.60 Rg=11.378 SPS=16364
# bl=0 pos[1]=[3.0 -0.6 12.1] dr=1.25 t=0.0ps kin=1.52 pot=21.62 Rg=11.409 SPS=16214
# bl=0 pos[1]=[2.1 0.9 10.7] dr=1.25 t=0.0ps kin=1.52 pot=21.62 Rg=11.427 SPS=17024
# bl=0 pos[1]=[2.9 -0.0 9.1] dr=1.25 t=0.0ps kin=1.54 pot=21.60 Rg=11.412 SPS=17442
# bl=0 pos[1]=[3.3 -1.3 8.4] dr=1.27 t=0.0ps kin=1.58 pot=21.56 Rg=11.390 SPS=15868
# bl=0 pos[1]=[2.1 -1.3 8.8] dr=1.29 t=0.0ps kin=1.55 pot=21.61 Rg=11.370 SPS=16205
# bl=0 pos[1]=[0.6 -0.8 8.3] dr=1.26 t=0.0ps kin=1.52 pot=21.56 Rg=11.371 SPS=16201
# bl=0 pos[1]=[0.2 -1.3 9.7] dr=1.25 t=0.0ps kin=1.48 pot=21.62 Rg=11.376 SPS=16390
# bl=0 pos[1]=[0.6 -0.5 9.6] dr=1.27 t=0.0ps kin=1.62 pot=21.58 Rg=11.379 SPS=16254
# bl=0 pos[1]=[1.5 -1.8 9.6] dr=1.28 t=0.0ps kin=1.60 pot=21.62 Rg=11.393 SPS=16066
# bl=0 pos[1]=[1.7 -1.4 9.9] dr=1.27 t=0.0ps kin=1.56 pot=21.62 Rg=11.435 SPS=16374
# bl=0 pos[1]=[1.7 -0.1 9.9] dr=1.30 t=0.0ps kin=1.47 pot=21.63 Rg=11.416 SPS=16305
# bl=0 pos[1]=[2.4 0.5 10.9] dr=1.27 t=0.0ps kin=1.49 pot=21.65 Rg=11.382 SPS=16592
# bl=0 pos[1]=[2.5 1.0 12.6] dr=1.27 t=0.0ps kin=1.52 pot=21.62 Rg=11.420 SPS=17068
# bl=0 pos[1]=[3.3 3.1 14.2] dr=1.27 t=0.0ps kin=1.56 pot=21.58 Rg=11.460 SPS=18151
# bl=0 pos[1]=[3.5 4.7 13.9] dr=1.29 t=0.0ps kin=1.52 pot=21.60 Rg=11.476 SPS=16665
# bl=0 pos[1]=[2.5 3.9 14.5] dr=1.30 t=0.0ps kin=1.53 pot=21.62 Rg=11.519 SPS=16228
# bl=0 pos[1]=[2.2 3.4 14.5] dr=1.27 t=0.0ps kin=1.47 pot=21.55 Rg=11.544 SPS=16633
# bl=0 pos[1]=[2.0 3.0 14.0] dr=1.25 t=0.0ps kin=1.50 pot=21.58 Rg=11.530 SPS=16588
# bl=0 pos[1]=[1.8 2.5 14.4] dr=1.26 t=0.0ps kin=1.48 pot=21.60 Rg=11.494 SPS=16298
# bl=0 pos[1]=[1.3 2.5 14.5] dr=1.23 t=0.0ps kin=1.46 pot=21.59 Rg=11.441 SPS=16707
# bl=0 pos[1]=[0.3 2.7 14.3] dr=1.23 t=0.0ps kin=1.50 pot=21.55 Rg=11.437 SPS=16659
# bl=0 pos[1]=[0.4 2.2 14.1] dr=1.24 t=0.0ps kin=1.43 pot=21.61 Rg=11.484 SPS=17337
# bl=0 pos[1]=[1.6 2.1 13.4] dr=1.27 t=0.0ps kin=1.49 pot=21.63 Rg=11.549 SPS=18718
# bl=0 pos[1]=[1.1 2.5 13.5] dr=1.28 t=0.0ps kin=1.52 pot=21.59 Rg=11.595 SPS=16838
# bl=0 pos[1]=[0.5 2.5 15.0] dr=1.24 t=0.0ps kin=1.44 pot=21.64 Rg=11.634 SPS=16800
# bl=0 pos[1]=[0.1 4.1 16.0] dr=1.22 t=0.0ps kin=1.49 pot=21.59 Rg=11.672 SPS=16168
# bl=0 pos[1]=[-0.2 4.5 17.6] dr=1.25 t=0.0ps kin=1.53 pot=21.60 Rg=11.677 SPS=16183
# bl=0 pos[1]=[0.2 3.1 18.9] dr=1.29 t=0.0ps kin=1.52 pot=21.59 Rg=11.700 SPS=16448
# bl=0 pos[1]=[1.1 2.5 20.0] dr=1.27 t=0.0ps kin=1.50 pot=21.58 Rg=11.680 SPS=16372
# bl=0 pos[1]=[1.0 1.4 20.1] dr=1.24 t=0.0ps kin=1.45 pot=21.60 Rg=11.625 SPS=17164
# bl=0 pos[1]=[0.1 1.2 18.6] dr=1.26 t=0.0ps kin=1.48 pot=21.58 Rg=11.598 SPS=17320
# bl=0 pos[1]=[1.0 1.7 18.0] dr=1.24 t=0.0ps kin=1.50 pot=21.56 Rg=11.580 SPS=16279
# bl=0 pos[1]=[1.3 2.7 18.1] dr=1.26 t=0.0ps kin=1.49 pot=21.60 Rg=11.549 SPS=16296
# bl=0 pos[1]=[1.0 3.5 16.3] dr=1.27 t=0.0ps kin=1.51 pot=21.55 Rg=11.541 SPS=16089
# bl=0 pos[1]=[0.9 3.9 17.5] dr=1.25 t=0.0ps kin=1.45 pot=21.58 Rg=11.522 SPS=16823
# bl=0 pos[1]=[1.6 1.7 16.3] dr=1.27 t=0.0ps kin=1.39 pot=21.60 Rg=11.515 SPS=15656
# bl=0 pos[1]=[0.6 -0.2 14.6] dr=1.26 t=0.0ps kin=1.45 pot=21.58 Rg=11.502 SPS=16307
# bl=0 pos[1]=[-1.2 0.1 15.7] dr=1.26 t=0.0ps kin=1.49 pot=21.59 Rg=11.478 SPS=16165
# bl=0 pos[1]=[-1.3 0.6 16.0] dr=1.28 t=0.0ps kin=1.50 pot=21.56 Rg=11.423 SPS=16137
# bl=0 pos[1]=[-1.1 -2.3 15.9] dr=1.27 t=0.0ps kin=1.49 pot=21.58 Rg=11.401 SPS=16798
# bl=0 pos[1]=[1.0 -3.3 14.4] dr=1.27 t=0.0ps kin=1.51 pot=21.60 Rg=11.364 SPS=17010
# bl=0 pos[1]=[2.1 -4.2 15.4] dr=1.32 t=0.0ps kin=1.59 pot=21.56 Rg=11.309 SPS=17481
# bl=0 pos[1]=[2.7 -4.6 15.5] dr=1.24 t=0.0ps kin=1.51 pot=21.61 Rg=11.289 SPS=16459
# bl=0 pos[1]=[1.5 -5.1 15.1] dr=1.26 t=0.0ps kin=1.55 pot=21.64 Rg=11.242 SPS=16030
# bl=0 pos[1]=[0.6 -5.3 15.2] dr=1.27 t=0.0ps kin=1.53 pot=21.59 Rg=11.231 SPS=16113
# bl=0 pos[1]=[-1.3 -4.8 15.5] dr=1.23 t=0.0ps kin=1.53 pot=21.60 Rg=11.248 SPS=16107
# bl=0 pos[1]=[-1.3 -5.7 16.1] dr=1.28 t=0.0ps kin=1.53 pot=21.55 Rg=11.275 SPS=15891
# bl=0 pos[1]=[-0.4 -6.6 16.0] dr=1.31 t=0.0ps kin=1.48 pot=21.57 Rg=11.371 SPS=16109
# bl=0 pos[1]=[-0.0 -5.4 15.0] dr=1.25 t=0.0ps kin=1.48 pot=21.56 Rg=11.464 SPS=16540
# bl=0 pos[1]=[-1.6 -5.2 15.8] dr=1.25 t=0.0ps kin=1.50 pot=21.60 Rg=11.524 SPS=16330
# bl=0 pos[1]=[-1.9 -4.1 17.2] dr=1.28 t=0.0ps kin=1.53 pot=21.59 Rg=11.527 SPS=16428
# bl=0 pos[1]=[-0.8 -3.0 17.2] dr=1.24 t=0.0ps kin=1.53 pot=21.56 Rg=11.522 SPS=16212
# bl=0 pos[1]=[-2.3 -3.9 16.9] dr=1.26 t=0.0ps kin=1.53 pot=21.61 Rg=11.443 SPS=17065
# bl=0 pos[1]=[-2.3 -4.3 17.3] dr=1.28 t=0.0ps kin=1.57 pot=21.58 Rg=11.426 SPS=17414
# bl=0 pos[1]=[-3.2 -4.6 17.7] dr=1.30 t=0.0ps kin=1.49 pot=21.59 Rg=11.428 SPS=16460
# bl=0 pos[1]=[-5.1 -6.1 18.1] dr=1.26 t=0.0ps kin=1.49 pot=21.57 Rg=11.456 SPS=16286
# bl=0 pos[1]=[-5.2 -7.4 18.0] dr=1.24 t=0.0ps kin=1.47 pot=21.57 Rg=11.481 SPS=16256
# bl=0 pos[1]=[-4.6 -8.8 18.9] dr=1.24 t=0.0ps kin=1.52 pot=21.56 Rg=11.480 SPS=16504
# bl=0 pos[1]=[-5.2 -8.5 17.6] dr=1.27 t=0.0ps kin=1.49 pot=21.65 Rg=11.456 SPS=15919
# bl=0 pos[1]=[-5.1 -7.9 17.0] dr=1.25 t=0.0ps kin=1.50 pot=21.61 Rg=11.450 SPS=16542
# bl=0 pos[1]=[-4.0 -7.6 18.4] dr=1.23 t=0.0ps kin=1.49 pot=21.60 Rg=11.514 SPS=16427
# bl=0 pos[1]=[-4.3 -6.6 18.7] dr=1.26 t=0.0ps kin=1.51 pot=21.61 Rg=11.566 SPS=16101
# bl=0 pos[1]=[-2.9 -6.7 17.3] dr=1.31 t=0.0ps kin=1.51 pot=21.60 Rg=11.601 SPS=16610
# bl=0 pos[1]=[-2.9 -4.6 18.4] dr=1.27 t=0.0ps kin=1.49 pot=21.57 Rg=11.585 SPS=16362
# bl=0 pos[1]=[-3.3 -3.1 17.8] dr=1.26 t=0.0ps kin=1.48 pot=21.57 Rg=11.538 SPS=17631
# bl=0 pos[1]=[-3.8 -1.9 16.2] dr=1.28 t=0.0ps kin=1.48 pot=21.62 Rg=11.500 SPS=16315
# bl=0 pos[1]=[-3.7 -2.4 15.4] dr=1.28 t=0.0ps kin=1.49 pot=21.61 Rg=11.454 SPS=14954
# bl=0 pos[1]=[-3.2 -3.3 16.0] dr=1.26 t=0.0ps kin=1.49 pot=21.59 Rg=11.409 SPS=16149
# bl=0 pos[1]=[-2.1 -1.4 15.7] dr=1.26 t=0.0ps kin=1.49 pot=21.56 Rg=11.339 SPS=16500
# bl=0 pos[1]=[-3.0 -0.7 13.6] dr=1.28 t=0.0ps kin=1.50 pot=21.54 Rg=11.287 SPS=16213
# bl=0 pos[1]=[-3.1 -1.7 12.4] dr=1.28 t=0.0ps kin=1.51 pot=21.54 Rg=11.253 SPS=16086
# bl=0 pos[1]=[-2.6 -0.9 13.3] dr=1.23 t=0.0ps kin=1.49 pot=21.57 Rg=11.226 SPS=15846
# bl=0 pos[1]=[-2.2 -3.2 13.2] dr=1.24 t=0.0ps kin=1.52 pot=21.54 Rg=11.227 SPS=16018
# bl=0 pos[1]=[-1.6 -3.5 12.9] dr=1.24 t=0.0ps kin=1.49 pot=21.56 Rg=11.216 SPS=16123
# bl=0 pos[1]=[-0.3 -2.6 14.4] dr=1.25 t=0.0ps kin=1.45 pot=21.57 Rg=11.272 SPS=16324
# bl=0 pos[1]=[1.6 -3.3 13.9] dr=1.25 t=0.0ps kin=1.54 pot=21.58 Rg=11.279 SPS=16426
# bl=0 pos[1]=[2.9 -4.2 14.1] dr=1.27 t=0.0ps kin=1.53 pot=21.61 Rg=11.261 SPS=16012
# bl=0 pos[1]=[3.1 -4.9 12.0] dr=1.29 t=0.0ps kin=1.56 pot=21.58 Rg=11.250 SPS=15930
# bl=0 pos[1]=[2.2 -5.4 10.6] dr=1.27 t=0.0ps kin=1.49 pot=21.61 Rg=11.256 SPS=17227
# bl=0 pos[1]=[1.4 -6.0 10.1] dr=1.27 t=0.0ps kin=1.49 pot=21.56 Rg=11.310 SPS=17363
# bl=0 pos[1]=[0.3 -7.6 9.0] dr=1.25 t=0.0ps kin=1.48 pot=21.60 Rg=11.362 SPS=16435
# bl=0 pos[1]=[-0.4 -8.4 8.4] dr=1.23 t=0.0ps kin=1.48 pot=21.60 Rg=11.385 SPS=16007
# bl=0 pos[1]=[-2.1 -7.9 6.8] dr=1.24 t=0.0ps kin=1.48 pot=21.58 Rg=11.353 SPS=16171
# bl=0 pos[1]=[-2.2 -7.7 6.7] dr=1.20 t=0.0ps kin=1.43 pot=21.58 Rg=11.327 SPS=16357
# bl=0 pos[1]=[-0.9 -8.1 7.0] dr=1.21 t=0.0ps kin=1.46 pot=21.57 Rg=11.331 SPS=16118
# bl=0 pos[1]=[-1.7 -9.7 5.4] dr=1.22 t=0.0ps kin=1.43 pot=21.58 Rg=11.333 SPS=15874
# bl=0 pos[1]=[-2.1 -8.9 4.5] dr=1.23 t=0.0ps kin=1.46 pot=21.57 Rg=11.379 SPS=15741
# bl=0 pos[1]=[-3.1 -8.0 5.3] dr=1.24 t=0.0ps kin=1.45 pot=21.56 Rg=11.344 SPS=15877
# bl=0 pos[1]=[-4.0 -7.8 5.7] dr=1.25 t=0.0ps kin=1.45 pot=21.60 Rg=11.264 SPS=16244
# bl=0 pos[1]=[-2.8 -7.9 6.1] dr=1.25 t=0.0ps kin=1.55 pot=21.55 Rg=11.228 SPS=16391
# bl=0 pos[1]=[-3.6 -7.4 7.2] dr=1.25 t=0.0ps kin=1.46 pot=21.56 Rg=11.203 SPS=16081
# bl=0 pos[1]=[-3.4 -7.8 6.5] dr=1.27 t=0.0ps kin=1.50 pot=21.56 Rg=11.168 SPS=16194
# bl=0 pos[1]=[-2.3 -7.0 5.5] dr=1.26 t=0.0ps kin=1.51 pot=21.58 Rg=11.185 SPS=16668
# bl=0 pos[1]=[-0.7 -7.4 5.9] dr=1.30 t=0.0ps kin=1.51 pot=21.57 Rg=11.230 SPS=17588
# bl=0 pos[1]=[0.4 -6.1 5.2] dr=1.27 t=0.0ps kin=1.53 pot=21.57 Rg=11.279 SPS=16269
# bl=0 pos[1]=[-1.0 -5.9 5.3] dr=1.27 t=0.0ps kin=1.53 pot=21.61 Rg=11.315 SPS=16028
# bl=0 pos[1]=[-0.4 -5.6 4.7] dr=1.25 t=0.0ps kin=1.50 pot=21.61 Rg=11.329 SPS=16513
# bl=0 pos[1]=[-1.4 -7.1 6.1] dr=1.23 t=0.0ps kin=1.44 pot=21.58 Rg=11.299 SPS=16217
# bl=0 pos[1]=[-1.4 -8.3 3.9] dr=1.25 t=0.0ps kin=1.49 pot=21.58 Rg=11.301 SPS=16411
# bl=0 pos[1]=[-1.1 -9.0 2.9] dr=1.22 t=0.0ps kin=1.50 pot=21.63 Rg=11.309 SPS=16372
# bl=0 pos[1]=[-0.6 -9.9 3.9] dr=1.27 t=0.0ps kin=1.50 pot=21.59 Rg=11.310 SPS=16077
# bl=0 pos[1]=[0.1 -9.1 4.5] dr=1.25 t=0.0ps kin=1.53 pot=21.56 Rg=11.336 SPS=16001
# bl=0 pos[1]=[0.6 -10.6 4.3] dr=1.25 t=0.0ps kin=1.49 pot=21.61 Rg=11.327 SPS=16032
# bl=0 pos[1]=[1.5 -10.2 4.8] dr=1.25 t=0.0ps kin=1.45 pot=21.63 Rg=11.352 SPS=16145
# bl=0 pos[1]=[0.7 -10.9 5.5] dr=1.25 t=0.0ps kin=1.52 pot=21.59 Rg=11.420 SPS=16061
# bl=0 pos[1]=[0.9 -9.6 4.7] dr=1.27 t=0.0ps kin=1.53 pot=21.60 Rg=11.447 SPS=16150
# bl=0 pos[1]=[0.6 -9.1 5.8] dr=1.27 t=0.0ps kin=1.52 pot=21.62 Rg=11.467 SPS=17190
# bl=0 pos[1]=[1.0 -10.6 5.6] dr=1.27 t=0.0ps kin=1.49 pot=21.62 Rg=11.511 SPS=17927
# bl=0 pos[1]=[1.3 -11.3 4.1] dr=1.30 t=0.0ps kin=1.56 pot=21.58 Rg=11.532 SPS=16499
# bl=0 pos[1]=[2.5 -12.4 3.7] dr=1.29 t=0.0ps kin=1.54 pot=21.60 Rg=11.493 SPS=16708
# bl=0 pos[1]=[3.9 -11.2 3.3] dr=1.29 t=0.0ps kin=1.47 pot=21.60 Rg=11.445 SPS=15992
# bl=0 pos[1]=[5.7 -8.0 2.7] dr=1.25 t=0.0ps kin=1.49 pot=21.60 Rg=11.422 SPS=16561
# bl=0 pos[1]=[5.5 -5.8 1.6] dr=1.26 t=0.0ps kin=1.52 pot=21.63 Rg=11.418 SPS=17383
# bl=0 pos[1]=[4.7 -4.6 2.8] dr=1.26 t=0.0ps kin=1.55 pot=21.52 Rg=11.431 SPS=17129
# bl=0 pos[1]=[5.4 -4.8 3.7] dr=1.25 t=0.0ps kin=1.49 pot=21.54 Rg=11.395 SPS=17551
# bl=0 pos[1]=[4.6 -4.0 2.9] dr=1.28 t=0.0ps kin=1.46 pot=21.57 Rg=11.354 SPS=16326
# bl=0 pos[1]=[4.0 -3.8 2.3] dr=1.25 t=0.0ps kin=1.49 pot=21.60 Rg=11.300 SPS=16346
# bl=0 pos[1]=[4.8 -3.7 1.0] dr=1.25 t=0.0ps kin=1.49 pot=21.66 Rg=11.239 SPS=16243
# bl=0 pos[1]=[6.7 -5.0 1.5] dr=1.26 t=0.0ps kin=1.52 pot=21.60 Rg=11.223 SPS=15602
# bl=0 pos[1]=[7.4 -4.7 1.9] dr=1.25 t=0.0ps kin=1.48 pot=21.59 Rg=11.247 SPS=15874

# %% [markdown]
# Some details about the output for each block performed:
#
# **bl=0** is the number of each block ran, in this case we set increment=False, so the number of steps is not accounted.<br>
# **pos\[1\]=\[X,Y,Z\]** the spatial position for the first bead. <br>
# **dr=1.26** show the average positions displacement in each block (in units os sigma). <br>
# **t=0** the time step. in this case we set increment=False, so the number of steps is not accounted.<br>
# **kin=1.5** is the kinect energy of the system.<br>
# **pot=19.90** is the potential energy of the system. <br>
# **RG=7.654** is the radius of gyration in the end of each block. <br>
# **SPS=12312** is the steps per second of each block. A way to look how fast the computations are being performed.

# %% [markdown]
# Check the convergence of the radius of gyration:

# %%
plt.plot(rg)

# %% [markdown]
# The next step is to remove the restraint force in order to run the sampling simulation

# %%
sim.removeFlatBottomharmonic()

# %% [markdown]
# Initiate the optimization object. In this tutorial, this object is named "opt"

# %%
opt = CustomMiChroMTraining(ChromSeq="input/seq_chr10_100k.txt",
                            mu=3.22, rc = 1.78)

# %% [markdown]
# The next step is to perform a long simulation to feed the optimization parameters. <br>
#
# In order to get a good inversion calcultation, it is important to have around $1\times10^5$ frames from different replicas. For example, $20$ replicas of $5000$ saved frames. <br>
#
# This can take some time, so in this tutorial we will use just 1 replica of $5000$ frames saved every $1000$ steps. <br>
#
# $block = 10\times3$ <br>
# $n\_blocks = 5000$

# %%
block = 1000
n_blocks = 500

# %%
for _ in range(n_blocks):
    sim.runSimBlock(block, increment=True) #perform 1 block of the simulation
    opt.probCalculation_types(sim.getPositions()) #feed the optimization with the last position
# Out:
# bl=51 pos[1]=[11.1 -20.6 13.9] dr=1.90 t=0.0ps kin=1.53 pot=21.53 Rg=14.796 SPS=12770
# bl=52 pos[1]=[10.7 -20.0 12.1] dr=1.88 t=0.0ps kin=1.48 pot=21.57 Rg=14.848 SPS=15465
# bl=53 pos[1]=[9.9 -19.7 14.2] dr=1.84 t=0.0ps kin=1.53 pot=21.54 Rg=15.033 SPS=15096
# bl=54 pos[1]=[9.8 -22.6 16.1] dr=1.93 t=0.0ps kin=1.53 pot=21.52 Rg=15.197 SPS=16331
# bl=55 pos[1]=[9.7 -22.2 17.5] dr=1.88 t=0.0ps kin=1.49 pot=21.47 Rg=15.127 SPS=18270
# bl=56 pos[1]=[10.9 -20.6 16.5] dr=1.95 t=0.0ps kin=1.49 pot=21.51 Rg=15.019 SPS=17871
# bl=57 pos[1]=[10.7 -18.2 15.0] dr=1.90 t=0.0ps kin=1.56 pot=21.49 Rg=14.992 SPS=17965
# bl=58 pos[1]=[11.5 -15.7 13.1] dr=1.92 t=0.0ps kin=1.52 pot=21.48 Rg=14.983 SPS=17453
# bl=59 pos[1]=[14.7 -14.3 9.9] dr=2.00 t=0.0ps kin=1.51 pot=21.47 Rg=15.017 SPS=16655
# bl=60 pos[1]=[13.3 -16.1 6.9] dr=1.92 t=0.0ps kin=1.48 pot=21.48 Rg=15.131 SPS=17253
# bl=61 pos[1]=[13.4 -14.4 6.8] dr=1.82 t=0.0ps kin=1.53 pot=21.51 Rg=15.214 SPS=16943
# bl=62 pos[1]=[16.2 -14.7 4.3] dr=1.89 t=0.0ps kin=1.54 pot=21.54 Rg=15.174 SPS=16907
# bl=63 pos[1]=[12.8 -14.6 3.7] dr=1.89 t=0.0ps kin=1.50 pot=21.52 Rg=15.209 SPS=17680
# bl=64 pos[1]=[11.0 -11.9 2.6] dr=1.93 t=0.0ps kin=1.52 pot=21.51 Rg=15.188 SPS=17531
# bl=65 pos[1]=[8.9 -14.9 2.0] dr=1.91 t=0.0ps kin=1.48 pot=21.51 Rg=15.102 SPS=17457
# bl=66 pos[1]=[8.0 -12.6 2.1] dr=1.94 t=0.0ps kin=1.49 pot=21.55 Rg=15.075 SPS=16985
# bl=67 pos[1]=[7.6 -13.4 2.9] dr=1.92 t=0.0ps kin=1.49 pot=21.54 Rg=15.082 SPS=17446
# bl=68 pos[1]=[8.7 -14.9 0.9] dr=1.91 t=0.0ps kin=1.46 pot=21.51 Rg=15.155 SPS=17526
# bl=69 pos[1]=[9.0 -14.7 -0.2] dr=1.91 t=0.0ps kin=1.52 pot=21.48 Rg=15.355 SPS=18113
# bl=70 pos[1]=[11.0 -14.6 -0.6] dr=1.93 t=0.0ps kin=1.48 pot=21.53 Rg=15.353 SPS=18800
# bl=71 pos[1]=[12.0 -14.8 -0.1] dr=1.95 t=0.0ps kin=1.52 pot=21.52 Rg=15.372 SPS=18000
# bl=72 pos[1]=[12.0 -14.9 0.0] dr=1.90 t=0.0ps kin=1.51 pot=21.53 Rg=15.475 SPS=18020
# bl=73 pos[1]=[13.6 -16.3 -1.6] dr=1.95 t=0.0ps kin=1.52 pot=21.51 Rg=15.642 SPS=18007
# bl=74 pos[1]=[15.7 -15.5 -0.8] dr=1.99 t=0.0ps kin=1.49 pot=21.49 Rg=15.815 SPS=17210
# bl=75 pos[1]=[15.1 -13.3 1.2] dr=1.93 t=0.0ps kin=1.48 pot=21.49 Rg=15.889 SPS=17599
# bl=76 pos[1]=[16.9 -14.8 -1.1] dr=1.96 t=0.0ps kin=1.51 pot=21.53 Rg=15.907 SPS=17849
# bl=77 pos[1]=[13.5 -11.9 -2.7] dr=1.83 t=0.0ps kin=1.48 pot=21.51 Rg=15.922 SPS=17465
# bl=78 pos[1]=[12.8 -12.3 1.2] dr=1.87 t=0.0ps kin=1.49 pot=21.49 Rg=16.066 SPS=17041
# bl=79 pos[1]=[14.3 -11.5 3.3] dr=1.88 t=0.0ps kin=1.47 pot=21.56 Rg=16.032 SPS=17415
# bl=80 pos[1]=[12.3 -11.0 6.7] dr=1.95 t=0.0ps kin=1.53 pot=21.52 Rg=15.852 SPS=18681
# bl=81 pos[1]=[10.0 -9.9 7.6] dr=1.89 t=0.0ps kin=1.48 pot=21.52 Rg=15.658 SPS=17203
# bl=82 pos[1]=[7.9 -9.7 8.6] dr=1.89 t=0.0ps kin=1.46 pot=21.49 Rg=15.647 SPS=17753
# bl=83 pos[1]=[10.4 -8.8 8.7] dr=1.91 t=0.0ps kin=1.44 pot=21.54 Rg=15.771 SPS=17805
# bl=84 pos[1]=[12.6 -10.4 7.6] dr=1.89 t=0.0ps kin=1.51 pot=21.46 Rg=15.864 SPS=18135
# bl=85 pos[1]=[13.9 -10.4 6.9] dr=1.94 t=0.0ps kin=1.44 pot=21.48 Rg=15.949 SPS=17774
# bl=86 pos[1]=[12.7 -11.7 3.4] dr=1.92 t=0.0ps kin=1.54 pot=21.46 Rg=16.064 SPS=18430
# bl=87 pos[1]=[13.3 -12.6 5.6] dr=1.91 t=0.0ps kin=1.48 pot=21.49 Rg=16.171 SPS=17479
# bl=88 pos[1]=[14.3 -11.2 8.9] dr=1.96 t=0.0ps kin=1.51 pot=21.51 Rg=16.211 SPS=17847
# bl=89 pos[1]=[12.6 -13.7 9.5] dr=1.96 t=0.0ps kin=1.56 pot=21.53 Rg=16.199 SPS=18434
# bl=90 pos[1]=[11.5 -13.9 10.7] dr=1.91 t=0.0ps kin=1.55 pot=21.51 Rg=16.260 SPS=18918
# bl=91 pos[1]=[11.6 -15.1 11.5] dr=1.94 t=0.0ps kin=1.54 pot=21.52 Rg=16.188 SPS=18457
# bl=92 pos[1]=[13.6 -12.5 10.6] dr=1.92 t=0.0ps kin=1.55 pot=21.52 Rg=16.132 SPS=18296
# bl=93 pos[1]=[14.9 -12.4 14.6] dr=1.89 t=0.0ps kin=1.51 pot=21.49 Rg=16.108 SPS=18593
# bl=94 pos[1]=[12.0 -13.8 14.6] dr=1.88 t=0.0ps kin=1.48 pot=21.52 Rg=16.061 SPS=18664
# bl=95 pos[1]=[11.7 -14.9 12.0] dr=1.91 t=0.0ps kin=1.48 pot=21.51 Rg=16.056 SPS=17470
# bl=96 pos[1]=[11.7 -16.0 14.7] dr=1.93 t=0.0ps kin=1.48 pot=21.49 Rg=16.131 SPS=18560
# bl=97 pos[1]=[10.4 -17.0 12.4] dr=1.98 t=0.0ps kin=1.46 pot=21.51 Rg=16.066 SPS=17961
# bl=98 pos[1]=[14.5 -16.3 8.0] dr=1.91 t=0.0ps kin=1.45 pot=21.54 Rg=16.005 SPS=18233
# bl=99 pos[1]=[16.6 -15.3 9.5] dr=1.90 t=0.0ps kin=1.53 pot=21.51 Rg=16.042 SPS=17812
#
# Statistics for the simulation opt_chr10_100K, number of particles: 1356,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.3187728  -1.2381029  -1.77266893]   Rg =  16.04195
#      median bond size is  0.9691883895638531
#      three shortest/longest (<10)/ bonds are  [0.87998194 0.88502281 0.88549745]    [1.08461977 1.08993458 1.09172074]
#      95 percentile of distance to center is:    23.63761365330591
#      density of closest 95% monomers is:    0.02328540497406575
#      density of the core monomers is:    0.057030414316403225
#      min/median/mean/max coordinates are:
#      x: -22.15, -1.64, -0.32, 29.94
#      y: -28.70, -0.28, -1.24, 19.69
#      z: -22.75, -1.68, -1.77, 18.78
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5371245901330841 should be: 1.5
#      fastest particles are (in kT):  [6.36215543 6.37080728 6.61982313 7.09003161 9.07994888]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'CustomTypes']
#      Number of exceptions:   1355
#
# Potential Energy Ep =  21.506207941556045
# bl=100 pos[1]=[16.7 -14.6 8.7] dr=1.92 t=0.0ps kin=1.57 pot=21.54 Rg=16.111 SPS=18275
# bl=101 pos[1]=[15.5 -15.1 7.8] dr=1.96 t=0.0ps kin=1.54 pot=21.49 Rg=16.075 SPS=18225
# bl=102 pos[1]=[15.5 -14.1 9.0] dr=1.90 t=0.0ps kin=1.48 pot=21.46 Rg=16.074 SPS=17506
# bl=103 pos[1]=[15.1 -14.7 11.6] dr=1.90 t=0.0ps kin=1.50 pot=21.45 Rg=16.134 SPS=17823
# bl=104 pos[1]=[13.6 -17.7 7.5] dr=1.88 t=0.0ps kin=1.48 pot=21.51 Rg=16.139 SPS=19019
# bl=105 pos[1]=[12.4 -19.6 8.9] dr=1.88 t=0.0ps kin=1.47 pot=21.50 Rg=16.193 SPS=18493
# bl=106 pos[1]=[12.5 -20.2 9.6] dr=1.92 t=0.0ps kin=1.50 pot=21.54 Rg=16.176 SPS=18031
# bl=107 pos[1]=[12.1 -20.0 10.7] dr=1.81 t=0.0ps kin=1.53 pot=21.52 Rg=16.067 SPS=18293
# bl=108 pos[1]=[11.7 -21.3 10.0] dr=1.85 t=0.0ps kin=1.48 pot=21.51 Rg=16.008 SPS=17793
# bl=109 pos[1]=[14.8 -19.4 8.5] dr=1.87 t=0.0ps kin=1.48 pot=21.51 Rg=16.012 SPS=17004
# bl=110 pos[1]=[15.5 -18.8 8.0] dr=1.91 t=0.0ps kin=1.51 pot=21.49 Rg=15.990 SPS=17537
# bl=111 pos[1]=[14.2 -19.2 8.7] dr=1.99 t=0.0ps kin=1.50 pot=21.53 Rg=15.952 SPS=17835
# bl=112 pos[1]=[12.1 -19.5 8.6] dr=2.01 t=0.0ps kin=1.52 pot=21.53 Rg=15.908 SPS=18529
# bl=113 pos[1]=[10.7 -18.7 7.6] dr=1.93 t=0.0ps kin=1.51 pot=21.56 Rg=16.050 SPS=18446
# bl=114 pos[1]=[11.8 -23.0 6.6] dr=1.93 t=0.0ps kin=1.58 pot=21.56 Rg=16.162 SPS=17868
# bl=115 pos[1]=[11.5 -20.2 3.5] dr=1.96 t=0.0ps kin=1.52 pot=21.54 Rg=16.249 SPS=17274
# bl=116 pos[1]=[14.3 -21.8 3.0] dr=1.93 t=0.0ps kin=1.51 pot=21.51 Rg=16.351 SPS=17242
# bl=117 pos[1]=[13.6 -19.2 3.5] dr=1.91 t=0.0ps kin=1.48 pot=21.54 Rg=16.429 SPS=17070
# bl=118 pos[1]=[15.7 -18.9 6.1] dr=1.88 t=0.0ps kin=1.50 pot=21.53 Rg=16.451 SPS=17578
# bl=119 pos[1]=[13.0 -21.4 7.3] dr=1.87 t=0.0ps kin=1.43 pot=21.50 Rg=16.426 SPS=18404
# bl=120 pos[1]=[10.0 -20.2 9.0] dr=1.89 t=0.0ps kin=1.45 pot=21.52 Rg=16.383 SPS=18353
# bl=121 pos[1]=[7.4 -18.7 8.4] dr=1.91 t=0.0ps kin=1.48 pot=21.50 Rg=16.341 SPS=17448
# bl=122 pos[1]=[7.1 -19.3 10.6] dr=1.96 t=0.0ps kin=1.49 pot=21.54 Rg=16.229 SPS=18326
# bl=123 pos[1]=[5.5 -15.9 11.0] dr=1.94 t=0.0ps kin=1.50 pot=21.51 Rg=16.180 SPS=17146
# bl=124 pos[1]=[4.3 -12.2 9.0] dr=1.95 t=0.0ps kin=1.46 pot=21.50 Rg=16.100 SPS=17800
# bl=125 pos[1]=[4.7 -11.3 7.7] dr=1.95 t=0.0ps kin=1.50 pot=21.54 Rg=15.985 SPS=18093
# bl=126 pos[1]=[2.2 -10.9 9.5] dr=1.92 t=0.0ps kin=1.48 pot=21.48 Rg=15.941 SPS=17747
# bl=127 pos[1]=[-0.2 -10.7 10.4] dr=1.88 t=0.0ps kin=1.49 pot=21.51 Rg=15.970 SPS=18470
# bl=128 pos[1]=[-2.8 -10.9 10.6] dr=1.96 t=0.0ps kin=1.55 pot=21.53 Rg=15.938 SPS=17767
# bl=129 pos[1]=[-3.6 -11.0 8.5] dr=1.90 t=0.0ps kin=1.52 pot=21.55 Rg=15.991 SPS=17753
# bl=130 pos[1]=[-1.5 -13.0 5.0] dr=1.92 t=0.0ps kin=1.56 pot=21.57 Rg=16.010 SPS=18409
# bl=131 pos[1]=[-2.9 -12.5 5.8] dr=1.97 t=0.0ps kin=1.52 pot=21.50 Rg=16.010 SPS=17770
# bl=132 pos[1]=[-1.0 -12.3 6.9] dr=1.86 t=0.0ps kin=1.53 pot=21.51 Rg=15.930 SPS=17885
# bl=133 pos[1]=[-0.9 -10.6 6.2] dr=1.88 t=0.0ps kin=1.50 pot=21.51 Rg=15.884 SPS=17567
# bl=134 pos[1]=[3.2 -12.6 7.3] dr=1.94 t=0.0ps kin=1.45 pot=21.55 Rg=15.979 SPS=18171
# bl=135 pos[1]=[4.9 -11.9 10.2] dr=1.89 t=0.0ps kin=1.49 pot=21.55 Rg=16.087 SPS=18702
# bl=136 pos[1]=[3.6 -10.5 13.8] dr=1.87 t=0.0ps kin=1.53 pot=21.47 Rg=16.199 SPS=17934
# bl=137 pos[1]=[3.5 -12.9 13.9] dr=1.92 t=0.0ps kin=1.50 pot=21.52 Rg=16.239 SPS=17822
# bl=138 pos[1]=[3.3 -14.5 12.0] dr=1.92 t=0.0ps kin=1.53 pot=21.53 Rg=16.257 SPS=18579
# bl=139 pos[1]=[4.0 -13.2 9.7] dr=1.92 t=0.0ps kin=1.52 pot=21.51 Rg=16.214 SPS=17656
# bl=140 pos[1]=[5.3 -12.9 9.9] dr=1.90 t=0.0ps kin=1.50 pot=21.56 Rg=16.077 SPS=19000
# bl=141 pos[1]=[6.4 -13.2 9.6] dr=1.92 t=0.0ps kin=1.53 pot=21.52 Rg=16.027 SPS=18340
# bl=142 pos[1]=[3.5 -12.0 8.4] dr=1.99 t=0.0ps kin=1.49 pot=21.51 Rg=15.934 SPS=17388
# bl=143 pos[1]=[1.1 -14.5 9.5] dr=1.92 t=0.0ps kin=1.51 pot=21.54 Rg=15.935 SPS=17510
# bl=144 pos[1]=[1.0 -14.4 8.3] dr=1.87 t=0.0ps kin=1.52 pot=21.53 Rg=15.994 SPS=17593
# bl=145 pos[1]=[1.3 -14.6 8.9] dr=1.88 t=0.0ps kin=1.47 pot=21.52 Rg=16.065 SPS=17937
# bl=146 pos[1]=[2.0 -13.5 8.7] dr=1.85 t=0.0ps kin=1.45 pot=21.54 Rg=16.105 SPS=17435
# bl=147 pos[1]=[1.5 -14.8 7.3] dr=1.90 t=0.0ps kin=1.49 pot=21.54 Rg=16.132 SPS=16944
# bl=148 pos[1]=[0.0 -16.7 8.3] dr=1.96 t=0.0ps kin=1.57 pot=21.50 Rg=16.103 SPS=17553
# bl=149 pos[1]=[-0.7 -15.7 6.4] dr=1.90 t=0.0ps kin=1.49 pot=21.50 Rg=16.106 SPS=18783
#
# Statistics for the simulation opt_chr10_100K, number of particles: 1356,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [ 0.3955844  -2.16987902 -2.33728494]   Rg =  16.106
#      median bond size is  0.9676073806011394
#      three shortest/longest (<10)/ bonds are  [0.88403753 0.88564089 0.89040627]    [1.0883895  1.09207766 1.1361758 ]
#      95 percentile of distance to center is:    22.093502919860068
#      density of closest 95% monomers is:    0.0285168104993717
#      density of the core monomers is:    0.02714125418291168
#      min/median/mean/max coordinates are:
#      x: -21.04, 0.08, 0.40, 19.72
#      y: -25.74, -1.96, -2.17, 19.35
#      z: -21.01, -1.34, -2.34, 13.43
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4953820346761537 should be: 1.5
#      fastest particles are (in kT):  [6.53773969 6.59641246 6.77899351 6.88137142 9.61808962]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'CustomTypes']
#      Number of exceptions:   1355
#
# Potential Energy Ep =  21.495746623801622
# bl=150 pos[1]=[-1.0 -15.1 7.5] dr=1.95 t=0.0ps kin=1.51 pot=21.51 Rg=16.231 SPS=17784
# bl=151 pos[1]=[1.0 -15.2 9.4] dr=1.90 t=0.0ps kin=1.54 pot=21.50 Rg=16.341 SPS=17452
# bl=152 pos[1]=[2.0 -16.9 7.7] dr=1.88 t=0.0ps kin=1.52 pot=21.53 Rg=16.317 SPS=17902
# bl=153 pos[1]=[2.3 -18.8 4.6] dr=1.87 t=0.0ps kin=1.49 pot=21.49 Rg=16.357 SPS=17752
# bl=154 pos[1]=[1.0 -20.6 4.8] dr=1.89 t=0.0ps kin=1.52 pot=21.49 Rg=16.441 SPS=18202
# bl=155 pos[1]=[1.4 -18.9 4.6] dr=1.92 t=0.0ps kin=1.47 pot=21.51 Rg=16.429 SPS=18128
# bl=156 pos[1]=[-2.7 -18.6 5.6] dr=1.90 t=0.0ps kin=1.46 pot=21.53 Rg=16.462 SPS=17624
# bl=157 pos[1]=[-3.4 -16.8 6.1] dr=1.86 t=0.0ps kin=1.51 pot=21.51 Rg=16.421 SPS=17684
# bl=158 pos[1]=[-2.2 -16.1 6.5] dr=1.90 t=0.0ps kin=1.51 pot=21.52 Rg=16.355 SPS=18936
# bl=159 pos[1]=[-1.4 -18.4 6.1] dr=1.98 t=0.0ps kin=1.54 pot=21.46 Rg=16.247 SPS=17856
# bl=160 pos[1]=[0.5 -18.4 9.7] dr=1.98 t=0.0ps kin=1.50 pot=21.49 Rg=16.225 SPS=17837
# bl=161 pos[1]=[0.2 -16.6 12.9] dr=1.93 t=0.0ps kin=1.46 pot=21.53 Rg=16.075 SPS=17144
# bl=162 pos[1]=[0.5 -16.0 12.1] dr=1.96 t=0.0ps kin=1.51 pot=21.56 Rg=15.968 SPS=16907
# bl=163 pos[1]=[1.6 -16.2 10.2] dr=2.00 t=0.0ps kin=1.54 pot=21.53 Rg=15.939 SPS=16802
# bl=164 pos[1]=[0.6 -16.1 11.1] dr=1.93 t=0.0ps kin=1.49 pot=21.55 Rg=16.045 SPS=17450
# bl=165 pos[1]=[1.2 -12.5 9.5] dr=1.90 t=0.0ps kin=1.45 pot=21.51 Rg=16.025 SPS=17604
# bl=166 pos[1]=[0.7 -12.7 10.4] dr=1.87 t=0.0ps kin=1.44 pot=21.48 Rg=16.049 SPS=18475
# bl=167 pos[1]=[-0.1 -10.4 9.5] dr=1.87 t=0.0ps kin=1.46 pot=21.51 Rg=16.030 SPS=18375
# bl=168 pos[1]=[0.8 -13.2 8.2] dr=1.96 t=0.0ps kin=1.56 pot=21.51 Rg=16.093 SPS=17420
# bl=169 pos[1]=[1.7 -14.4 7.9] dr=2.00 t=0.0ps kin=1.51 pot=21.55 Rg=16.106 SPS=17095
# bl=170 pos[1]=[2.6 -16.1 7.3] dr=1.88 t=0.0ps kin=1.53 pot=21.55 Rg=16.105 SPS=17812
# bl=171 pos[1]=[2.5 -18.6 9.0] dr=1.92 t=0.0ps kin=1.51 pot=21.53 Rg=16.053 SPS=17990
# bl=172 pos[1]=[0.0 -21.3 9.7] dr=1.92 t=0.0ps kin=1.52 pot=21.53 Rg=16.204 SPS=18728
# bl=173 pos[1]=[-3.0 -18.8 9.6] dr=1.94 t=0.0ps kin=1.48 pot=21.53 Rg=16.189 SPS=18545
# bl=174 pos[1]=[-5.2 -17.8 11.7] dr=1.98 t=0.0ps kin=1.49 pot=21.54 Rg=16.144 SPS=18175
# bl=175 pos[1]=[-6.1 -18.7 11.9] dr=1.91 t=0.0ps kin=1.53 pot=21.50 Rg=16.165 SPS=17687
# bl=176 pos[1]=[-6.4 -17.9 9.5] dr=1.88 t=0.0ps kin=1.50 pot=21.60 Rg=16.115 SPS=18300
# bl=177 pos[1]=[-5.0 -17.2 8.3] dr=1.93 t=0.0ps kin=1.54 pot=21.56 Rg=16.200 SPS=18689
# bl=178 pos[1]=[-6.0 -16.2 8.7] dr=1.94 t=0.0ps kin=1.49 pot=21.52 Rg=16.297 SPS=17194
# bl=179 pos[1]=[-8.6 -13.3 8.7] dr=1.88 t=0.0ps kin=1.43 pot=21.51 Rg=16.305 SPS=16772
# bl=180 pos[1]=[-8.6 -12.1 6.2] dr=1.91 t=0.0ps kin=1.42 pot=21.50 Rg=16.226 SPS=17392
# bl=181 pos[1]=[-10.6 -13.2 7.5] dr=1.90 t=0.0ps kin=1.46 pot=21.48 Rg=16.081 SPS=16960
# bl=182 pos[1]=[-8.3 -11.9 9.5] dr=1.91 t=0.0ps kin=1.48 pot=21.54 Rg=16.066 SPS=16863
# bl=183 pos[1]=[-7.6 -10.4 8.0] dr=1.91 t=0.0ps kin=1.52 pot=21.50 Rg=16.148 SPS=16951
# bl=184 pos[1]=[-8.1 -12.0 8.8] dr=1.87 t=0.0ps kin=1.50 pot=21.56 Rg=16.205 SPS=16739
# bl=185 pos[1]=[-8.1 -13.1 7.0] dr=1.92 t=0.0ps kin=1.50 pot=21.53 Rg=16.257 SPS=17018
# bl=186 pos[1]=[-7.7 -13.9 5.6] dr=1.92 t=0.0ps kin=1.55 pot=21.52 Rg=16.322 SPS=16921
# bl=187 pos[1]=[-6.2 -13.1 4.5] dr=1.93 t=0.0ps kin=1.53 pot=21.50 Rg=16.311 SPS=17135
# bl=188 pos[1]=[-4.3 -14.8 2.1] dr=1.98 t=0.0ps kin=1.47 pot=21.54 Rg=16.375 SPS=17713
# bl=189 pos[1]=[-4.6 -14.6 2.9] dr=1.88 t=0.0ps kin=1.49 pot=21.49 Rg=16.493 SPS=17491
# bl=190 pos[1]=[-6.3 -17.3 6.3] dr=1.95 t=0.0ps kin=1.49 pot=21.50 Rg=16.535 SPS=17268
# bl=191 pos[1]=[-2.5 -19.2 7.9] dr=1.99 t=0.0ps kin=1.50 pot=21.55 Rg=16.560 SPS=17046
# bl=192 pos[1]=[-3.8 -20.8 6.6] dr=1.93 t=0.0ps kin=1.48 pot=21.55 Rg=16.524 SPS=17511
# bl=193 pos[1]=[-4.6 -20.4 3.5] dr=1.91 t=0.0ps kin=1.43 pot=21.55 Rg=16.508 SPS=16988
# bl=194 pos[1]=[-3.9 -18.6 0.5] dr=1.96 t=0.0ps kin=1.52 pot=21.50 Rg=16.648 SPS=18260
# bl=195 pos[1]=[-2.6 -17.6 0.5] dr=1.99 t=0.0ps kin=1.49 pot=21.49 Rg=16.756 SPS=17985
# bl=196 pos[1]=[1.2 -17.2 -1.1] dr=1.94 t=0.0ps kin=1.45 pot=21.48 Rg=16.728 SPS=18014
# bl=197 pos[1]=[2.1 -17.3 -1.0] dr=1.84 t=0.0ps kin=1.48 pot=21.52 Rg=16.665 SPS=18241
# bl=198 pos[1]=[5.6 -19.0 -1.5] dr=1.86 t=0.0ps kin=1.50 pot=21.52 Rg=16.683 SPS=17658
# bl=199 pos[1]=[4.1 -19.7 -0.4] dr=1.90 t=0.0ps kin=1.49 pot=21.52 Rg=16.661 SPS=17853
#
# Statistics for the simulation opt_chr10_100K, number of particles: 1356,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [ 0.46574305 -1.98369191 -1.72204101]   Rg =  16.660751
#      median bond size is  0.96530842269036
#      three shortest/longest (<10)/ bonds are  [0.88344923 0.88421928 0.88538336]    [1.07272131 1.0832057  1.09608652]
#      95 percentile of distance to center is:    24.624180997897753
#      density of closest 95% monomers is:    0.020597252892797194
#      density of the core monomers is:    0.054957908493900864
#      min/median/mean/max coordinates are:
#      x: -20.65, 0.91, 0.47, 22.33
#      y: -22.22, -1.52, -1.98, 24.47
#      z: -17.12, -1.74, -1.72, 18.75
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4926055052648535 should be: 1.5
#      fastest particles are (in kT):  [6.70128739 6.92560531 7.23482571 7.30277684 7.38038253]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'CustomTypes']
#      Number of exceptions:   1355
#
# Potential Energy Ep =  21.52352392146018
# bl=200 pos[1]=[4.0 -21.9 2.3] dr=1.89 t=0.0ps kin=1.49 pot=21.47 Rg=16.703 SPS=17127
# bl=201 pos[1]=[1.5 -21.0 3.1] dr=1.90 t=0.0ps kin=1.48 pot=21.51 Rg=16.807 SPS=17965
# bl=202 pos[1]=[-1.1 -21.2 0.9] dr=1.89 t=0.0ps kin=1.47 pot=21.53 Rg=16.772 SPS=17886
# bl=203 pos[1]=[-1.6 -22.7 1.0] dr=1.86 t=0.0ps kin=1.51 pot=21.54 Rg=16.738 SPS=16776
# bl=204 pos[1]=[-3.1 -21.7 -0.5] dr=1.94 t=0.0ps kin=1.47 pot=21.53 Rg=16.738 SPS=17997
# bl=205 pos[1]=[-2.6 -22.4 1.5] dr=1.90 t=0.0ps kin=1.51 pot=21.55 Rg=16.877 SPS=17706
# bl=206 pos[1]=[-3.2 -21.8 2.2] dr=1.88 t=0.0ps kin=1.51 pot=21.49 Rg=16.943 SPS=17644
# bl=207 pos[1]=[-5.3 -21.2 2.4] dr=1.92 t=0.0ps kin=1.51 pot=21.50 Rg=16.804 SPS=17532
# bl=208 pos[1]=[-1.6 -21.1 2.5] dr=1.96 t=0.0ps kin=1.43 pot=21.54 Rg=16.769 SPS=17221
# bl=209 pos[1]=[-1.8 -23.3 -0.3] dr=1.93 t=0.0ps kin=1.50 pot=21.52 Rg=16.775 SPS=18202
# bl=210 pos[1]=[-2.2 -22.9 -1.4] dr=2.02 t=0.0ps kin=1.60 pot=21.47 Rg=16.963 SPS=18431
# bl=211 pos[1]=[-2.6 -20.9 1.6] dr=1.91 t=0.0ps kin=1.54 pot=21.59 Rg=17.139 SPS=17678
# bl=212 pos[1]=[-4.3 -21.7 1.0] dr=1.98 t=0.0ps kin=1.54 pot=21.54 Rg=17.247 SPS=16637
# bl=213 pos[1]=[-5.4 -21.9 3.7] dr=1.94 t=0.0ps kin=1.52 pot=21.47 Rg=17.309 SPS=19014
# bl=214 pos[1]=[-4.7 -22.4 3.9] dr=1.86 t=0.0ps kin=1.52 pot=21.51 Rg=17.302 SPS=17933
# bl=215 pos[1]=[-5.8 -18.6 6.9] dr=1.94 t=0.0ps kin=1.45 pot=21.53 Rg=17.296 SPS=17355
# bl=216 pos[1]=[-4.4 -16.9 10.1] dr=1.82 t=0.0ps kin=1.46 pot=21.50 Rg=17.313 SPS=17562
# bl=217 pos[1]=[-4.2 -18.7 6.4] dr=1.93 t=0.0ps kin=1.47 pot=21.47 Rg=17.275 SPS=18053
# bl=218 pos[1]=[-5.1 -18.2 6.2] dr=1.91 t=0.0ps kin=1.48 pot=21.50 Rg=17.200 SPS=17219
# bl=219 pos[1]=[-4.2 -15.1 6.4] dr=1.88 t=0.0ps kin=1.55 pot=21.51 Rg=17.234 SPS=16924
# bl=220 pos[1]=[-0.5 -15.7 3.8] dr=1.94 t=0.0ps kin=1.56 pot=21.54 Rg=17.262 SPS=18422
# bl=221 pos[1]=[1.3 -14.1 2.2] dr=1.94 t=0.0ps kin=1.51 pot=21.51 Rg=17.212 SPS=18929
# bl=222 pos[1]=[3.5 -12.5 2.9] dr=1.94 t=0.0ps kin=1.48 pot=21.54 Rg=17.130 SPS=18319
# bl=223 pos[1]=[4.1 -9.9 5.5] dr=1.90 t=0.0ps kin=1.49 pot=21.48 Rg=17.194 SPS=18309
# bl=224 pos[1]=[4.6 -10.5 4.8] dr=1.94 t=0.0ps kin=1.51 pot=21.54 Rg=17.230 SPS=17752
# bl=225 pos[1]=[4.4 -11.2 6.1] dr=1.92 t=0.0ps kin=1.54 pot=21.52 Rg=17.163 SPS=17358
# bl=226 pos[1]=[3.0 -12.6 8.7] dr=2.03 t=0.0ps kin=1.57 pot=21.55 Rg=17.292 SPS=16937
# bl=227 pos[1]=[5.8 -14.2 7.6] dr=1.93 t=0.0ps kin=1.48 pot=21.52 Rg=17.515 SPS=17888
# bl=228 pos[1]=[4.9 -15.3 6.7] dr=1.91 t=0.0ps kin=1.48 pot=21.51 Rg=17.612 SPS=18158
# bl=229 pos[1]=[7.8 -18.2 9.0] dr=1.93 t=0.0ps kin=1.53 pot=21.54 Rg=17.678 SPS=18723
# bl=230 pos[1]=[7.8 -20.6 10.7] dr=1.89 t=0.0ps kin=1.51 pot=21.53 Rg=17.518 SPS=18642
# bl=231 pos[1]=[8.9 -20.3 12.2] dr=1.93 t=0.0ps kin=1.54 pot=21.49 Rg=17.305 SPS=18510
# bl=232 pos[1]=[10.2 -19.2 11.2] dr=1.88 t=0.0ps kin=1.45 pot=21.52 Rg=17.313 SPS=18167
# bl=233 pos[1]=[10.6 -18.8 12.0] dr=1.88 t=0.0ps kin=1.55 pot=21.50 Rg=17.354 SPS=17410
# bl=234 pos[1]=[8.7 -22.1 12.5] dr=1.90 t=0.0ps kin=1.49 pot=21.54 Rg=17.442 SPS=18695
# bl=235 pos[1]=[6.8 -19.8 11.6] dr=1.91 t=0.0ps kin=1.54 pot=21.50 Rg=17.498 SPS=18775
# bl=236 pos[1]=[7.7 -16.7 12.9] dr=1.89 t=0.0ps kin=1.51 pot=21.49 Rg=17.538 SPS=17984
# bl=237 pos[1]=[8.0 -15.0 13.8] dr=1.89 t=0.0ps kin=1.53 pot=21.53 Rg=17.601 SPS=16819
# bl=238 pos[1]=[5.5 -19.2 15.1] dr=1.91 t=0.0ps kin=1.53 pot=21.52 Rg=17.569 SPS=17507
# bl=239 pos[1]=[6.7 -19.4 13.1] dr=1.93 t=0.0ps kin=1.49 pot=21.53 Rg=17.491 SPS=17725
# bl=240 pos[1]=[3.3 -17.4 10.5] dr=1.87 t=0.0ps kin=1.45 pot=21.50 Rg=17.456 SPS=18336
# bl=241 pos[1]=[2.1 -18.5 7.5] dr=1.87 t=0.0ps kin=1.42 pot=21.51 Rg=17.403 SPS=18321
# bl=242 pos[1]=[1.9 -18.6 7.5] dr=1.88 t=0.0ps kin=1.53 pot=21.47 Rg=17.380 SPS=17723
# bl=243 pos[1]=[1.0 -18.8 6.1] dr=1.91 t=0.0ps kin=1.47 pot=21.54 Rg=17.351 SPS=16931
# bl=244 pos[1]=[1.0 -20.2 5.4] dr=1.92 t=0.0ps kin=1.52 pot=21.47 Rg=17.279 SPS=17247
# bl=245 pos[1]=[1.4 -23.4 6.8] dr=1.88 t=0.0ps kin=1.52 pot=21.51 Rg=17.257 SPS=18358
# bl=246 pos[1]=[-0.4 -22.9 9.1] dr=1.87 t=0.0ps kin=1.49 pot=21.51 Rg=17.279 SPS=18391
# bl=247 pos[1]=[0.3 -20.8 9.3] dr=1.94 t=0.0ps kin=1.56 pot=21.51 Rg=17.241 SPS=18194
# bl=248 pos[1]=[-0.1 -20.3 7.8] dr=1.91 t=0.0ps kin=1.55 pot=21.52 Rg=17.217 SPS=17024
# bl=249 pos[1]=[3.0 -20.1 7.7] dr=1.99 t=0.0ps kin=1.59 pot=21.48 Rg=17.339 SPS=16887
#
# Statistics for the simulation opt_chr10_100K, number of particles: 1356,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [ 1.07048744 -2.37814791 -2.31064257]   Rg =  17.33892
#      median bond size is  0.9680621274947117
#      three shortest/longest (<10)/ bonds are  [0.87035943 0.88699315 0.88895872]    [1.07900698 1.08583165 1.10318548]
#      95 percentile of distance to center is:    24.369216910901162
#      density of closest 95% monomers is:    0.02125053971503314
#      density of the core monomers is:    0.041956968555376874
#      min/median/mean/max coordinates are:
#      x: -16.52, 0.86, 1.07, 23.00
#      y: -22.90, -4.10, -2.38, 24.62
#      z: -20.55, -2.83, -2.31, 25.06
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5977372510252068 should be: 1.5
#      fastest particles are (in kT):  [7.45903861 7.6184961  8.10328185 8.66741291 9.39034269]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'CustomTypes']
#      Number of exceptions:   1355
#
# Potential Energy Ep =  21.479037034476402
# bl=250 pos[1]=[2.6 -20.1 5.3] dr=1.88 t=0.0ps kin=1.52 pot=21.53 Rg=17.477 SPS=16898
# bl=251 pos[1]=[0.7 -20.7 6.5] dr=1.97 t=0.0ps kin=1.47 pot=21.49 Rg=17.611 SPS=16840
# bl=252 pos[1]=[-1.4 -23.6 9.6] dr=1.88 t=0.0ps kin=1.51 pot=21.48 Rg=17.799 SPS=17484
# bl=253 pos[1]=[-1.9 -22.7 9.9] dr=1.89 t=0.0ps kin=1.53 pot=21.50 Rg=17.962 SPS=17449
# bl=254 pos[1]=[-1.3 -21.6 12.5] dr=1.97 t=0.0ps kin=1.53 pot=21.52 Rg=18.097 SPS=16942
# bl=255 pos[1]=[-0.8 -20.7 12.6] dr=1.89 t=0.0ps kin=1.52 pot=21.50 Rg=18.179 SPS=18264
# bl=256 pos[1]=[-0.4 -18.8 14.2] dr=1.89 t=0.0ps kin=1.48 pot=21.55 Rg=18.229 SPS=18407
# bl=257 pos[1]=[0.3 -17.4 13.2] dr=1.87 t=0.0ps kin=1.49 pot=21.49 Rg=18.368 SPS=17421
# bl=258 pos[1]=[-0.8 -18.0 11.3] dr=1.90 t=0.0ps kin=1.49 pot=21.53 Rg=18.499 SPS=17812
# bl=259 pos[1]=[-1.8 -18.5 11.7] dr=1.89 t=0.0ps kin=1.52 pot=21.52 Rg=18.442 SPS=18579
# bl=260 pos[1]=[-2.9 -17.5 11.5] dr=1.91 t=0.0ps kin=1.52 pot=21.51 Rg=18.346 SPS=17264
# bl=261 pos[1]=[-3.1 -16.9 13.1] dr=1.91 t=0.0ps kin=1.52 pot=21.51 Rg=18.239 SPS=17001
# bl=262 pos[1]=[-6.3 -15.9 10.9] dr=1.85 t=0.0ps kin=1.45 pot=21.50 Rg=18.257 SPS=17505
# bl=263 pos[1]=[-7.0 -14.8 11.8] dr=1.85 t=0.0ps kin=1.47 pot=21.49 Rg=18.330 SPS=18160
# bl=264 pos[1]=[-5.9 -15.7 10.7] dr=1.93 t=0.0ps kin=1.55 pot=21.51 Rg=18.332 SPS=17204
# bl=265 pos[1]=[-6.1 -16.5 11.5] dr=1.92 t=0.0ps kin=1.45 pot=21.52 Rg=18.289 SPS=17791
# bl=266 pos[1]=[-4.4 -20.7 9.9] dr=1.83 t=0.0ps kin=1.50 pot=21.50 Rg=18.381 SPS=17029
# bl=267 pos[1]=[-5.0 -18.5 9.5] dr=1.96 t=0.0ps kin=1.50 pot=21.55 Rg=18.456 SPS=18106
# bl=268 pos[1]=[-4.0 -18.7 9.3] dr=1.97 t=0.0ps kin=1.48 pot=21.51 Rg=18.406 SPS=18798
# bl=269 pos[1]=[-6.2 -16.2 13.3] dr=1.94 t=0.0ps kin=1.44 pot=21.51 Rg=18.362 SPS=18569
# bl=270 pos[1]=[-5.7 -16.9 15.0] dr=1.90 t=0.0ps kin=1.47 pot=21.51 Rg=18.432 SPS=16971
# bl=271 pos[1]=[-6.1 -18.5 16.5] dr=1.91 t=0.0ps kin=1.47 pot=21.50 Rg=18.495 SPS=17985
# bl=272 pos[1]=[-2.1 -19.4 17.8] dr=1.96 t=0.0ps kin=1.48 pot=21.50 Rg=18.545 SPS=18037
# bl=273 pos[1]=[-1.8 -18.3 16.3] dr=1.91 t=0.0ps kin=1.50 pot=21.53 Rg=18.540 SPS=17705
# bl=274 pos[1]=[-1.1 -18.1 16.6] dr=1.92 t=0.0ps kin=1.52 pot=21.54 Rg=18.613 SPS=17707
# bl=275 pos[1]=[-1.0 -19.0 16.0] dr=1.97 t=0.0ps kin=1.56 pot=21.52 Rg=18.731 SPS=17100
# bl=276 pos[1]=[-1.0 -18.4 15.4] dr=1.92 t=0.0ps kin=1.49 pot=21.54 Rg=18.776 SPS=17373
# bl=277 pos[1]=[-0.1 -19.2 11.2] dr=1.89 t=0.0ps kin=1.45 pot=21.52 Rg=18.710 SPS=17225
# bl=278 pos[1]=[0.2 -17.5 9.3] dr=1.87 t=0.0ps kin=1.47 pot=21.52 Rg=18.750 SPS=16603
# bl=279 pos[1]=[0.9 -17.0 8.4] dr=1.94 t=0.0ps kin=1.50 pot=21.50 Rg=18.676 SPS=16906
# bl=280 pos[1]=[-1.2 -18.9 6.1] dr=1.96 t=0.0ps kin=1.50 pot=21.49 Rg=18.760 SPS=17628
# bl=281 pos[1]=[-1.7 -18.8 5.3] dr=1.93 t=0.0ps kin=1.47 pot=21.51 Rg=18.744 SPS=16560
# bl=282 pos[1]=[-0.8 -20.0 6.4] dr=1.88 t=0.0ps kin=1.51 pot=21.53 Rg=18.620 SPS=16393
# bl=283 pos[1]=[2.2 -23.4 6.3] dr=1.96 t=0.0ps kin=1.49 pot=21.45 Rg=18.523 SPS=17104
# bl=284 pos[1]=[3.9 -23.0 6.0] dr=1.88 t=0.0ps kin=1.45 pot=21.52 Rg=18.639 SPS=16996
# bl=285 pos[1]=[3.6 -19.9 4.0] dr=1.86 t=0.0ps kin=1.47 pot=21.49 Rg=18.799 SPS=16857
# bl=286 pos[1]=[3.0 -17.7 5.3] dr=1.95 t=0.0ps kin=1.49 pot=21.49 Rg=18.836 SPS=17209
# bl=287 pos[1]=[1.4 -20.7 6.5] dr=1.96 t=0.0ps kin=1.45 pot=21.55 Rg=18.738 SPS=17566
# bl=288 pos[1]=[2.0 -24.4 6.9] dr=1.96 t=0.0ps kin=1.53 pot=21.54 Rg=18.682 SPS=16893
# bl=289 pos[1]=[4.2 -25.9 5.2] dr=1.99 t=0.0ps kin=1.50 pot=21.57 Rg=18.634 SPS=18645
# bl=290 pos[1]=[3.7 -25.5 8.4] dr=2.01 t=0.0ps kin=1.52 pot=21.53 Rg=18.587 SPS=19282
# bl=291 pos[1]=[6.0 -27.4 8.0] dr=1.90 t=0.0ps kin=1.53 pot=21.49 Rg=18.585 SPS=17412
# bl=292 pos[1]=[7.1 -29.5 7.4] dr=1.88 t=0.0ps kin=1.52 pot=21.51 Rg=18.583 SPS=17972
# bl=293 pos[1]=[10.0 -28.9 9.4] dr=1.94 t=0.0ps kin=1.53 pot=21.54 Rg=18.554 SPS=17493
# bl=294 pos[1]=[9.2 -29.6 9.6] dr=1.98 t=0.0ps kin=1.53 pot=21.46 Rg=18.549 SPS=18315
# bl=295 pos[1]=[6.5 -28.5 7.9] dr=1.92 t=0.0ps kin=1.51 pot=21.49 Rg=18.476 SPS=17085
# bl=296 pos[1]=[7.0 -29.2 6.5] dr=1.94 t=0.0ps kin=1.51 pot=21.47 Rg=18.380 SPS=18496
# bl=297 pos[1]=[4.8 -27.3 5.8] dr=1.92 t=0.0ps kin=1.47 pot=21.48 Rg=18.439 SPS=18701
# bl=298 pos[1]=[4.9 -29.0 6.8] dr=1.87 t=0.0ps kin=1.44 pot=21.51 Rg=18.311 SPS=18141
# bl=299 pos[1]=[7.3 -29.0 7.6] dr=1.92 t=0.0ps kin=1.56 pot=21.51 Rg=18.285 SPS=18129
#
# Statistics for the simulation opt_chr10_100K, number of particles: 1356,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [ 2.09631257 -2.13393333 -0.77457297]   Rg =  18.28549
#      median bond size is  0.9688292987519572
#      three shortest/longest (<10)/ bonds are  [0.87966    0.88493206 0.88765188]    [1.0910917  1.09299757 1.09763014]
#      95 percentile of distance to center is:    26.950637089410925
#      density of closest 95% monomers is:    0.015710412114139993
#      density of the core monomers is:    0.047966418990545434
#      min/median/mean/max coordinates are:
#      x: -19.98, 2.05, 2.10, 21.49
#      y: -28.99, -3.92, -2.13, 28.39
#      z: -21.51, -1.04, -0.77, 22.79
#
# Statistics for velocities:
#      mean kinetic energy is:  1.5667172263442366 should be: 1.5
#      fastest particles are (in kT):  [7.96111179 8.19872701 8.91857226 9.44663236 9.66619122]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'CustomTypes']
#      Number of exceptions:   1355
#
# Potential Energy Ep =  21.513733810379794
# bl=300 pos[1]=[8.2 -28.8 10.9] dr=1.93 t=0.0ps kin=1.51 pot=21.52 Rg=18.296 SPS=17194
# bl=301 pos[1]=[6.6 -26.1 9.7] dr=1.93 t=0.0ps kin=1.49 pot=21.49 Rg=18.278 SPS=17352
# bl=302 pos[1]=[7.1 -25.9 6.8] dr=1.94 t=0.0ps kin=1.46 pot=21.50 Rg=18.237 SPS=17517
# bl=303 pos[1]=[6.8 -25.5 6.0] dr=1.97 t=0.0ps kin=1.52 pot=21.49 Rg=18.251 SPS=17564
# bl=304 pos[1]=[7.2 -25.7 7.0] dr=1.88 t=0.0ps kin=1.50 pot=21.48 Rg=18.199 SPS=17076
# bl=305 pos[1]=[7.5 -25.2 5.9] dr=1.96 t=0.0ps kin=1.52 pot=21.51 Rg=18.294 SPS=16984
# bl=306 pos[1]=[9.5 -28.3 5.0] dr=1.91 t=0.0ps kin=1.52 pot=21.50 Rg=18.259 SPS=18129
# bl=307 pos[1]=[10.6 -28.4 8.8] dr=1.91 t=0.0ps kin=1.44 pot=21.50 Rg=18.273 SPS=17992
# bl=308 pos[1]=[10.5 -27.9 9.7] dr=1.88 t=0.0ps kin=1.45 pot=21.55 Rg=18.199 SPS=18019
# bl=309 pos[1]=[11.0 -26.8 10.9] dr=1.97 t=0.0ps kin=1.53 pot=21.51 Rg=18.214 SPS=18019
# bl=310 pos[1]=[9.9 -25.8 12.3] dr=1.91 t=0.0ps kin=1.51 pot=21.49 Rg=18.244 SPS=18247
# bl=311 pos[1]=[11.4 -26.4 12.3] dr=1.90 t=0.0ps kin=1.50 pot=21.50 Rg=18.179 SPS=16784
# bl=312 pos[1]=[11.7 -28.7 9.8] dr=1.88 t=0.0ps kin=1.53 pot=21.50 Rg=18.218 SPS=17550
# bl=313 pos[1]=[11.7 -26.5 10.6] dr=1.93 t=0.0ps kin=1.48 pot=21.49 Rg=18.332 SPS=18782
# bl=314 pos[1]=[11.2 -23.2 11.2] dr=1.92 t=0.0ps kin=1.51 pot=21.51 Rg=18.425 SPS=18296
# bl=315 pos[1]=[11.2 -24.0 11.0] dr=1.89 t=0.0ps kin=1.51 pot=21.57 Rg=18.420 SPS=18165
# bl=316 pos[1]=[8.7 -21.9 11.9] dr=1.93 t=0.0ps kin=1.55 pot=21.53 Rg=18.227 SPS=16827
# bl=317 pos[1]=[4.0 -23.1 11.5] dr=1.87 t=0.0ps kin=1.46 pot=21.52 Rg=18.122 SPS=17087
# bl=318 pos[1]=[4.1 -24.1 10.8] dr=1.90 t=0.0ps kin=1.50 pot=21.53 Rg=18.124 SPS=16825
# bl=319 pos[1]=[6.0 -25.2 9.2] dr=1.90 t=0.0ps kin=1.49 pot=21.55 Rg=18.184 SPS=18125
# bl=320 pos[1]=[8.9 -26.1 9.0] dr=1.87 t=0.0ps kin=1.46 pot=21.48 Rg=18.275 SPS=17466
# bl=321 pos[1]=[6.8 -26.6 7.6] dr=1.89 t=0.0ps kin=1.45 pot=21.51 Rg=18.309 SPS=18320
# bl=322 pos[1]=[5.3 -25.2 8.7] dr=1.87 t=0.0ps kin=1.47 pot=21.53 Rg=18.423 SPS=17102
# bl=323 pos[1]=[7.2 -26.1 10.3] dr=1.99 t=0.0ps kin=1.55 pot=21.51 Rg=18.481 SPS=18018
# bl=324 pos[1]=[9.8 -27.9 8.9] dr=2.01 t=0.0ps kin=1.55 pot=21.52 Rg=18.469 SPS=17710
# bl=325 pos[1]=[11.1 -29.5 5.5] dr=1.97 t=0.0ps kin=1.56 pot=21.55 Rg=18.477 SPS=17977
# bl=326 pos[1]=[12.4 -29.2 4.5] dr=1.91 t=0.0ps kin=1.54 pot=21.53 Rg=18.452 SPS=17479
# bl=327 pos[1]=[11.6 -29.9 1.9] dr=1.93 t=0.0ps kin=1.49 pot=21.52 Rg=18.488 SPS=18501
# bl=328 pos[1]=[11.2 -29.8 2.9] dr=1.92 t=0.0ps kin=1.49 pot=21.54 Rg=18.611 SPS=18272
# bl=329 pos[1]=[9.9 -28.6 1.6] dr=1.87 t=0.0ps kin=1.52 pot=21.55 Rg=18.797 SPS=18425
# bl=330 pos[1]=[6.5 -27.0 -0.3] dr=1.96 t=0.0ps kin=1.49 pot=21.54 Rg=18.976 SPS=17115
# bl=331 pos[1]=[3.0 -24.9 -0.7] dr=1.93 t=0.0ps kin=1.53 pot=21.53 Rg=19.053 SPS=17985
# bl=332 pos[1]=[3.8 -21.3 -1.9] dr=1.91 t=0.0ps kin=1.45 pot=21.55 Rg=19.111 SPS=17689
# bl=333 pos[1]=[2.7 -21.5 2.2] dr=1.92 t=0.0ps kin=1.52 pot=21.51 Rg=19.141 SPS=18270
# bl=334 pos[1]=[5.0 -20.7 2.6] dr=1.97 t=0.0ps kin=1.54 pot=21.47 Rg=19.240 SPS=18027
# bl=335 pos[1]=[2.6 -25.1 2.1] dr=1.93 t=0.0ps kin=1.46 pot=21.53 Rg=19.196 SPS=16756
# bl=336 pos[1]=[3.1 -27.3 3.8] dr=1.92 t=0.0ps kin=1.55 pot=21.53 Rg=19.116 SPS=17372
# bl=337 pos[1]=[5.4 -26.2 3.8] dr=1.91 t=0.0ps kin=1.53 pot=21.50 Rg=19.102 SPS=16841
# bl=338 pos[1]=[5.2 -25.3 4.5] dr=1.88 t=0.0ps kin=1.50 pot=21.51 Rg=19.129 SPS=16883
# bl=339 pos[1]=[3.6 -23.3 6.2] dr=1.91 t=0.0ps kin=1.50 pot=21.53 Rg=19.180 SPS=17289
# bl=340 pos[1]=[5.4 -22.0 6.1] dr=1.91 t=0.0ps kin=1.51 pot=21.48 Rg=19.158 SPS=17998
# bl=341 pos[1]=[4.1 -21.3 5.1] dr=1.95 t=0.0ps kin=1.56 pot=21.48 Rg=19.163 SPS=18041
# bl=342 pos[1]=[6.5 -20.9 5.3] dr=1.98 t=0.0ps kin=1.51 pot=21.49 Rg=19.235 SPS=18027
# bl=343 pos[1]=[7.1 -22.4 4.2] dr=2.00 t=0.0ps kin=1.44 pot=21.56 Rg=19.239 SPS=17161
# bl=344 pos[1]=[8.9 -19.0 1.3] dr=1.91 t=0.0ps kin=1.48 pot=21.47 Rg=19.209 SPS=17516
# bl=345 pos[1]=[12.4 -16.4 0.2] dr=1.99 t=0.0ps kin=1.48 pot=21.51 Rg=19.193 SPS=18848
# bl=346 pos[1]=[13.3 -15.1 1.2] dr=1.93 t=0.0ps kin=1.45 pot=21.49 Rg=19.136 SPS=18380
# bl=347 pos[1]=[14.2 -15.0 -0.3] dr=1.88 t=0.0ps kin=1.52 pot=21.49 Rg=19.081 SPS=17169
# bl=348 pos[1]=[14.0 -14.2 2.5] dr=1.93 t=0.0ps kin=1.57 pot=21.49 Rg=19.112 SPS=17829
# bl=349 pos[1]=[13.8 -12.1 1.5] dr=1.91 t=0.0ps kin=1.48 pot=21.49 Rg=19.082 SPS=17120
#
# Statistics for the simulation opt_chr10_100K, number of particles: 1356,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [ 1.66462897 -1.27931647 -1.43918024]   Rg =  19.08176
#      median bond size is  0.9664581121271456
#      three shortest/longest (<10)/ bonds are  [0.89022093 0.89306854 0.89339459]    [1.08832165 1.10181164 1.11194387]
#      95 percentile of distance to center is:    28.83606672437731
#      density of closest 95% monomers is:    0.012825863694581541
#      density of the core monomers is:    0.03290931019065132
#      min/median/mean/max coordinates are:
#      x: -18.90, 2.54, 1.66, 23.12
#      y: -22.58, -3.73, -1.28, 33.21
#      z: -23.21, -0.94, -1.44, 22.89
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4770665479018352 should be: 1.5
#      fastest particles are (in kT):  [6.13822407 6.4708541  7.39615011 7.76043692 7.8582537 ]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'CustomTypes']
#      Number of exceptions:   1355
#
# Potential Energy Ep =  21.487690703355458
# bl=350 pos[1]=[13.7 -14.2 4.9] dr=1.89 t=0.0ps kin=1.51 pot=21.48 Rg=19.027 SPS=17779
# bl=351 pos[1]=[11.6 -13.9 5.7] dr=1.95 t=0.0ps kin=1.47 pot=21.50 Rg=18.913 SPS=18891
# bl=352 pos[1]=[11.7 -13.1 7.0] dr=1.94 t=0.0ps kin=1.48 pot=21.51 Rg=18.799 SPS=18004
# bl=353 pos[1]=[9.5 -13.4 8.2] dr=1.97 t=0.0ps kin=1.54 pot=21.48 Rg=18.668 SPS=17512
# bl=354 pos[1]=[9.0 -11.5 8.7] dr=1.95 t=0.0ps kin=1.51 pot=21.47 Rg=18.769 SPS=18218
# bl=355 pos[1]=[7.5 -11.3 6.9] dr=1.86 t=0.0ps kin=1.53 pot=21.48 Rg=18.842 SPS=18310
# bl=356 pos[1]=[10.6 -8.3 5.3] dr=1.94 t=0.0ps kin=1.49 pot=21.51 Rg=18.756 SPS=18240
# bl=357 pos[1]=[7.6 -7.6 7.5] dr=1.96 t=0.0ps kin=1.53 pot=21.56 Rg=18.667 SPS=18669
# bl=358 pos[1]=[8.6 -7.7 6.9] dr=2.01 t=0.0ps kin=1.51 pot=21.52 Rg=18.622 SPS=17172
# bl=359 pos[1]=[9.4 -3.7 7.0] dr=1.92 t=0.0ps kin=1.48 pot=21.52 Rg=18.654 SPS=16775
# bl=360 pos[1]=[9.8 -1.3 3.7] dr=1.93 t=0.0ps kin=1.51 pot=21.48 Rg=18.592 SPS=18311
# bl=361 pos[1]=[12.1 0.3 2.3] dr=1.98 t=0.0ps kin=1.51 pot=21.52 Rg=18.547 SPS=17962
# bl=362 pos[1]=[11.6 -0.3 3.1] dr=1.95 t=0.0ps kin=1.53 pot=21.50 Rg=18.628 SPS=18761
# bl=363 pos[1]=[13.2 -1.4 3.3] dr=1.96 t=0.0ps kin=1.48 pot=21.52 Rg=18.545 SPS=17777
# bl=364 pos[1]=[10.3 -2.3 2.9] dr=1.96 t=0.0ps kin=1.53 pot=21.50 Rg=18.524 SPS=17886
# bl=365 pos[1]=[11.7 0.2 3.9] dr=1.91 t=0.0ps kin=1.55 pot=21.51 Rg=18.498 SPS=17910
# bl=366 pos[1]=[12.8 -0.0 6.3] dr=2.01 t=0.0ps kin=1.55 pot=21.50 Rg=18.362 SPS=16977
# bl=367 pos[1]=[12.1 -2.0 5.0] dr=1.95 t=0.0ps kin=1.49 pot=21.48 Rg=18.310 SPS=17217
# bl=368 pos[1]=[11.1 -2.2 7.0] dr=1.94 t=0.0ps kin=1.53 pot=21.51 Rg=18.327 SPS=17335
# bl=369 pos[1]=[10.2 0.6 7.5] dr=1.91 t=0.0ps kin=1.49 pot=21.51 Rg=18.207 SPS=18819
# bl=370 pos[1]=[12.5 2.4 7.1] dr=1.95 t=0.0ps kin=1.48 pot=21.50 Rg=18.138 SPS=18404
# bl=371 pos[1]=[10.7 0.0 9.4] dr=1.95 t=0.0ps kin=1.54 pot=21.50 Rg=18.173 SPS=17796
# bl=372 pos[1]=[9.7 1.3 11.5] dr=2.01 t=0.0ps kin=1.46 pot=21.52 Rg=18.205 SPS=17560
# bl=373 pos[1]=[8.7 -0.4 11.1] dr=1.93 t=0.0ps kin=1.59 pot=21.56 Rg=18.272 SPS=17411
# bl=374 pos[1]=[10.0 -4.0 8.4] dr=1.92 t=0.0ps kin=1.57 pot=21.49 Rg=18.384 SPS=18825
# bl=375 pos[1]=[10.1 -5.0 10.8] dr=1.93 t=0.0ps kin=1.50 pot=21.56 Rg=18.457 SPS=19222
# bl=376 pos[1]=[8.0 -5.2 9.3] dr=1.86 t=0.0ps kin=1.48 pot=21.50 Rg=18.483 SPS=17631
# bl=377 pos[1]=[9.5 -5.3 9.5] dr=1.91 t=0.0ps kin=1.56 pot=21.47 Rg=18.526 SPS=18578
# bl=378 pos[1]=[9.9 -5.4 11.5] dr=1.87 t=0.0ps kin=1.47 pot=21.52 Rg=18.510 SPS=18029
# bl=379 pos[1]=[11.3 -5.2 15.0] dr=1.88 t=0.0ps kin=1.48 pot=21.50 Rg=18.514 SPS=17897
# bl=380 pos[1]=[12.6 -4.4 12.7] dr=1.92 t=0.0ps kin=1.45 pot=21.47 Rg=18.437 SPS=17407
# bl=381 pos[1]=[12.7 -4.5 11.7] dr=1.91 t=0.0ps kin=1.46 pot=21.50 Rg=18.327 SPS=17147
# bl=382 pos[1]=[12.2 -5.3 11.6] dr=1.98 t=0.0ps kin=1.50 pot=21.49 Rg=18.391 SPS=18053
# bl=383 pos[1]=[13.4 -7.3 11.6] dr=2.00 t=0.0ps kin=1.50 pot=21.48 Rg=18.383 SPS=18620
# bl=384 pos[1]=[13.9 -6.9 9.8] dr=1.94 t=0.0ps kin=1.50 pot=21.50 Rg=18.475 SPS=17685
# bl=385 pos[1]=[16.7 -6.4 9.0] dr=1.88 t=0.0ps kin=1.50 pot=21.53 Rg=18.575 SPS=18746
# bl=386 pos[1]=[15.5 -4.9 10.8] dr=1.90 t=0.0ps kin=1.51 pot=21.54 Rg=18.696 SPS=17716
# bl=387 pos[1]=[17.6 -4.1 8.2] dr=1.92 t=0.0ps kin=1.52 pot=21.54 Rg=18.786 SPS=17378
# bl=388 pos[1]=[17.5 -3.7 6.6] dr=1.96 t=0.0ps kin=1.52 pot=21.53 Rg=18.789 SPS=17420
# bl=389 pos[1]=[16.5 -4.3 4.1] dr=1.94 t=0.0ps kin=1.56 pot=21.50 Rg=18.776 SPS=17778
# bl=390 pos[1]=[17.5 -3.3 5.6] dr=2.01 t=0.0ps kin=1.48 pot=21.52 Rg=18.733 SPS=17386
# bl=391 pos[1]=[18.1 -3.6 7.1] dr=2.01 t=0.0ps kin=1.55 pot=21.51 Rg=18.637 SPS=17210
# bl=392 pos[1]=[16.7 -2.1 5.3] dr=1.95 t=0.0ps kin=1.52 pot=21.49 Rg=18.617 SPS=17261
# bl=393 pos[1]=[14.5 -3.5 5.9] dr=1.92 t=0.0ps kin=1.51 pot=21.51 Rg=18.546 SPS=18048
# bl=394 pos[1]=[14.7 -1.5 5.2] dr=1.95 t=0.0ps kin=1.52 pot=21.51 Rg=18.452 SPS=17421
# bl=395 pos[1]=[10.6 -4.6 7.3] dr=1.93 t=0.0ps kin=1.53 pot=21.59 Rg=18.464 SPS=16750
# bl=396 pos[1]=[10.0 -2.2 5.7] dr=1.92 t=0.0ps kin=1.53 pot=21.52 Rg=18.614 SPS=16789
# bl=397 pos[1]=[8.9 -3.9 6.9] dr=1.95 t=0.0ps kin=1.52 pot=21.53 Rg=18.791 SPS=18089
# bl=398 pos[1]=[9.0 -7.6 8.2] dr=1.91 t=0.0ps kin=1.51 pot=21.58 Rg=18.850 SPS=18007
# bl=399 pos[1]=[8.5 -7.8 11.0] dr=1.93 t=0.0ps kin=1.48 pot=21.49 Rg=18.839 SPS=18758
#
# Statistics for the simulation opt_chr10_100K, number of particles: 1356,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [ 0.06530078 -1.9308405  -0.11011067]   Rg =  18.839436
#      median bond size is  0.9667944000574894
#      three shortest/longest (<10)/ bonds are  [0.8821583  0.88587266 0.89173606]    [1.08801945 1.10101398 1.1138815 ]
#      95 percentile of distance to center is:    28.72540775013482
#      density of closest 95% monomers is:    0.012974662783731232
#      density of the core monomers is:    0.06886614937948349
#      min/median/mean/max coordinates are:
#      x: -19.65, -1.02, 0.07, 25.87
#      y: -26.58, -2.28, -1.93, 25.97
#      z: -23.06, -0.31, -0.11, 23.87
#
# Statistics for velocities:
#      mean kinetic energy is:  1.483789606606152 should be: 1.5
#      fastest particles are (in kT):  [6.53953617 6.59416806 6.94441046 7.23671965 9.41887791]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'CustomTypes']
#      Number of exceptions:   1355
#
# Potential Energy Ep =  21.494641869469028
# bl=400 pos[1]=[7.4 -7.6 10.8] dr=1.92 t=0.0ps kin=1.45 pot=21.48 Rg=18.956 SPS=17846
# bl=401 pos[1]=[8.6 -6.9 10.9] dr=1.88 t=0.0ps kin=1.50 pot=21.47 Rg=19.054 SPS=17863
# bl=402 pos[1]=[8.7 -7.2 10.9] dr=1.90 t=0.0ps kin=1.48 pot=21.48 Rg=19.093 SPS=17588
# bl=403 pos[1]=[8.7 -8.5 9.6] dr=1.95 t=0.0ps kin=1.51 pot=21.47 Rg=19.111 SPS=17943
# bl=404 pos[1]=[9.7 -9.2 9.0] dr=1.93 t=0.0ps kin=1.43 pot=21.56 Rg=19.131 SPS=16793
# bl=405 pos[1]=[11.1 -10.2 7.8] dr=1.94 t=0.0ps kin=1.58 pot=21.49 Rg=19.072 SPS=16989
# bl=406 pos[1]=[12.1 -11.3 6.3] dr=1.95 t=0.0ps kin=1.50 pot=21.54 Rg=19.085 SPS=16329
# bl=407 pos[1]=[11.3 -10.0 4.9] dr=1.94 t=0.0ps kin=1.52 pot=21.49 Rg=19.087 SPS=17399
# bl=408 pos[1]=[12.7 -10.1 5.1] dr=1.88 t=0.0ps kin=1.50 pot=21.50 Rg=18.947 SPS=18585
# bl=409 pos[1]=[13.5 -11.8 4.0] dr=1.93 t=0.0ps kin=1.49 pot=21.55 Rg=18.910 SPS=17920
# bl=410 pos[1]=[12.4 -8.9 4.1] dr=1.94 t=0.0ps kin=1.58 pot=21.52 Rg=18.847 SPS=17370
# bl=411 pos[1]=[13.2 -9.9 5.8] dr=1.94 t=0.0ps kin=1.53 pot=21.53 Rg=18.650 SPS=17151
# bl=412 pos[1]=[12.5 -9.9 8.3] dr=1.91 t=0.0ps kin=1.49 pot=21.53 Rg=18.530 SPS=17504
# bl=413 pos[1]=[14.1 -10.5 7.9] dr=1.91 t=0.0ps kin=1.46 pot=21.54 Rg=18.419 SPS=17731
# bl=414 pos[1]=[12.6 -12.4 9.8] dr=1.94 t=0.0ps kin=1.47 pot=21.53 Rg=18.335 SPS=17358
# bl=415 pos[1]=[12.6 -12.6 10.2] dr=1.89 t=0.0ps kin=1.47 pot=21.52 Rg=18.410 SPS=18332
# bl=416 pos[1]=[10.8 -11.8 10.0] dr=1.92 t=0.0ps kin=1.57 pot=21.47 Rg=18.477 SPS=17926
# bl=417 pos[1]=[9.5 -8.6 8.8] dr=1.93 t=0.0ps kin=1.45 pot=21.48 Rg=18.504 SPS=18482
# bl=418 pos[1]=[9.6 -9.2 9.2] dr=1.93 t=0.0ps kin=1.50 pot=21.49 Rg=18.535 SPS=17835
# bl=419 pos[1]=[8.1 -9.1 10.8] dr=1.95 t=0.0ps kin=1.51 pot=21.55 Rg=18.513 SPS=18957
# bl=420 pos[1]=[9.5 -8.6 12.0] dr=1.95 t=0.0ps kin=1.50 pot=21.52 Rg=18.487 SPS=18619
# bl=421 pos[1]=[10.5 -8.7 10.5] dr=1.89 t=0.0ps kin=1.50 pot=21.53 Rg=18.416 SPS=17756
# bl=422 pos[1]=[9.6 -8.3 10.7] dr=1.90 t=0.0ps kin=1.54 pot=21.55 Rg=18.335 SPS=17278
# bl=423 pos[1]=[11.5 -4.9 11.4] dr=1.88 t=0.0ps kin=1.56 pot=21.56 Rg=18.376 SPS=17895
# bl=424 pos[1]=[13.6 -5.0 12.6] dr=1.86 t=0.0ps kin=1.61 pot=21.48 Rg=18.290 SPS=18318
# bl=425 pos[1]=[14.2 -6.6 13.0] dr=1.90 t=0.0ps kin=1.54 pot=21.51 Rg=18.153 SPS=19033
# bl=426 pos[1]=[12.0 -7.4 8.8] dr=1.87 t=0.0ps kin=1.46 pot=21.55 Rg=18.142 SPS=18995
# bl=427 pos[1]=[11.0 -8.6 10.3] dr=1.91 t=0.0ps kin=1.51 pot=21.55 Rg=18.050 SPS=18261
# bl=428 pos[1]=[12.3 -6.0 14.1] dr=1.93 t=0.0ps kin=1.51 pot=21.52 Rg=17.958 SPS=19491
# bl=429 pos[1]=[8.8 -4.9 14.6] dr=1.93 t=0.0ps kin=1.50 pot=21.48 Rg=17.983 SPS=18079
# bl=430 pos[1]=[8.3 -5.1 14.7] dr=1.92 t=0.0ps kin=1.45 pot=21.52 Rg=18.013 SPS=18081
# bl=431 pos[1]=[10.3 -2.5 12.3] dr=1.94 t=0.0ps kin=1.45 pot=21.59 Rg=18.040 SPS=16941
# bl=432 pos[1]=[11.3 -4.2 11.8] dr=1.93 t=0.0ps kin=1.48 pot=21.54 Rg=18.094 SPS=18689
# bl=433 pos[1]=[11.2 -5.8 9.7] dr=1.99 t=0.0ps kin=1.54 pot=21.53 Rg=18.088 SPS=18042
# bl=434 pos[1]=[9.0 -8.4 13.6] dr=2.01 t=0.0ps kin=1.51 pot=21.52 Rg=18.083 SPS=18356
# bl=435 pos[1]=[5.2 -7.3 12.7] dr=1.90 t=0.0ps kin=1.53 pot=21.49 Rg=18.085 SPS=17871
# bl=436 pos[1]=[4.7 -7.2 12.6] dr=1.86 t=0.0ps kin=1.47 pot=21.53 Rg=18.104 SPS=17393
# bl=437 pos[1]=[5.6 -9.2 14.4] dr=1.88 t=0.0ps kin=1.51 pot=21.51 Rg=18.109 SPS=18527
# bl=438 pos[1]=[7.9 -8.8 12.5] dr=1.94 t=0.0ps kin=1.51 pot=21.49 Rg=18.157 SPS=19452
# bl=439 pos[1]=[8.9 -8.2 12.8] dr=1.99 t=0.0ps kin=1.47 pot=21.62 Rg=18.170 SPS=17817
# bl=440 pos[1]=[8.8 -10.4 12.9] dr=1.90 t=0.0ps kin=1.48 pot=21.51 Rg=18.102 SPS=18442
# bl=441 pos[1]=[9.4 -11.3 9.3] dr=1.92 t=0.0ps kin=1.48 pot=21.51 Rg=18.169 SPS=18969
# bl=442 pos[1]=[9.3 -11.5 7.8] dr=1.93 t=0.0ps kin=1.55 pot=21.54 Rg=18.117 SPS=18065
# bl=443 pos[1]=[10.3 -9.3 6.9] dr=1.95 t=0.0ps kin=1.48 pot=21.52 Rg=18.073 SPS=17305
# bl=444 pos[1]=[12.5 -8.7 7.8] dr=1.84 t=0.0ps kin=1.47 pot=21.53 Rg=18.066 SPS=17964
# bl=445 pos[1]=[12.9 -9.8 9.8] dr=1.93 t=0.0ps kin=1.50 pot=21.53 Rg=18.110 SPS=18342
# bl=446 pos[1]=[11.3 -8.1 10.2] dr=1.92 t=0.0ps kin=1.47 pot=21.51 Rg=18.233 SPS=18036
# bl=447 pos[1]=[9.4 -8.9 10.4] dr=1.82 t=0.0ps kin=1.47 pot=21.54 Rg=18.299 SPS=17754
# bl=448 pos[1]=[7.7 -6.4 10.2] dr=1.85 t=0.0ps kin=1.53 pot=21.49 Rg=18.351 SPS=17935
# bl=449 pos[1]=[11.8 -8.4 10.3] dr=1.85 t=0.0ps kin=1.49 pot=21.52 Rg=18.337 SPS=18395
#
# Statistics for the simulation opt_chr10_100K, number of particles: 1356,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-0.07227567 -2.66322794  0.52706425]   Rg =  18.337341
#      median bond size is  0.9686703224329067
#      three shortest/longest (<10)/ bonds are  [0.88452477 0.89201103 0.89562897]    [1.08577991 1.09868998 1.10660633]
#      95 percentile of distance to center is:    28.14832701231159
#      density of closest 95% monomers is:    0.01378913178227239
#      density of the core monomers is:    0.048936216632071365
#      min/median/mean/max coordinates are:
#      x: -18.62, -0.72, -0.07, 18.04
#      y: -26.90, -3.81, -2.66, 24.91
#      z: -23.27, 0.58, 0.53, 22.82
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4969761510119945 should be: 1.5
#      fastest particles are (in kT):  [7.26874342 7.42209823 7.5722081  7.74802984 8.65235415]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'CustomTypes']
#      Number of exceptions:   1355
#
# Potential Energy Ep =  21.51648633388643
# bl=450 pos[1]=[12.8 -8.5 10.5] dr=1.94 t=0.0ps kin=1.52 pot=21.49 Rg=18.385 SPS=18013
# bl=451 pos[1]=[11.8 -9.0 10.2] dr=2.01 t=0.0ps kin=1.53 pot=21.55 Rg=18.456 SPS=17801
# bl=452 pos[1]=[10.4 -9.2 10.9] dr=2.02 t=0.0ps kin=1.46 pot=21.48 Rg=18.453 SPS=17966
# bl=453 pos[1]=[7.5 -7.4 9.1] dr=1.95 t=0.0ps kin=1.44 pot=21.51 Rg=18.351 SPS=17377
# bl=454 pos[1]=[8.4 -7.9 8.9] dr=1.93 t=0.0ps kin=1.55 pot=21.49 Rg=18.180 SPS=18436
# bl=455 pos[1]=[9.5 -5.8 11.5] dr=1.89 t=0.0ps kin=1.51 pot=21.50 Rg=18.196 SPS=18007
# bl=456 pos[1]=[11.8 -5.2 9.8] dr=1.95 t=0.0ps kin=1.45 pot=21.52 Rg=18.253 SPS=18478
# bl=457 pos[1]=[9.4 -5.9 11.1] dr=1.96 t=0.0ps kin=1.48 pot=21.49 Rg=18.398 SPS=17272
# bl=458 pos[1]=[9.2 -5.8 12.0] dr=1.90 t=0.0ps kin=1.47 pot=21.50 Rg=18.531 SPS=17164
# bl=459 pos[1]=[9.7 -5.5 10.3] dr=1.86 t=0.0ps kin=1.46 pot=21.52 Rg=18.592 SPS=17210
# bl=460 pos[1]=[10.6 -5.8 10.7] dr=1.99 t=0.0ps kin=1.56 pot=21.54 Rg=18.703 SPS=18393
# bl=461 pos[1]=[9.2 -6.3 8.3] dr=1.99 t=0.0ps kin=1.54 pot=21.55 Rg=18.589 SPS=18268
# bl=462 pos[1]=[8.1 -5.0 12.2] dr=1.93 t=0.0ps kin=1.50 pot=21.49 Rg=18.540 SPS=18842
# bl=463 pos[1]=[8.3 -3.3 12.6] dr=1.90 t=0.0ps kin=1.46 pot=21.47 Rg=18.660 SPS=17534
# bl=464 pos[1]=[7.3 -3.7 12.4] dr=1.92 t=0.0ps kin=1.44 pot=21.48 Rg=18.799 SPS=18585
# bl=465 pos[1]=[8.4 -4.8 12.3] dr=1.90 t=0.0ps kin=1.47 pot=21.49 Rg=18.853 SPS=17820
# bl=466 pos[1]=[6.4 -7.2 11.9] dr=1.87 t=0.0ps kin=1.45 pot=21.54 Rg=18.925 SPS=17620
# bl=467 pos[1]=[7.9 -8.1 13.1] dr=1.89 t=0.0ps kin=1.47 pot=21.50 Rg=19.005 SPS=17836
# bl=468 pos[1]=[8.7 -8.7 11.8] dr=1.89 t=0.0ps kin=1.47 pot=21.51 Rg=19.013 SPS=17542
# bl=469 pos[1]=[8.4 -10.5 8.9] dr=1.95 t=0.0ps kin=1.53 pot=21.51 Rg=19.014 SPS=16890
# bl=470 pos[1]=[10.3 -12.2 9.7] dr=1.85 t=0.0ps kin=1.48 pot=21.51 Rg=19.015 SPS=16688
# bl=471 pos[1]=[11.8 -13.0 10.9] dr=1.90 t=0.0ps kin=1.47 pot=21.52 Rg=19.059 SPS=16420
# bl=472 pos[1]=[14.4 -9.9 11.9] dr=1.88 t=0.0ps kin=1.42 pot=21.52 Rg=19.097 SPS=17549
# bl=473 pos[1]=[16.2 -10.1 11.9] dr=2.01 t=0.0ps kin=1.51 pot=21.49 Rg=19.124 SPS=17193
# bl=474 pos[1]=[14.4 -7.4 9.5] dr=1.91 t=0.0ps kin=1.55 pot=21.56 Rg=19.167 SPS=17502
# bl=475 pos[1]=[14.5 -7.4 7.3] dr=1.86 t=0.0ps kin=1.54 pot=21.56 Rg=19.220 SPS=17610
# bl=476 pos[1]=[13.2 -7.4 6.4] dr=1.88 t=0.0ps kin=1.51 pot=21.48 Rg=19.264 SPS=18545
# bl=477 pos[1]=[13.2 -11.9 4.0] dr=1.88 t=0.0ps kin=1.45 pot=21.53 Rg=19.343 SPS=18407
# bl=478 pos[1]=[12.8 -12.5 1.5] dr=1.93 t=0.0ps kin=1.48 pot=21.57 Rg=19.374 SPS=18264
# bl=479 pos[1]=[13.4 -15.9 -0.5] dr=1.87 t=0.0ps kin=1.55 pot=21.49 Rg=19.445 SPS=17459
# bl=480 pos[1]=[10.8 -17.1 -1.9] dr=1.93 t=0.0ps kin=1.52 pot=21.50 Rg=19.453 SPS=17634
# bl=481 pos[1]=[11.4 -17.9 -0.4] dr=1.96 t=0.0ps kin=1.55 pot=21.49 Rg=19.426 SPS=16682
# bl=482 pos[1]=[9.5 -16.7 -0.2] dr=2.03 t=0.0ps kin=1.53 pot=21.49 Rg=19.402 SPS=17459
# bl=483 pos[1]=[11.1 -16.3 0.3] dr=1.96 t=0.0ps kin=1.47 pot=21.54 Rg=19.343 SPS=18388
# bl=484 pos[1]=[9.9 -14.6 -2.9] dr=1.92 t=0.0ps kin=1.53 pot=21.50 Rg=19.245 SPS=17616
# bl=485 pos[1]=[7.3 -12.9 -1.5] dr=1.93 t=0.0ps kin=1.49 pot=21.52 Rg=19.210 SPS=17767
# bl=486 pos[1]=[7.2 -11.0 -1.0] dr=2.00 t=0.0ps kin=1.53 pot=21.53 Rg=19.330 SPS=17683
# bl=487 pos[1]=[9.0 -9.5 -2.6] dr=1.97 t=0.0ps kin=1.53 pot=21.50 Rg=19.414 SPS=17602
# bl=488 pos[1]=[10.4 -9.3 -1.6] dr=1.91 t=0.0ps kin=1.54 pot=21.48 Rg=19.465 SPS=17105
# bl=489 pos[1]=[11.5 -6.9 -3.2] dr=1.95 t=0.0ps kin=1.50 pot=21.53 Rg=19.410 SPS=17572
# bl=490 pos[1]=[11.0 -10.6 -0.5] dr=1.91 t=0.0ps kin=1.51 pot=21.54 Rg=19.475 SPS=17413
# bl=491 pos[1]=[10.7 -8.5 0.1] dr=1.87 t=0.0ps kin=1.50 pot=21.51 Rg=19.463 SPS=17065
# bl=492 pos[1]=[9.9 -7.8 0.1] dr=1.92 t=0.0ps kin=1.49 pot=21.52 Rg=19.425 SPS=17887
# bl=493 pos[1]=[9.2 -5.1 -0.6] dr=1.94 t=0.0ps kin=1.47 pot=21.50 Rg=19.329 SPS=17985
# bl=494 pos[1]=[8.7 -6.6 -1.1] dr=1.89 t=0.0ps kin=1.51 pot=21.51 Rg=19.269 SPS=19224
# bl=495 pos[1]=[8.8 -5.2 -0.2] dr=1.97 t=0.0ps kin=1.48 pot=21.54 Rg=19.244 SPS=17232
# bl=496 pos[1]=[13.0 -4.8 0.1] dr=1.93 t=0.0ps kin=1.53 pot=21.49 Rg=19.292 SPS=17349
# bl=497 pos[1]=[13.4 -7.7 -1.5] dr=1.95 t=0.0ps kin=1.44 pot=21.49 Rg=19.308 SPS=19356
# bl=498 pos[1]=[12.4 -8.1 -4.1] dr=1.93 t=0.0ps kin=1.50 pot=21.52 Rg=19.345 SPS=18841
# bl=499 pos[1]=[15.1 -9.4 -5.3] dr=2.00 t=0.0ps kin=1.52 pot=21.49 Rg=19.431 SPS=19043
#
# Statistics for the simulation opt_chr10_100K, number of particles: 1356,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-1.58077303 -3.03268388  1.26731141]   Rg =  19.431221
#      median bond size is  0.9668922533966471
#      three shortest/longest (<10)/ bonds are  [0.8810699  0.8864538  0.89048832]    [1.08607889 1.08624744 1.1096066 ]
#      95 percentile of distance to center is:    29.298526039002308
#      density of closest 95% monomers is:    0.012228054585920347
#      density of the core monomers is:    0.031233295747088635
#      min/median/mean/max coordinates are:
#      x: -23.78, -1.81, -1.58, 18.15
#      y: -26.05, -4.44, -3.03, 26.04
#      z: -22.66, 1.13, 1.27, 21.36
#
# Statistics for velocities:
#      mean kinetic energy is:  1.523154574455818 should be: 1.5
#      fastest particles are (in kT):  [6.90841757 7.05230531 7.28597672 7.76097068 7.85130844]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'CustomTypes']
#      Number of exceptions:   1355
#
# Potential Energy Ep =  21.487707987647493
# bl=500 pos[1]=[15.8 -10.1 -6.8] dr=1.93 t=0.0ps kin=1.55 pot=21.52 Rg=19.475 SPS=16830
# bl=501 pos[1]=[17.1 -7.7 -8.9] dr=1.96 t=0.0ps kin=1.47 pot=21.55 Rg=19.509 SPS=17453
# bl=502 pos[1]=[18.2 -8.2 -9.0] dr=1.90 t=0.0ps kin=1.55 pot=21.51 Rg=19.601 SPS=17036
# bl=503 pos[1]=[18.9 -8.3 -9.7] dr=1.96 t=0.0ps kin=1.49 pot=21.54 Rg=19.697 SPS=17006
# bl=504 pos[1]=[19.4 -8.9 -8.8] dr=1.97 t=0.0ps kin=1.56 pot=21.51 Rg=19.778 SPS=16917
# bl=505 pos[1]=[19.5 -7.3 -7.7] dr=1.85 t=0.0ps kin=1.53 pot=21.51 Rg=19.739 SPS=16449
# bl=506 pos[1]=[18.1 -6.9 -8.1] dr=1.86 t=0.0ps kin=1.49 pot=21.51 Rg=19.733 SPS=17360
# bl=507 pos[1]=[18.2 -8.7 -7.9] dr=1.94 t=0.0ps kin=1.54 pot=21.47 Rg=19.753 SPS=18496
# bl=508 pos[1]=[14.2 -6.4 -9.8] dr=1.92 t=0.0ps kin=1.52 pot=21.53 Rg=19.835 SPS=18055
# bl=509 pos[1]=[10.7 -4.6 -9.6] dr=1.94 t=0.0ps kin=1.52 pot=21.53 Rg=19.819 SPS=17995
# bl=510 pos[1]=[12.2 -2.8 -9.1] dr=2.00 t=0.0ps kin=1.56 pot=21.50 Rg=19.781 SPS=18380
# bl=511 pos[1]=[13.9 -3.9 -7.8] dr=1.95 t=0.0ps kin=1.50 pot=21.55 Rg=19.696 SPS=18754
# bl=512 pos[1]=[12.7 -6.0 -6.5] dr=1.85 t=0.0ps kin=1.45 pot=21.52 Rg=19.691 SPS=17316
# bl=513 pos[1]=[13.2 -7.0 -9.7] dr=1.91 t=0.0ps kin=1.48 pot=21.52 Rg=19.717 SPS=18879
# bl=514 pos[1]=[12.4 -5.5 -9.0] dr=1.93 t=0.0ps kin=1.50 pot=21.53 Rg=19.767 SPS=18802
# bl=515 pos[1]=[10.2 -3.9 -9.8] dr=1.90 t=0.0ps kin=1.50 pot=21.57 Rg=19.898 SPS=17889
# bl=516 pos[1]=[9.5 -4.4 -9.3] dr=1.90 t=0.0ps kin=1.56 pot=21.51 Rg=20.031 SPS=16946
# bl=517 pos[1]=[9.5 -3.4 -8.8] dr=1.92 t=0.0ps kin=1.47 pot=21.48 Rg=20.139 SPS=17123
# bl=518 pos[1]=[9.8 -6.7 -8.6] dr=1.86 t=0.0ps kin=1.45 pot=21.47 Rg=20.237 SPS=17204
# bl=519 pos[1]=[8.3 -4.5 -5.7] dr=1.82 t=0.0ps kin=1.45 pot=21.48 Rg=20.344 SPS=16950
# bl=520 pos[1]=[7.8 -4.8 -4.5] dr=1.91 t=0.0ps kin=1.53 pot=21.49 Rg=20.361 SPS=17410
# bl=521 pos[1]=[9.5 -3.2 -4.9] dr=1.93 t=0.0ps kin=1.48 pot=21.54 Rg=20.403 SPS=17789
# bl=522 pos[1]=[12.7 -3.7 -7.9] dr=1.96 t=0.0ps kin=1.48 pot=21.49 Rg=20.336 SPS=18426
# bl=523 pos[1]=[12.1 -3.3 -7.9] dr=1.96 t=0.0ps kin=1.53 pot=21.51 Rg=20.272 SPS=18018
# bl=524 pos[1]=[14.5 -4.7 -5.5] dr=1.93 t=0.0ps kin=1.49 pot=21.54 Rg=20.225 SPS=17607
# bl=525 pos[1]=[16.6 -3.5 -7.8] dr=1.94 t=0.0ps kin=1.50 pot=21.53 Rg=20.275 SPS=17293
# bl=526 pos[1]=[18.3 -5.5 -6.2] dr=1.92 t=0.0ps kin=1.51 pot=21.52 Rg=20.267 SPS=17293
# bl=527 pos[1]=[18.2 -5.7 -2.6] dr=1.93 t=0.0ps kin=1.49 pot=21.50 Rg=20.264 SPS=17787
# bl=528 pos[1]=[16.2 -5.2 -0.3] dr=1.91 t=0.0ps kin=1.48 pot=21.54 Rg=20.265 SPS=17433
# bl=529 pos[1]=[16.9 -6.4 0.5] dr=1.91 t=0.0ps kin=1.52 pot=21.54 Rg=20.185 SPS=18321
# bl=530 pos[1]=[13.0 -8.6 -0.3] dr=1.91 t=0.0ps kin=1.49 pot=21.53 Rg=20.207 SPS=18888
# bl=531 pos[1]=[13.3 -9.8 1.2] dr=1.91 t=0.0ps kin=1.51 pot=21.53 Rg=20.238 SPS=18805
# bl=532 pos[1]=[10.4 -8.9 2.6] dr=1.96 t=0.0ps kin=1.51 pot=21.49 Rg=20.353 SPS=19770
# bl=533 pos[1]=[12.7 -10.2 3.0] dr=1.84 t=0.0ps kin=1.55 pot=21.48 Rg=20.443 SPS=18921
# bl=534 pos[1]=[14.4 -10.8 2.8] dr=1.93 t=0.0ps kin=1.53 pot=21.56 Rg=20.521 SPS=19309
# bl=535 pos[1]=[14.3 -11.8 1.8] dr=1.96 t=0.0ps kin=1.50 pot=21.55 Rg=20.566 SPS=19285
# bl=536 pos[1]=[13.3 -9.1 3.2] dr=1.97 t=0.0ps kin=1.52 pot=21.53 Rg=20.559 SPS=18387
# bl=537 pos[1]=[10.5 -10.2 1.7] dr=1.97 t=0.0ps kin=1.52 pot=21.52 Rg=20.629 SPS=19346
# bl=538 pos[1]=[7.6 -6.6 1.4] dr=1.91 t=0.0ps kin=1.51 pot=21.53 Rg=20.805 SPS=19581
# bl=539 pos[1]=[7.3 -6.3 -0.8] dr=1.92 t=0.0ps kin=1.51 pot=21.51 Rg=20.943 SPS=19683
# bl=540 pos[1]=[7.2 -7.1 -1.1] dr=2.04 t=0.0ps kin=1.47 pot=21.52 Rg=21.073 SPS=19711
# bl=541 pos[1]=[8.5 -6.5 1.6] dr=2.01 t=0.0ps kin=1.50 pot=21.51 Rg=21.044 SPS=19387
# bl=542 pos[1]=[9.8 -4.7 5.2] dr=2.05 t=0.0ps kin=1.51 pot=21.50 Rg=21.073 SPS=19298
# bl=543 pos[1]=[13.1 -3.4 2.1] dr=1.99 t=0.0ps kin=1.57 pot=21.53 Rg=21.196 SPS=19184
# bl=544 pos[1]=[13.4 -3.3 1.3] dr=1.97 t=0.0ps kin=1.50 pot=21.51 Rg=21.290 SPS=18217
# bl=545 pos[1]=[15.2 -1.2 4.7] dr=1.92 t=0.0ps kin=1.46 pot=21.51 Rg=21.341 SPS=18839
# bl=546 pos[1]=[17.8 -2.1 5.0] dr=1.92 t=0.0ps kin=1.51 pot=21.50 Rg=21.275 SPS=18060
# bl=547 pos[1]=[15.3 -0.8 4.9] dr=1.82 t=0.0ps kin=1.54 pot=21.48 Rg=21.252 SPS=19464
# bl=548 pos[1]=[13.5 -0.5 4.2] dr=1.92 t=0.0ps kin=1.50 pot=21.54 Rg=21.307 SPS=18517
# bl=549 pos[1]=[14.6 -0.9 4.6] dr=1.84 t=0.0ps kin=1.48 pot=21.53 Rg=21.447 SPS=19058
#
# Statistics for the simulation opt_chr10_100K, number of particles: 1356,  number of chains: 1
#
# Statistics for particle position
#      mean position is:  [-1.48787812 -1.69393354  3.20714016]   Rg =  21.446777
#      median bond size is  0.9685468450517378
#      three shortest/longest (<10)/ bonds are  [0.87836769 0.89275814 0.89468099]    [1.08557798 1.08831558 1.09376884]
#      95 percentile of distance to center is:    31.78132846236095
#      density of closest 95% monomers is:    0.009580287563315745
#      density of the core monomers is:    0.015419462504867225
#      min/median/mean/max coordinates are:
#      x: -29.25, -0.74, -1.49, 24.15
#      y: -32.07, -1.69, -1.69, 34.02
#      z: -24.47, 2.13, 3.21, 26.66
#
# Statistics for velocities:
#      mean kinetic energy is:  1.4878563873654906 should be: 1.5
#      fastest particles are (in kT):  [6.84950413 7.63155124 7.72072748 8.23989752 8.91064381]
#
# Statistics for the system:
#      Forces are:  ['FENEBond', 'AngleForce', 'RepulsiveSoftCore', 'CustomTypes']
#      Number of exceptions:   1355
#
# Potential Energy Ep =  21.526786331581857
# bl=550 pos[1]=[16.8 -1.4 5.7] dr=1.90 t=0.0ps kin=1.49 pot=21.50 Rg=21.545 SPS=17628

# %% [markdown]
# In the end of each replica simulation we need to save some important values required to calculate the inversion. <br>
#
# We are saving these files using the H5 compression because it is faster to write/read. <br>
#
# Note: attention to this step. We have these 4 files for each replica for each iteration step. Be organized!

# %%
rep=1

with h5py.File(sim.folder + "/polds_type_" + str(rep)+".h5", 'w') as hf:
    hf.create_dataset("polds_type",  data=opt.polds_type)

with h5py.File(sim.folder + "/Bij_type_" + str(rep)+".h5", 'w') as hf:
    hf.create_dataset("Bij_type",  data=opt.Bij_type)

with h5py.File(sim.folder + "/Nframes_" + str(rep)+".h5", 'w') as hf:
    hf.create_dataset("Nframes",  data=opt.Nframes)

with h5py.File(sim.folder + "/Pold_" + str(rep)+".h5", 'w') as hf:
    hf.create_dataset("Pold",  data=opt.Pold)

# %% [markdown]
# The first part of the optimization is finished. Inside the output folder, for each iteration, there are these 4 files used in next step.

# %%
# %%bash
# ls iteration_0/*.h5
# Out:
# iteration_0/Bij_type_1.h5
# iteration_0/Nframes_1.h5
# iteration_0/Pold_1.h5
# iteration_0/polds_type_1.h5

# %% [markdown]
# The second part is the inversion, it is quite simple, just feed the optmization object with all replicas and make the inversion to get the new lambda file.

# %%
opt2 = CustomMiChroMTraining(ChromSeq="input/seq_chr10_100k.txt",
                            mu=3.22, rc = 1.78)

# %%
iterations = "iteration_0"
replicas=[1]
for replica in replicas:
    with h5py.File(iterations + "/polds_type_" + str(replica)+".h5", 'r') as hf:
        opt2.polds_type += hf['polds_type'][:]

    with h5py.File(iterations + "/Bij_type_" + str(replica)+".h5", 'r') as hf:
        opt2.Bij_type += hf['Bij_type'][:]

    with h5py.File(iterations + "/Nframes_" + str(replica)+".h5", 'r') as hf:
        opt2.Nframes +=hf['Nframes'][()]

    with h5py.File(iterations + "/Pold_" + str(replica)+".h5", 'r') as hf:
        opt2.Pold += hf['Pold'][:]

# %% [markdown]
# With the parameters fed with all replicas, we calculate the inversion and get the new lambdas

# %%
lambdas = opt2.getLamb_types(exp_map="input/chr10_100k.dense")
print(lambdas)
# Out:
# [[657009.61913517 434848.55381908]
#  [434848.55381908 324626.27938706]]

# %% [markdown]
# Now load the old lambda value to calculate the new (lambda_1, in this case) according the Newton Method: <br>
#
# $\lambda_1 = \lambda_0 - \delta\times\lambda_{actual}$
#
# $\delta$ is the learning rate or damp, it can be adjusted in order to get values between [-1:0]. The average value of MiChroM's parameters for Human GM12878 is -0.3

# %%
old = pd.read_csv("input/lambda_0", sep=None, engine='python')
lambda_old = old.values
seq = old.columns
print(lambda_old)
# Out:
# [[0 0]
#  [0 0]]

# %%
damp = 10**-6
lambda_new = lambda_old - damp*lambdas

# %%
print(lambda_new)
# Out:
# [[-0.65700962 -0.43484855]
#  [-0.43484855 -0.32462628]]

# %% [markdown]
# Save the new lambda file (lambda_1.txt) and some files to analyze the inversion

# %%
iteration = 0
#prob of A/B in sim and exp
phi_sim = opt2.calc_sim_phi_types().ravel()
phi_exp = opt2.calc_exp_phi_types().ravel()
np.savetxt('phi_sim_' + str(iteration), phi_sim)
np.savetxt('phi_exp', phi_exp)

plt.plot(phi_sim, label="sim")
plt.plot(phi_exp, label="exp")
plt.legend()

#HiC_simulate
dense_sim = opt2.getHiCSim()
np.savetxt('hic_sim_' + str(iteration)+'.dense', dense_sim)
plt.matshow(dense_sim, norm=mpl.colors.LogNorm(vmin=0.0001, vmax=dense_sim.max()),cmap="Reds")

#save the new lambda file
lamb = pd.DataFrame(lambda_new,columns=seq)
lamb.to_csv("input/lambda_1", index=False)

# %% [markdown]
# Redo these steps using the new lambda file (lambda_1) as input for Types potential in the next iteration.
#
# The error can be calculate using phi_sim_1 and phi_exp by the equation:<br>
# $error = \frac{|\phi_{sim}-\phi_{exp}|}{\phi_{exp}}$
#
# This is appended in the file  "error_and_pearsonC_types"

# %%
# %%bash
# cat error_and_pearsonC_types
# Out:
# Error: 0.607774  Pearson's Correlation: 0.814562
# Error: 0.615568  Pearson's Correlation: 0.854520

# %% [markdown]
# We included a folder named "scripts" that has some .py and .slurm files that can be used to run this optimization in parallel using slurm clusters (like POD).
